# %%
import sys, os

from html.parser import HTMLParser
from tqdm import tqdm_notebook as tqdm

import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt

from datetime import datetime
from datetime import timedelta

import yfinance as yf
from yahoofinancials import YahooFinancials

from humpack import tdict, Key_Table

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
def get_startdate(yrs):
    return datetime.today() - timedelta(days=int(365*yrs))

# %%
entry = '''<div _ngcontent-ddm-c13="" class="market-list list-view" data-etoro-locale-ns="discoverMarketResultsList"><!----><div _ngcontent-ddm-c13="" class="list-row-title ng-star-inserted"><div _ngcontent-ddm-c13="" automation-id="discover-market-results-symbol-head" class="list-row-title-cell pointer sort"> Market </div><div _ngcontent-ddm-c13="" automation-id="discover-market-results-change-head" class="list-row-title-cell pointer sort change"> Change </div><div _ngcontent-ddm-c13="" automation-id="discover-market-results-date-head" class="list-row-title-cell sort pointer change"><span _ngcontent-ddm-c13="" class="date">1D</span><div _ngcontent-ddm-c13="" class="resolution-arrows"><span _ngcontent-ddm-c13="" class="resolution-arrow-up"></span><span _ngcontent-ddm-c13="" class="resolution-arrow-down"></span></div></div><div _ngcontent-ddm-c13="" class="list-row-title-cell mobile-off buy-sell-column"><div _ngcontent-ddm-c13="" class="row-title-label">Sell</div><div _ngcontent-ddm-c13="" class="space-gap"></div><div _ngcontent-ddm-c13="" class="row-title-label">Buy</div></div><div _ngcontent-ddm-c13="" class="list-row-title-cell weeks"><div _ngcontent-ddm-c13="" automation-id="watchlist-list-title-range" class="row-title-label">52W Range</div></div><div _ngcontent-ddm-c13="" class="list-row-title-cell sentiment"><div _ngcontent-ddm-c13="" class="row-title-label">Sentiment</div></div><a _ngcontent-ddm-c13="" class="button-standard button-blue done pointer"><span _ngcontent-ddm-c13="" class="button-icon sprite"></span><span _ngcontent-ddm-c13="" class="done-button-text">discoverMarketResultsList.done</span></a></div><!----><!----><!----><et-instrument-row _ngcontent-ddm-c13="" automation-id="discover-market-results-row" _nghost-ddm-c16="" class="ng-star-inserted"><!----><!----><et-instrument-trading-row _ngcontent-ddm-c16="" automation-id="watchlist-grid-instruments-list" _nghost-ddm-c21="" class="ng-star-inserted"><div _ngcontent-ddm-c21="" class="row-wrap desktop-row"><et-card-avatar _ngcontent-ddm-c21="" automation-id="watchlist-item-list-wrapp-instrument" class="instrument-cell" _nghost-ddm-c22=""><a _ngcontent-ddm-c22="" class="card-avatar-wrap" href="/markets/btc"><div _ngcontent-ddm-c22="" class="avatar-img-wrap"><img _ngcontent-ddm-c22="" automation-id="trade-item-avatar" class="avatar-img" src="https://etoro-cdn.etorostatic.com/market-avatars/btc/70x70.png" alt="Bitcoin"><!----></div><div _ngcontent-ddm-c22="" automation-id="trade-item-info" class="avatar-info"><div _ngcontent-ddm-c22="" automation-id="trade-item-name" class="symbol">BTC</div><div _ngcontent-ddm-c22="" automation-id="trade-item-full-name" class="name">Bitcoin</div></div></a></et-card-avatar><!----><div _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-wrapp-rate-change" class="instrument-change instrument-cell negative ng-star-inserted"><!----><!----><div _ngcontent-ddm-c21="" class="change-items"><b _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-rate-change-amount" class="instrument-pro">-32.33</b><div _ngcontent-ddm-c21="" class="instrument-num"><span _ngcontent-ddm-c21="" class="arrow-sign"></span>(-0.35%)</div></div></div><!----><div _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-chart" class="instrument-cell chart-wrap ng-star-inserted"><et-instrument-sparklines _ngcontent-ddm-c21="" _nghost-ddm-c24=""><div _ngcontent-ddm-c24="" class="sparklines"><et-canvas-chart _ngcontent-ddm-c24="" class="fedeOut fadeIn" _nghost-ddm-c29=""><!----><canvas _ngcontent-ddm-c29="" class="ng-star-inserted" width="346" height="70" style="width: 173px; height: 35px;"></canvas><!----></et-canvas-chart></div></et-instrument-sparklines><a _ngcontent-ddm-c21="" class="watchlist-card-external-link icon-external-link"></a></div><et-buy-sell-buttons _ngcontent-ddm-c21="" automation-id="watchlist-item-grid-instrument-buy-sell-container" class="instrument-cell buy-sell-buttons" _nghost-ddm-c25=""><et-buy-sell-button _ngcontent-ddm-c25="" _nghost-ddm-c28=""><div _ngcontent-ddm-c28="" class="prices short-label negative-change" automation-id="buy-sell-button-container-sell"><div _ngcontent-ddm-c28="" class="trade-button-title">S</div><div _ngcontent-ddm-c28="" automation-id="buy-sell-button-rate-value" class="price">9190.<span class="after-decimal">31</span></div></div></et-buy-sell-button><div _ngcontent-ddm-c25="" class="space-gap"></div><et-buy-sell-button _ngcontent-ddm-c25="" _nghost-ddm-c28=""><div _ngcontent-ddm-c28="" class="prices short-label negative-change" automation-id="buy-sell-button-container-buy"><div _ngcontent-ddm-c28="" class="trade-button-title">B</div><div _ngcontent-ddm-c28="" automation-id="buy-sell-button-rate-value" class="price">9259.<span class="after-decimal">45</span></div></div></et-buy-sell-button></et-buy-sell-buttons><et-fifty-two-weeks _ngcontent-ddm-c21="" class="instrument-cell" _nghost-ddm-c26=""><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range" class="fiftytwo-weeks-progress-bar"><div _ngcontent-ddm-c26="" class="price-range"><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range-min" class="low">3797.37</div><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range-max" class="high">12294.36</div></div><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-bar" class="bar-wrap"><span _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-indicator" class="measure-arrow" style="left: 63.7193%;"></span></div></div></et-fifty-two-weeks><et-instrument-sentiment _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-sentiment" class="instrument-cell" _nghost-ddm-c27=""><!----><div _ngcontent-ddm-c27="" automation-id="instrument-sentiment-bar" class="bar-full-wrap ng-star-inserted"><div _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-data-title" class="bar-info"><h5 _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-percentage" class="percentage">97%</h5><h6 _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-action" class="status">Buying</h6></div><div _ngcontent-ddm-c27="" class="bar-wrap"><span _ngcontent-ddm-c27="" automation-id="list-instrument-sentiment-bar" class="progress-bar-buy-part" style="width: 97%; visibility: visible;"></span><span _ngcontent-ddm-c27="" automation-id="list-instrument-sentiment-bar" class="progress-bar-sell-part" style="width: 3%; visibility: visible;"></span></div></div><!----><!----></et-instrument-sentiment><et-trade-item-card-action _ngcontent-ddm-c16="" _nghost-ddm-c17=""><!----><et-trade-item-card-action _ngcontent-ddm-c13="" _nghost-ddm-c17="" class="ng-star-inserted"><et-watchlist-quick-edit _ngcontent-ddm-c13="" _nghost-ddm-c18=""><et-select _ngcontent-ddm-c18="" class="no-arrow ng-tns-c2-2400" _nghost-ddm-c2=""><div _ngcontent-ddm-c2="" class="ng-tns-c2-2400"><et-select-header _ngcontent-ddm-c18="" automation-id="watchlists-quick-edit-btn-add" class="watchlists-edit following" _nghost-ddm-c3=""><div _ngcontent-ddm-c3="" class="header-text"></div><i _ngcontent-ddm-c3="" class="arrow-down"></i></et-select-header><!----></div><!----><!----><!----></et-select></et-watchlist-quick-edit></et-trade-item-card-action><!----></et-trade-item-card-action></div></et-instrument-trading-row><!----></et-instrument-row><et-instrument-row _ngcontent-ddm-c13="" automation-id="discover-market-results-row" _nghost-ddm-c16="" class="ng-star-inserted"><!----><!----><et-instrument-trading-row _ngcontent-ddm-c16="" automation-id="watchlist-grid-instruments-list" _nghost-ddm-c21="" class="ng-star-inserted"><div _ngcontent-ddm-c21="" class="row-wrap desktop-row"><et-card-avatar _ngcontent-ddm-c21="" automation-id="watchlist-item-list-wrapp-instrument" class="instrument-cell" _nghost-ddm-c22=""><a _ngcontent-ddm-c22="" class="card-avatar-wrap" href="/markets/ethereum"><div _ngcontent-ddm-c22="" class="avatar-img-wrap"><img _ngcontent-ddm-c22="" automation-id="trade-item-avatar" class="avatar-img" src="https://etoro-cdn.etorostatic.com/market-avatars/eth-usd/150x150.png" alt="Ethereum"><!----></div><div _ngcontent-ddm-c22="" automation-id="trade-item-info" class="avatar-info"><div _ngcontent-ddm-c22="" automation-id="trade-item-name" class="symbol">ETHEREUM</div><div _ngcontent-ddm-c22="" automation-id="trade-item-full-name" class="name">Ethereum</div></div></a></et-card-avatar><!----><div _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-wrapp-rate-change" class="instrument-change instrument-cell negative ng-star-inserted"><!----><!----><div _ngcontent-ddm-c21="" class="change-items"><b _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-rate-change-amount" class="instrument-pro">-2.7704</b><div _ngcontent-ddm-c21="" class="instrument-num"><span _ngcontent-ddm-c21="" class="arrow-sign"></span>(-1.16%)</div></div></div><!----><div _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-chart" class="instrument-cell chart-wrap ng-star-inserted"><et-instrument-sparklines _ngcontent-ddm-c21="" _nghost-ddm-c24=""><div _ngcontent-ddm-c24="" class="sparklines"><et-canvas-chart _ngcontent-ddm-c24="" class="fedeOut fadeIn" _nghost-ddm-c29=""><!----><canvas _ngcontent-ddm-c29="" class="ng-star-inserted" width="346" height="70" style="width: 173px; height: 35px;"></canvas><!----></et-canvas-chart></div></et-instrument-sparklines><a _ngcontent-ddm-c21="" class="watchlist-card-external-link icon-external-link"></a></div><et-buy-sell-buttons _ngcontent-ddm-c21="" automation-id="watchlist-item-grid-instrument-buy-sell-container" class="instrument-cell buy-sell-buttons" _nghost-ddm-c25=""><et-buy-sell-button _ngcontent-ddm-c25="" _nghost-ddm-c28=""><div _ngcontent-ddm-c28="" class="prices short-label negative-change" automation-id="buy-sell-button-container-sell"><div _ngcontent-ddm-c28="" class="trade-button-title">S</div><div _ngcontent-ddm-c28="" automation-id="buy-sell-button-rate-value" class="price">236.<span class="after-decimal">7750</span></div></div></et-buy-sell-button><div _ngcontent-ddm-c25="" class="space-gap"></div><et-buy-sell-button _ngcontent-ddm-c25="" _nghost-ddm-c28=""><div _ngcontent-ddm-c28="" class="prices short-label negative-change" automation-id="buy-sell-button-container-buy"><div _ngcontent-ddm-c28="" class="trade-button-title">B</div><div _ngcontent-ddm-c28="" automation-id="buy-sell-button-rate-value" class="price">241.<span class="after-decimal">3126</span></div></div></et-buy-sell-button></et-buy-sell-buttons><et-fifty-two-weeks _ngcontent-ddm-c21="" class="instrument-cell" _nghost-ddm-c26=""><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range" class="fiftytwo-weeks-progress-bar"><div _ngcontent-ddm-c26="" class="price-range"><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range-min" class="low">84.62</div><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range-max" class="high">287.70</div></div><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-bar" class="bar-wrap"><span _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-indicator" class="measure-arrow" style="left: 75.8488%;"></span></div></div></et-fifty-two-weeks><et-instrument-sentiment _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-sentiment" class="instrument-cell" _nghost-ddm-c27=""><!----><div _ngcontent-ddm-c27="" automation-id="instrument-sentiment-bar" class="bar-full-wrap ng-star-inserted"><div _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-data-title" class="bar-info"><h5 _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-percentage" class="percentage">99%</h5><h6 _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-action" class="status">Buying</h6></div><div _ngcontent-ddm-c27="" class="bar-wrap"><span _ngcontent-ddm-c27="" automation-id="list-instrument-sentiment-bar" class="progress-bar-buy-part" style="width: 99%; visibility: visible;"></span><span _ngcontent-ddm-c27="" automation-id="list-instrument-sentiment-bar" class="progress-bar-sell-part" style="width: 1%; visibility: visible;"></span></div></div><!----><!----></et-instrument-sentiment><et-trade-item-card-action _ngcontent-ddm-c16="" _nghost-ddm-c17=""><!----><et-trade-item-card-action _ngcontent-ddm-c13="" _nghost-ddm-c17="" class="ng-star-inserted"><et-watchlist-quick-edit _ngcontent-ddm-c13="" _nghost-ddm-c18=""><et-select _ngcontent-ddm-c18="" class="no-arrow ng-tns-c2-2401" _nghost-ddm-c2=""><div _ngcontent-ddm-c2="" class="ng-tns-c2-2401"><et-select-header _ngcontent-ddm-c18="" automation-id="watchlists-quick-edit-btn-add" class="watchlists-edit" _nghost-ddm-c3=""><div _ngcontent-ddm-c3="" class="header-text"></div><i _ngcontent-ddm-c3="" class="arrow-down"></i></et-select-header><!----></div><!----><!----><!----></et-select></et-watchlist-quick-edit></et-trade-item-card-action><!----></et-trade-item-card-action></div></et-instrument-trading-row><!----></et-instrument-row><et-instrument-row _ngcontent-ddm-c13="" automation-id="discover-market-results-row" _nghost-ddm-c16="" class="ng-star-inserted"><!----><!----><et-instrument-trading-row _ngcontent-ddm-c16="" automation-id="watchlist-grid-instruments-list" _nghost-ddm-c21="" class="ng-star-inserted"><div _ngcontent-ddm-c21="" class="row-wrap desktop-row"><et-card-avatar _ngcontent-ddm-c21="" automation-id="watchlist-item-list-wrapp-instrument" class="instrument-cell" _nghost-ddm-c22=""><a _ngcontent-ddm-c22="" class="card-avatar-wrap" href="/markets/bch"><div _ngcontent-ddm-c22="" class="avatar-img-wrap"><img _ngcontent-ddm-c22="" automation-id="trade-item-avatar" class="avatar-img" src="https://etoro-cdn.etorostatic.com/market-avatars/100002/150x150.png" alt="Bitcoin Cash"><!----></div><div _ngcontent-ddm-c22="" automation-id="trade-item-info" class="avatar-info"><div _ngcontent-ddm-c22="" automation-id="trade-item-name" class="symbol">BCH</div><div _ngcontent-ddm-c22="" automation-id="trade-item-full-name" class="name">Bitcoin Cash</div></div></a></et-card-avatar><!----><div _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-wrapp-rate-change" class="instrument-change instrument-cell negative ng-star-inserted"><!----><!----><div _ngcontent-ddm-c21="" class="change-items"><b _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-rate-change-amount" class="instrument-pro">-0.38</b><div _ngcontent-ddm-c21="" class="instrument-num"><span _ngcontent-ddm-c21="" class="arrow-sign"></span>(-0.16%)</div></div></div><!----><div _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-chart" class="instrument-cell chart-wrap ng-star-inserted"><et-instrument-sparklines _ngcontent-ddm-c21="" _nghost-ddm-c24=""><div _ngcontent-ddm-c24="" class="sparklines"><et-canvas-chart _ngcontent-ddm-c24="" class="fedeOut fadeIn" _nghost-ddm-c29=""><!----><canvas _ngcontent-ddm-c29="" class="ng-star-inserted" width="346" height="70" style="width: 173px; height: 35px;"></canvas><!----></et-canvas-chart></div></et-instrument-sparklines><a _ngcontent-ddm-c21="" class="watchlist-card-external-link icon-external-link"></a></div><et-buy-sell-buttons _ngcontent-ddm-c21="" automation-id="watchlist-item-grid-instrument-buy-sell-container" class="instrument-cell buy-sell-buttons" _nghost-ddm-c25=""><et-buy-sell-button _ngcontent-ddm-c25="" _nghost-ddm-c28=""><div _ngcontent-ddm-c28="" class="prices short-label negative-change" automation-id="buy-sell-button-container-sell"><div _ngcontent-ddm-c28="" class="trade-button-title">S</div><div _ngcontent-ddm-c28="" automation-id="buy-sell-button-rate-value" class="price">234.<span class="after-decimal">83</span></div></div></et-buy-sell-button><div _ngcontent-ddm-c25="" class="space-gap"></div><et-buy-sell-button _ngcontent-ddm-c25="" _nghost-ddm-c28=""><div _ngcontent-ddm-c28="" class="prices short-label negative-change" automation-id="buy-sell-button-container-buy"><div _ngcontent-ddm-c28="" class="trade-button-title">B</div><div _ngcontent-ddm-c28="" automation-id="buy-sell-button-rate-value" class="price">239.<span class="after-decimal">33</span></div></div></et-buy-sell-button></et-buy-sell-buttons><et-fifty-two-weeks _ngcontent-ddm-c21="" class="instrument-cell" _nghost-ddm-c26=""><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range" class="fiftytwo-weeks-progress-bar"><div _ngcontent-ddm-c26="" class="price-range"><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range-min" class="low">135.81</div><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range-max" class="high">494.24</div></div><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-bar" class="bar-wrap"><span _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-indicator" class="measure-arrow" style="left: 27.9557%;"></span></div></div></et-fifty-two-weeks><et-instrument-sentiment _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-sentiment" class="instrument-cell" _nghost-ddm-c27=""><!----><div _ngcontent-ddm-c27="" automation-id="instrument-sentiment-bar" class="bar-full-wrap ng-star-inserted"><div _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-data-title" class="bar-info"><h5 _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-percentage" class="percentage">99%</h5><h6 _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-action" class="status">Buying</h6></div><div _ngcontent-ddm-c27="" class="bar-wrap"><span _ngcontent-ddm-c27="" automation-id="list-instrument-sentiment-bar" class="progress-bar-buy-part" style="width: 99%; visibility: visible;"></span><span _ngcontent-ddm-c27="" automation-id="list-instrument-sentiment-bar" class="progress-bar-sell-part" style="width: 1%; visibility: visible;"></span></div></div><!----><!----></et-instrument-sentiment><et-trade-item-card-action _ngcontent-ddm-c16="" _nghost-ddm-c17=""><!----><et-trade-item-card-action _ngcontent-ddm-c13="" _nghost-ddm-c17="" class="ng-star-inserted"><et-watchlist-quick-edit _ngcontent-ddm-c13="" _nghost-ddm-c18=""><et-select _ngcontent-ddm-c18="" class="no-arrow ng-tns-c2-2402" _nghost-ddm-c2=""><div _ngcontent-ddm-c2="" class="ng-tns-c2-2402"><et-select-header _ngcontent-ddm-c18="" automation-id="watchlists-quick-edit-btn-add" class="watchlists-edit" _nghost-ddm-c3=""><div _ngcontent-ddm-c3="" class="header-text"></div><i _ngcontent-ddm-c3="" class="arrow-down"></i></et-select-header><!----></div><!----><!----><!----></et-select></et-watchlist-quick-edit></et-trade-item-card-action><!----></et-trade-item-card-action></div></et-instrument-trading-row><!----></et-instrument-row><et-instrument-row _ngcontent-ddm-c13="" automation-id="discover-market-results-row" _nghost-ddm-c16="" class="ng-star-inserted"><!----><!----><et-instrument-trading-row _ngcontent-ddm-c16="" automation-id="watchlist-grid-instruments-list" _nghost-ddm-c21="" class="ng-star-inserted"><div _ngcontent-ddm-c21="" class="row-wrap desktop-row"><et-card-avatar _ngcontent-ddm-c21="" automation-id="watchlist-item-list-wrapp-instrument" class="instrument-cell" _nghost-ddm-c22=""><a _ngcontent-ddm-c22="" class="card-avatar-wrap" href="/markets/xrp"><div _ngcontent-ddm-c22="" class="avatar-img-wrap"><img _ngcontent-ddm-c22="" automation-id="trade-item-avatar" class="avatar-img" src="https://etoro-cdn.etorostatic.com/market-avatars/100003/150x150.png" alt="Ripple"><!----></div><div _ngcontent-ddm-c22="" automation-id="trade-item-info" class="avatar-info"><div _ngcontent-ddm-c22="" automation-id="trade-item-name" class="symbol">XRP</div><div _ngcontent-ddm-c22="" automation-id="trade-item-full-name" class="name">Ripple</div></div></a></et-card-avatar><!----><div _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-wrapp-rate-change" class="instrument-change instrument-cell negative ng-star-inserted"><!----><!----><div _ngcontent-ddm-c21="" class="change-items"><b _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-rate-change-amount" class="instrument-pro">-0.0071</b><div _ngcontent-ddm-c21="" class="instrument-num"><span _ngcontent-ddm-c21="" class="arrow-sign"></span>(-3.54%)</div></div></div><!----><div _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-chart" class="instrument-cell chart-wrap ng-star-inserted"><et-instrument-sparklines _ngcontent-ddm-c21="" _nghost-ddm-c24=""><div _ngcontent-ddm-c24="" class="sparklines"><et-canvas-chart _ngcontent-ddm-c24="" class="fedeOut fadeIn" _nghost-ddm-c29=""><!----><canvas _ngcontent-ddm-c29="" class="ng-star-inserted" width="346" height="70" style="width: 173px; height: 35px;"></canvas><!----></et-canvas-chart></div></et-instrument-sparklines><a _ngcontent-ddm-c21="" class="watchlist-card-external-link icon-external-link"></a></div><et-buy-sell-buttons _ngcontent-ddm-c21="" automation-id="watchlist-item-grid-instrument-buy-sell-container" class="instrument-cell buy-sell-buttons" _nghost-ddm-c25=""><et-buy-sell-button _ngcontent-ddm-c25="" _nghost-ddm-c28=""><div _ngcontent-ddm-c28="" class="prices short-label negative-change" automation-id="buy-sell-button-container-sell"><div _ngcontent-ddm-c28="" class="trade-button-title">S</div><div _ngcontent-ddm-c28="" automation-id="buy-sell-button-rate-value" class="price">0.<span class="after-decimal">1937</span></div></div></et-buy-sell-button><div _ngcontent-ddm-c25="" class="space-gap"></div><et-buy-sell-button _ngcontent-ddm-c25="" _nghost-ddm-c28=""><div _ngcontent-ddm-c28="" class="prices short-label negative-change" automation-id="buy-sell-button-container-buy"><div _ngcontent-ddm-c28="" class="trade-button-title">B</div><div _ngcontent-ddm-c28="" automation-id="buy-sell-button-rate-value" class="price">0.<span class="after-decimal">1985</span></div></div></et-buy-sell-button></et-buy-sell-buttons><et-fifty-two-weeks _ngcontent-ddm-c21="" class="instrument-cell" _nghost-ddm-c26=""><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range" class="fiftytwo-weeks-progress-bar"><div _ngcontent-ddm-c26="" class="price-range"><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range-min" class="low">0.11</div><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range-max" class="high">0.34</div></div><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-bar" class="bar-wrap"><span _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-indicator" class="measure-arrow" style="left: 37.5512%;"></span></div></div></et-fifty-two-weeks><et-instrument-sentiment _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-sentiment" class="instrument-cell" _nghost-ddm-c27=""><!----><div _ngcontent-ddm-c27="" automation-id="instrument-sentiment-bar" class="bar-full-wrap ng-star-inserted"><div _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-data-title" class="bar-info"><h5 _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-percentage" class="percentage">100%</h5><h6 _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-action" class="status">Buying</h6></div><div _ngcontent-ddm-c27="" class="bar-wrap"><span _ngcontent-ddm-c27="" automation-id="list-instrument-sentiment-bar" class="progress-bar-buy-part" style="width: 100%; visibility: visible;"></span><span _ngcontent-ddm-c27="" automation-id="list-instrument-sentiment-bar" class="progress-bar-sell-part" style="width: 0%; visibility: visible;"></span></div></div><!----><!----></et-instrument-sentiment><et-trade-item-card-action _ngcontent-ddm-c16="" _nghost-ddm-c17=""><!----><et-trade-item-card-action _ngcontent-ddm-c13="" _nghost-ddm-c17="" class="ng-star-inserted"><et-watchlist-quick-edit _ngcontent-ddm-c13="" _nghost-ddm-c18=""><et-select _ngcontent-ddm-c18="" class="no-arrow ng-tns-c2-2403" _nghost-ddm-c2=""><div _ngcontent-ddm-c2="" class="ng-tns-c2-2403"><et-select-header _ngcontent-ddm-c18="" automation-id="watchlists-quick-edit-btn-add" class="watchlists-edit" _nghost-ddm-c3=""><div _ngcontent-ddm-c3="" class="header-text"></div><i _ngcontent-ddm-c3="" class="arrow-down"></i></et-select-header><!----></div><!----><!----><!----></et-select></et-watchlist-quick-edit></et-trade-item-card-action><!----></et-trade-item-card-action></div></et-instrument-trading-row><!----></et-instrument-row><et-instrument-row _ngcontent-ddm-c13="" automation-id="discover-market-results-row" _nghost-ddm-c16="" class="ng-star-inserted"><!----><!----><et-instrument-trading-row _ngcontent-ddm-c16="" automation-id="watchlist-grid-instruments-list" _nghost-ddm-c21="" class="ng-star-inserted"><div _ngcontent-ddm-c21="" class="row-wrap desktop-row"><et-card-avatar _ngcontent-ddm-c21="" automation-id="watchlist-item-list-wrapp-instrument" class="instrument-cell" _nghost-ddm-c22=""><a _ngcontent-ddm-c22="" class="card-avatar-wrap" href="/markets/dash"><div _ngcontent-ddm-c22="" class="avatar-img-wrap"><img _ngcontent-ddm-c22="" automation-id="trade-item-avatar" class="avatar-img" src="https://etoro-cdn.etorostatic.com/market-avatars/100004/150x150.png" alt="Dash"><!----></div><div _ngcontent-ddm-c22="" automation-id="trade-item-info" class="avatar-info"><div _ngcontent-ddm-c22="" automation-id="trade-item-name" class="symbol">DASH</div><div _ngcontent-ddm-c22="" automation-id="trade-item-full-name" class="name">Dash</div></div></a></et-card-avatar><!----><div _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-wrapp-rate-change" class="instrument-change instrument-cell negative ng-star-inserted"><!----><!----><div _ngcontent-ddm-c21="" class="change-items"><b _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-rate-change-amount" class="instrument-pro">-0.56</b><div _ngcontent-ddm-c21="" class="instrument-num"><span _ngcontent-ddm-c21="" class="arrow-sign"></span>(-0.79%)</div></div></div><!----><div _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-chart" class="instrument-cell chart-wrap ng-star-inserted"><et-instrument-sparklines _ngcontent-ddm-c21="" _nghost-ddm-c24=""><div _ngcontent-ddm-c24="" class="sparklines"><et-canvas-chart _ngcontent-ddm-c24="" class="fedeOut fadeIn" _nghost-ddm-c29=""><!----><canvas _ngcontent-ddm-c29="" class="ng-star-inserted" width="346" height="70" style="width: 173px; height: 35px;"></canvas><!----></et-canvas-chart></div></et-instrument-sparklines><a _ngcontent-ddm-c21="" class="watchlist-card-external-link icon-external-link"></a></div><et-buy-sell-buttons _ngcontent-ddm-c21="" automation-id="watchlist-item-grid-instrument-buy-sell-container" class="instrument-cell buy-sell-buttons" _nghost-ddm-c25=""><et-buy-sell-button _ngcontent-ddm-c25="" _nghost-ddm-c28=""><div _ngcontent-ddm-c28="" class="prices short-label positive-change" automation-id="buy-sell-button-container-sell"><div _ngcontent-ddm-c28="" class="trade-button-title">S</div><div _ngcontent-ddm-c28="" automation-id="buy-sell-button-rate-value" class="price">70.<span class="after-decimal">21</span></div></div></et-buy-sell-button><div _ngcontent-ddm-c25="" class="space-gap"></div><et-buy-sell-button _ngcontent-ddm-c25="" _nghost-ddm-c28=""><div _ngcontent-ddm-c28="" class="prices short-label positive-change" automation-id="buy-sell-button-container-buy"><div _ngcontent-ddm-c28="" class="trade-button-title">B</div><div _ngcontent-ddm-c28="" automation-id="buy-sell-button-rate-value" class="price">72.<span class="after-decimal">28</span></div></div></et-buy-sell-button></et-buy-sell-buttons><et-fifty-two-weeks _ngcontent-ddm-c21="" class="instrument-cell" _nghost-ddm-c26=""><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range" class="fiftytwo-weeks-progress-bar"><div _ngcontent-ddm-c26="" class="price-range"><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range-min" class="low">32.00</div><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range-max" class="high">141.96</div></div><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-bar" class="bar-wrap"><span _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-indicator" class="measure-arrow" style="left: 35.5338%;"></span></div></div></et-fifty-two-weeks><et-instrument-sentiment _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-sentiment" class="instrument-cell" _nghost-ddm-c27=""><!----><div _ngcontent-ddm-c27="" automation-id="instrument-sentiment-bar" class="bar-full-wrap ng-star-inserted"><div _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-data-title" class="bar-info"><h5 _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-percentage" class="percentage">100%</h5><h6 _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-action" class="status">Buying</h6></div><div _ngcontent-ddm-c27="" class="bar-wrap"><span _ngcontent-ddm-c27="" automation-id="list-instrument-sentiment-bar" class="progress-bar-buy-part" style="width: 100%; visibility: visible;"></span><span _ngcontent-ddm-c27="" automation-id="list-instrument-sentiment-bar" class="progress-bar-sell-part" style="width: 0%; visibility: visible;"></span></div></div><!----><!----></et-instrument-sentiment><et-trade-item-card-action _ngcontent-ddm-c16="" _nghost-ddm-c17=""><!----><et-trade-item-card-action _ngcontent-ddm-c13="" _nghost-ddm-c17="" class="ng-star-inserted"><et-watchlist-quick-edit _ngcontent-ddm-c13="" _nghost-ddm-c18=""><et-select _ngcontent-ddm-c18="" class="no-arrow ng-tns-c2-2404" _nghost-ddm-c2=""><div _ngcontent-ddm-c2="" class="ng-tns-c2-2404"><et-select-header _ngcontent-ddm-c18="" automation-id="watchlists-quick-edit-btn-add" class="watchlists-edit" _nghost-ddm-c3=""><div _ngcontent-ddm-c3="" class="header-text"></div><i _ngcontent-ddm-c3="" class="arrow-down"></i></et-select-header><!----></div><!----><!----><!----></et-select></et-watchlist-quick-edit></et-trade-item-card-action><!----></et-trade-item-card-action></div></et-instrument-trading-row><!----></et-instrument-row><et-instrument-row _ngcontent-ddm-c13="" automation-id="discover-market-results-row" _nghost-ddm-c16="" class="ng-star-inserted"><!----><!----><et-instrument-trading-row _ngcontent-ddm-c16="" automation-id="watchlist-grid-instruments-list" _nghost-ddm-c21="" class="ng-star-inserted"><div _ngcontent-ddm-c21="" class="row-wrap desktop-row"><et-card-avatar _ngcontent-ddm-c21="" automation-id="watchlist-item-list-wrapp-instrument" class="instrument-cell" _nghost-ddm-c22=""><a _ngcontent-ddm-c22="" class="card-avatar-wrap" href="/markets/ltc"><div _ngcontent-ddm-c22="" class="avatar-img-wrap"><img _ngcontent-ddm-c22="" automation-id="trade-item-avatar" class="avatar-img" src="https://etoro-cdn.etorostatic.com/market-avatars/100005/150x150.png" alt="Litecoin"><!----></div><div _ngcontent-ddm-c22="" automation-id="trade-item-info" class="avatar-info"><div _ngcontent-ddm-c22="" automation-id="trade-item-name" class="symbol">LTC</div><div _ngcontent-ddm-c22="" automation-id="trade-item-full-name" class="name">Litecoin</div></div></a></et-card-avatar><!----><div _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-wrapp-rate-change" class="instrument-change instrument-cell negative ng-star-inserted"><!----><!----><div _ngcontent-ddm-c21="" class="change-items"><b _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-rate-change-amount" class="instrument-pro">-0.07</b><div _ngcontent-ddm-c21="" class="instrument-num"><span _ngcontent-ddm-c21="" class="arrow-sign"></span>(-0.16%)</div></div></div><!----><div _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-chart" class="instrument-cell chart-wrap ng-star-inserted"><et-instrument-sparklines _ngcontent-ddm-c21="" _nghost-ddm-c24=""><div _ngcontent-ddm-c24="" class="sparklines"><et-canvas-chart _ngcontent-ddm-c24="" class="fedeOut fadeIn" _nghost-ddm-c29=""><!----><canvas _ngcontent-ddm-c29="" class="ng-star-inserted" width="346" height="70" style="width: 173px; height: 35px;"></canvas><!----></et-canvas-chart></div></et-instrument-sparklines><a _ngcontent-ddm-c21="" class="watchlist-card-external-link icon-external-link"></a></div><et-buy-sell-buttons _ngcontent-ddm-c21="" automation-id="watchlist-item-grid-instrument-buy-sell-container" class="instrument-cell buy-sell-buttons" _nghost-ddm-c25=""><et-buy-sell-button _ngcontent-ddm-c25="" _nghost-ddm-c28=""><div _ngcontent-ddm-c28="" class="prices short-label positive-change" automation-id="buy-sell-button-container-sell"><div _ngcontent-ddm-c28="" class="trade-button-title">S</div><div _ngcontent-ddm-c28="" automation-id="buy-sell-button-rate-value" class="price">43.<span class="after-decimal">73</span></div></div></et-buy-sell-button><div _ngcontent-ddm-c25="" class="space-gap"></div><et-buy-sell-button _ngcontent-ddm-c25="" _nghost-ddm-c28=""><div _ngcontent-ddm-c28="" class="prices short-label positive-change" automation-id="buy-sell-button-container-buy"><div _ngcontent-ddm-c28="" class="trade-button-title">B</div><div _ngcontent-ddm-c28="" automation-id="buy-sell-button-rate-value" class="price">44.<span class="after-decimal">57</span></div></div></et-buy-sell-button></et-buy-sell-buttons><et-fifty-two-weeks _ngcontent-ddm-c21="" class="instrument-cell" _nghost-ddm-c26=""><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range" class="fiftytwo-weeks-progress-bar"><div _ngcontent-ddm-c26="" class="price-range"><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range-min" class="low">23.81</div><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range-max" class="high">106.10</div></div><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-bar" class="bar-wrap"><span _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-indicator" class="measure-arrow" style="left: 24.544%;"></span></div></div></et-fifty-two-weeks><et-instrument-sentiment _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-sentiment" class="instrument-cell" _nghost-ddm-c27=""><!----><div _ngcontent-ddm-c27="" automation-id="instrument-sentiment-bar" class="bar-full-wrap ng-star-inserted"><div _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-data-title" class="bar-info"><h5 _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-percentage" class="percentage">100%</h5><h6 _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-action" class="status">Buying</h6></div><div _ngcontent-ddm-c27="" class="bar-wrap"><span _ngcontent-ddm-c27="" automation-id="list-instrument-sentiment-bar" class="progress-bar-buy-part" style="width: 100%; visibility: visible;"></span><span _ngcontent-ddm-c27="" automation-id="list-instrument-sentiment-bar" class="progress-bar-sell-part" style="width: 0%; visibility: visible;"></span></div></div><!----><!----></et-instrument-sentiment><et-trade-item-card-action _ngcontent-ddm-c16="" _nghost-ddm-c17=""><!----><et-trade-item-card-action _ngcontent-ddm-c13="" _nghost-ddm-c17="" class="ng-star-inserted"><et-watchlist-quick-edit _ngcontent-ddm-c13="" _nghost-ddm-c18=""><et-select _ngcontent-ddm-c18="" class="no-arrow ng-tns-c2-2405" _nghost-ddm-c2=""><div _ngcontent-ddm-c2="" class="ng-tns-c2-2405"><et-select-header _ngcontent-ddm-c18="" automation-id="watchlists-quick-edit-btn-add" class="watchlists-edit" _nghost-ddm-c3=""><div _ngcontent-ddm-c3="" class="header-text"></div><i _ngcontent-ddm-c3="" class="arrow-down"></i></et-select-header><!----></div><!----><!----><!----></et-select></et-watchlist-quick-edit></et-trade-item-card-action><!----></et-trade-item-card-action></div></et-instrument-trading-row><!----></et-instrument-row><et-instrument-row _ngcontent-ddm-c13="" automation-id="discover-market-results-row" _nghost-ddm-c16="" class="ng-star-inserted"><!----><!----><et-instrument-trading-row _ngcontent-ddm-c16="" automation-id="watchlist-grid-instruments-list" _nghost-ddm-c21="" class="ng-star-inserted"><div _ngcontent-ddm-c21="" class="row-wrap desktop-row"><et-card-avatar _ngcontent-ddm-c21="" automation-id="watchlist-item-list-wrapp-instrument" class="instrument-cell" _nghost-ddm-c22=""><a _ngcontent-ddm-c22="" class="card-avatar-wrap" href="/markets/etc"><div _ngcontent-ddm-c22="" class="avatar-img-wrap"><img _ngcontent-ddm-c22="" automation-id="trade-item-avatar" class="avatar-img" src="https://etoro-cdn.etorostatic.com/market-avatars/100007/150x150.png" alt="Ethereum Classic"><!----></div><div _ngcontent-ddm-c22="" automation-id="trade-item-info" class="avatar-info"><div _ngcontent-ddm-c22="" automation-id="trade-item-name" class="symbol">ETC</div><div _ngcontent-ddm-c22="" automation-id="trade-item-full-name" class="name">Ethereum Classic</div></div></a></et-card-avatar><!----><div _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-wrapp-rate-change" class="instrument-change instrument-cell negative ng-star-inserted"><!----><!----><div _ngcontent-ddm-c21="" class="change-items"><b _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-rate-change-amount" class="instrument-pro">-0.2529</b><div _ngcontent-ddm-c21="" class="instrument-num"><span _ngcontent-ddm-c21="" class="arrow-sign"></span>(-3.85%)</div></div></div><!----><div _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-chart" class="instrument-cell chart-wrap ng-star-inserted"><et-instrument-sparklines _ngcontent-ddm-c21="" _nghost-ddm-c24=""><div _ngcontent-ddm-c24="" class="sparklines"><et-canvas-chart _ngcontent-ddm-c24="" class="fedeOut fadeIn" _nghost-ddm-c29=""><!----><canvas _ngcontent-ddm-c29="" class="ng-star-inserted" width="346" height="70" style="width: 173px; height: 35px;"></canvas><!----></et-canvas-chart></div></et-instrument-sparklines><a _ngcontent-ddm-c21="" class="watchlist-card-external-link icon-external-link"></a></div><et-buy-sell-buttons _ngcontent-ddm-c21="" automation-id="watchlist-item-grid-instrument-buy-sell-container" class="instrument-cell buy-sell-buttons" _nghost-ddm-c25=""><et-buy-sell-button _ngcontent-ddm-c25="" _nghost-ddm-c28=""><div _ngcontent-ddm-c28="" class="prices short-label negative-change" automation-id="buy-sell-button-container-sell"><div _ngcontent-ddm-c28="" class="trade-button-title">S</div><div _ngcontent-ddm-c28="" automation-id="buy-sell-button-rate-value" class="price">6.<span class="after-decimal">3132</span></div></div></et-buy-sell-button><div _ngcontent-ddm-c25="" class="space-gap"></div><et-buy-sell-button _ngcontent-ddm-c25="" _nghost-ddm-c28=""><div _ngcontent-ddm-c28="" class="prices short-label negative-change" automation-id="buy-sell-button-container-buy"><div _ngcontent-ddm-c28="" class="trade-button-title">B</div><div _ngcontent-ddm-c28="" automation-id="buy-sell-button-rate-value" class="price">6.<span class="after-decimal">4339</span></div></div></et-buy-sell-button></et-buy-sell-buttons><et-fifty-two-weeks _ngcontent-ddm-c21="" class="instrument-cell" _nghost-ddm-c26=""><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range" class="fiftytwo-weeks-progress-bar"><div _ngcontent-ddm-c26="" class="price-range"><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range-min" class="low">3.17</div><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range-max" class="high">13.08</div></div><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-bar" class="bar-wrap"><span _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-indicator" class="measure-arrow" style="left: 31.9645%;"></span></div></div></et-fifty-two-weeks><et-instrument-sentiment _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-sentiment" class="instrument-cell" _nghost-ddm-c27=""><!----><div _ngcontent-ddm-c27="" automation-id="instrument-sentiment-bar" class="bar-full-wrap ng-star-inserted"><div _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-data-title" class="bar-info"><h5 _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-percentage" class="percentage">100%</h5><h6 _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-action" class="status">Buying</h6></div><div _ngcontent-ddm-c27="" class="bar-wrap"><span _ngcontent-ddm-c27="" automation-id="list-instrument-sentiment-bar" class="progress-bar-buy-part" style="width: 100%; visibility: visible;"></span><span _ngcontent-ddm-c27="" automation-id="list-instrument-sentiment-bar" class="progress-bar-sell-part" style="width: 0%; visibility: visible;"></span></div></div><!----><!----></et-instrument-sentiment><et-trade-item-card-action _ngcontent-ddm-c16="" _nghost-ddm-c17=""><!----><et-trade-item-card-action _ngcontent-ddm-c13="" _nghost-ddm-c17="" class="ng-star-inserted"><et-watchlist-quick-edit _ngcontent-ddm-c13="" _nghost-ddm-c18=""><et-select _ngcontent-ddm-c18="" class="no-arrow ng-tns-c2-2406" _nghost-ddm-c2=""><div _ngcontent-ddm-c2="" class="ng-tns-c2-2406"><et-select-header _ngcontent-ddm-c18="" automation-id="watchlists-quick-edit-btn-add" class="watchlists-edit" _nghost-ddm-c3=""><div _ngcontent-ddm-c3="" class="header-text"></div><i _ngcontent-ddm-c3="" class="arrow-down"></i></et-select-header><!----></div><!----><!----><!----></et-select></et-watchlist-quick-edit></et-trade-item-card-action><!----></et-trade-item-card-action></div></et-instrument-trading-row><!----></et-instrument-row><et-instrument-row _ngcontent-ddm-c13="" automation-id="discover-market-results-row" _nghost-ddm-c16="" class="ng-star-inserted"><!----><!----><et-instrument-trading-row _ngcontent-ddm-c16="" automation-id="watchlist-grid-instruments-list" _nghost-ddm-c21="" class="ng-star-inserted"><div _ngcontent-ddm-c21="" class="row-wrap desktop-row"><et-card-avatar _ngcontent-ddm-c21="" automation-id="watchlist-item-list-wrapp-instrument" class="instrument-cell" _nghost-ddm-c22=""><a _ngcontent-ddm-c22="" class="card-avatar-wrap" href="/markets/ada"><div _ngcontent-ddm-c22="" class="avatar-img-wrap"><img _ngcontent-ddm-c22="" automation-id="trade-item-avatar" class="avatar-img" src="https://etoro-cdn.etorostatic.com/market-avatars/100017/150x150.png" alt="Cardano"><!----></div><div _ngcontent-ddm-c22="" automation-id="trade-item-info" class="avatar-info"><div _ngcontent-ddm-c22="" automation-id="trade-item-name" class="symbol">ADA</div><div _ngcontent-ddm-c22="" automation-id="trade-item-full-name" class="name">Cardano</div></div></a></et-card-avatar><!----><div _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-wrapp-rate-change" class="instrument-change instrument-cell negative ng-star-inserted"><!----><!----><div _ngcontent-ddm-c21="" class="change-items"><b _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-rate-change-amount" class="instrument-pro">-0.0070</b><div _ngcontent-ddm-c21="" class="instrument-num"><span _ngcontent-ddm-c21="" class="arrow-sign"></span>(-5.74%)</div></div></div><!----><div _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-chart" class="instrument-cell chart-wrap ng-star-inserted"><et-instrument-sparklines _ngcontent-ddm-c21="" _nghost-ddm-c24=""><div _ngcontent-ddm-c24="" class="sparklines"><et-canvas-chart _ngcontent-ddm-c24="" class="fedeOut fadeIn" _nghost-ddm-c29=""><!----><canvas _ngcontent-ddm-c29="" class="ng-star-inserted" width="346" height="70" style="width: 173px; height: 35px;"></canvas><!----></et-canvas-chart></div></et-instrument-sparklines><a _ngcontent-ddm-c21="" class="watchlist-card-external-link icon-external-link"></a></div><et-buy-sell-buttons _ngcontent-ddm-c21="" automation-id="watchlist-item-grid-instrument-buy-sell-container" class="instrument-cell buy-sell-buttons" _nghost-ddm-c25=""><et-buy-sell-button _ngcontent-ddm-c25="" _nghost-ddm-c28=""><div _ngcontent-ddm-c28="" class="prices short-label positive-change" automation-id="buy-sell-button-container-sell"><div _ngcontent-ddm-c28="" class="trade-button-title">S</div><div _ngcontent-ddm-c28="" automation-id="buy-sell-button-rate-value" class="price">0.<span class="after-decimal">1149</span></div></div></et-buy-sell-button><div _ngcontent-ddm-c25="" class="space-gap"></div><et-buy-sell-button _ngcontent-ddm-c25="" _nghost-ddm-c28=""><div _ngcontent-ddm-c28="" class="prices short-label positive-change" automation-id="buy-sell-button-container-buy"><div _ngcontent-ddm-c28="" class="trade-button-title">B</div><div _ngcontent-ddm-c28="" automation-id="buy-sell-button-rate-value" class="price">0.<span class="after-decimal">1190</span></div></div></et-buy-sell-button></et-buy-sell-buttons><et-fifty-two-weeks _ngcontent-ddm-c21="" class="instrument-cell" _nghost-ddm-c26=""><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range" class="fiftytwo-weeks-progress-bar"><div _ngcontent-ddm-c26="" class="price-range"><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range-min" class="low">0.02</div><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range-max" class="high">0.14</div></div><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-bar" class="bar-wrap"><span _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-indicator" class="measure-arrow" style="left: 81.5156%;"></span></div></div></et-fifty-two-weeks><et-instrument-sentiment _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-sentiment" class="instrument-cell" _nghost-ddm-c27=""><!----><div _ngcontent-ddm-c27="" automation-id="instrument-sentiment-bar" class="bar-full-wrap ng-star-inserted"><div _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-data-title" class="bar-info"><h5 _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-percentage" class="percentage">99%</h5><h6 _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-action" class="status">Buying</h6></div><div _ngcontent-ddm-c27="" class="bar-wrap"><span _ngcontent-ddm-c27="" automation-id="list-instrument-sentiment-bar" class="progress-bar-buy-part" style="width: 99%; visibility: visible;"></span><span _ngcontent-ddm-c27="" automation-id="list-instrument-sentiment-bar" class="progress-bar-sell-part" style="width: 1%; visibility: visible;"></span></div></div><!----><!----></et-instrument-sentiment><et-trade-item-card-action _ngcontent-ddm-c16="" _nghost-ddm-c17=""><!----><et-trade-item-card-action _ngcontent-ddm-c13="" _nghost-ddm-c17="" class="ng-star-inserted"><et-watchlist-quick-edit _ngcontent-ddm-c13="" _nghost-ddm-c18=""><et-select _ngcontent-ddm-c18="" class="no-arrow ng-tns-c2-2407" _nghost-ddm-c2=""><div _ngcontent-ddm-c2="" class="ng-tns-c2-2407"><et-select-header _ngcontent-ddm-c18="" automation-id="watchlists-quick-edit-btn-add" class="watchlists-edit" _nghost-ddm-c3=""><div _ngcontent-ddm-c3="" class="header-text"></div><i _ngcontent-ddm-c3="" class="arrow-down"></i></et-select-header><!----></div><!----><!----><!----></et-select></et-watchlist-quick-edit></et-trade-item-card-action><!----></et-trade-item-card-action></div></et-instrument-trading-row><!----></et-instrument-row><et-instrument-row _ngcontent-ddm-c13="" automation-id="discover-market-results-row" _nghost-ddm-c16="" class="ng-star-inserted"><!----><!----><et-instrument-trading-row _ngcontent-ddm-c16="" automation-id="watchlist-grid-instruments-list" _nghost-ddm-c21="" class="ng-star-inserted"><div _ngcontent-ddm-c21="" class="row-wrap desktop-row"><et-card-avatar _ngcontent-ddm-c21="" automation-id="watchlist-item-list-wrapp-instrument" class="instrument-cell" _nghost-ddm-c22=""><a _ngcontent-ddm-c22="" class="card-avatar-wrap" href="/markets/miota"><div _ngcontent-ddm-c22="" class="avatar-img-wrap"><img _ngcontent-ddm-c22="" automation-id="trade-item-avatar" class="avatar-img" src="https://etoro-cdn.etorostatic.com/market-avatars/100018/150x150.png" alt="IOTA"><!----></div><div _ngcontent-ddm-c22="" automation-id="trade-item-info" class="avatar-info"><div _ngcontent-ddm-c22="" automation-id="trade-item-name" class="symbol">MIOTA</div><div _ngcontent-ddm-c22="" automation-id="trade-item-full-name" class="name">IOTA</div></div></a></et-card-avatar><!----><div _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-wrapp-rate-change" class="instrument-change instrument-cell negative ng-star-inserted"><!----><!----><div _ngcontent-ddm-c21="" class="change-items"><b _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-rate-change-amount" class="instrument-pro">-0.0045</b><div _ngcontent-ddm-c21="" class="instrument-num"><span _ngcontent-ddm-c21="" class="arrow-sign"></span>(-1.81%)</div></div></div><!----><div _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-chart" class="instrument-cell chart-wrap ng-star-inserted"><et-instrument-sparklines _ngcontent-ddm-c21="" _nghost-ddm-c24=""><div _ngcontent-ddm-c24="" class="sparklines"><et-canvas-chart _ngcontent-ddm-c24="" class="fedeOut fadeIn" _nghost-ddm-c29=""><!----><canvas _ngcontent-ddm-c29="" class="ng-star-inserted" width="346" height="70" style="width: 173px; height: 35px;"></canvas><!----></et-canvas-chart></div></et-instrument-sparklines><a _ngcontent-ddm-c21="" class="watchlist-card-external-link icon-external-link"></a></div><et-buy-sell-buttons _ngcontent-ddm-c21="" automation-id="watchlist-item-grid-instrument-buy-sell-container" class="instrument-cell buy-sell-buttons" _nghost-ddm-c25=""><et-buy-sell-button _ngcontent-ddm-c25="" _nghost-ddm-c28=""><div _ngcontent-ddm-c28="" class="prices short-label negative-change" automation-id="buy-sell-button-container-sell"><div _ngcontent-ddm-c28="" class="trade-button-title">S</div><div _ngcontent-ddm-c28="" automation-id="buy-sell-button-rate-value" class="price">0.<span class="after-decimal">2446</span></div></div></et-buy-sell-button><div _ngcontent-ddm-c25="" class="space-gap"></div><et-buy-sell-button _ngcontent-ddm-c25="" _nghost-ddm-c28=""><div _ngcontent-ddm-c28="" class="prices short-label negative-change" automation-id="buy-sell-button-container-buy"><div _ngcontent-ddm-c28="" class="trade-button-title">B</div><div _ngcontent-ddm-c28="" automation-id="buy-sell-button-rate-value" class="price">0.<span class="after-decimal">2548</span></div></div></et-buy-sell-button></et-buy-sell-buttons><et-fifty-two-weeks _ngcontent-ddm-c21="" class="instrument-cell" _nghost-ddm-c26=""><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range" class="fiftytwo-weeks-progress-bar"><div _ngcontent-ddm-c26="" class="price-range"><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range-min" class="low">0.06</div><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range-max" class="high">0.37</div></div><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-bar" class="bar-wrap"><span _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-indicator" class="measure-arrow" style="left: 60.6695%;"></span></div></div></et-fifty-two-weeks><et-instrument-sentiment _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-sentiment" class="instrument-cell" _nghost-ddm-c27=""><!----><div _ngcontent-ddm-c27="" automation-id="instrument-sentiment-bar" class="bar-full-wrap ng-star-inserted"><div _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-data-title" class="bar-info"><h5 _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-percentage" class="percentage">99%</h5><h6 _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-action" class="status">Buying</h6></div><div _ngcontent-ddm-c27="" class="bar-wrap"><span _ngcontent-ddm-c27="" automation-id="list-instrument-sentiment-bar" class="progress-bar-buy-part" style="width: 99%; visibility: visible;"></span><span _ngcontent-ddm-c27="" automation-id="list-instrument-sentiment-bar" class="progress-bar-sell-part" style="width: 1%; visibility: visible;"></span></div></div><!----><!----></et-instrument-sentiment><et-trade-item-card-action _ngcontent-ddm-c16="" _nghost-ddm-c17=""><!----><et-trade-item-card-action _ngcontent-ddm-c13="" _nghost-ddm-c17="" class="ng-star-inserted"><et-watchlist-quick-edit _ngcontent-ddm-c13="" _nghost-ddm-c18=""><et-select _ngcontent-ddm-c18="" class="no-arrow ng-tns-c2-2408" _nghost-ddm-c2=""><div _ngcontent-ddm-c2="" class="ng-tns-c2-2408"><et-select-header _ngcontent-ddm-c18="" automation-id="watchlists-quick-edit-btn-add" class="watchlists-edit" _nghost-ddm-c3=""><div _ngcontent-ddm-c3="" class="header-text"></div><i _ngcontent-ddm-c3="" class="arrow-down"></i></et-select-header><!----></div><!----><!----><!----></et-select></et-watchlist-quick-edit></et-trade-item-card-action><!----></et-trade-item-card-action></div></et-instrument-trading-row><!----></et-instrument-row><et-instrument-row _ngcontent-ddm-c13="" automation-id="discover-market-results-row" _nghost-ddm-c16="" class="ng-star-inserted"><!----><!----><et-instrument-trading-row _ngcontent-ddm-c16="" automation-id="watchlist-grid-instruments-list" _nghost-ddm-c21="" class="ng-star-inserted"><div _ngcontent-ddm-c21="" class="row-wrap desktop-row"><et-card-avatar _ngcontent-ddm-c21="" automation-id="watchlist-item-list-wrapp-instrument" class="instrument-cell" _nghost-ddm-c22=""><a _ngcontent-ddm-c22="" class="card-avatar-wrap" href="/markets/xlm"><div _ngcontent-ddm-c22="" class="avatar-img-wrap"><img _ngcontent-ddm-c22="" automation-id="trade-item-avatar" class="avatar-img" src="https://etoro-cdn.etorostatic.com/market-avatars/100020/150x150.png" alt="Stellar"><!----></div><div _ngcontent-ddm-c22="" automation-id="trade-item-info" class="avatar-info"><div _ngcontent-ddm-c22="" automation-id="trade-item-name" class="symbol">XLM</div><div _ngcontent-ddm-c22="" automation-id="trade-item-full-name" class="name">Stellar</div></div></a></et-card-avatar><!----><div _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-wrapp-rate-change" class="instrument-change instrument-cell negative ng-star-inserted"><!----><!----><div _ngcontent-ddm-c21="" class="change-items"><b _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-rate-change-amount" class="instrument-pro">-0.0046</b><div _ngcontent-ddm-c21="" class="instrument-num"><span _ngcontent-ddm-c21="" class="arrow-sign"></span>(-5.05%)</div></div></div><!----><div _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-chart" class="instrument-cell chart-wrap ng-star-inserted"><et-instrument-sparklines _ngcontent-ddm-c21="" _nghost-ddm-c24=""><div _ngcontent-ddm-c24="" class="sparklines"><et-canvas-chart _ngcontent-ddm-c24="" class="fedeOut fadeIn" _nghost-ddm-c29=""><!----><canvas _ngcontent-ddm-c29="" class="ng-star-inserted" width="346" height="70" style="width: 173px; height: 35px;"></canvas><!----></et-canvas-chart></div></et-instrument-sparklines><a _ngcontent-ddm-c21="" class="watchlist-card-external-link icon-external-link"></a></div><et-buy-sell-buttons _ngcontent-ddm-c21="" automation-id="watchlist-item-grid-instrument-buy-sell-container" class="instrument-cell buy-sell-buttons" _nghost-ddm-c25=""><et-buy-sell-button _ngcontent-ddm-c25="" _nghost-ddm-c28=""><div _ngcontent-ddm-c28="" class="prices short-label negative-change" automation-id="buy-sell-button-container-sell"><div _ngcontent-ddm-c28="" class="trade-button-title">S</div><div _ngcontent-ddm-c28="" automation-id="buy-sell-button-rate-value" class="price">0.<span class="after-decimal">0865</span></div></div></et-buy-sell-button><div _ngcontent-ddm-c25="" class="space-gap"></div><et-buy-sell-button _ngcontent-ddm-c25="" _nghost-ddm-c28=""><div _ngcontent-ddm-c28="" class="prices short-label negative-change" automation-id="buy-sell-button-container-buy"><div _ngcontent-ddm-c28="" class="trade-button-title">B</div><div _ngcontent-ddm-c28="" automation-id="buy-sell-button-rate-value" class="price">0.<span class="after-decimal">0886</span></div></div></et-buy-sell-button></et-buy-sell-buttons><et-fifty-two-weeks _ngcontent-ddm-c21="" class="instrument-cell" _nghost-ddm-c26=""><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range" class="fiftytwo-weeks-progress-bar"><div _ngcontent-ddm-c26="" class="price-range"><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range-min" class="low">0.03</div><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range-max" class="high">0.10</div></div><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-bar" class="bar-wrap"><span _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-indicator" class="measure-arrow" style="left: 83.844%;"></span></div></div></et-fifty-two-weeks><et-instrument-sentiment _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-sentiment" class="instrument-cell" _nghost-ddm-c27=""><!----><div _ngcontent-ddm-c27="" automation-id="instrument-sentiment-bar" class="bar-full-wrap ng-star-inserted"><div _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-data-title" class="bar-info"><h5 _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-percentage" class="percentage">99%</h5><h6 _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-action" class="status">Buying</h6></div><div _ngcontent-ddm-c27="" class="bar-wrap"><span _ngcontent-ddm-c27="" automation-id="list-instrument-sentiment-bar" class="progress-bar-buy-part" style="width: 99%; visibility: visible;"></span><span _ngcontent-ddm-c27="" automation-id="list-instrument-sentiment-bar" class="progress-bar-sell-part" style="width: 1%; visibility: visible;"></span></div></div><!----><!----></et-instrument-sentiment><et-trade-item-card-action _ngcontent-ddm-c16="" _nghost-ddm-c17=""><!----><et-trade-item-card-action _ngcontent-ddm-c13="" _nghost-ddm-c17="" class="ng-star-inserted"><et-watchlist-quick-edit _ngcontent-ddm-c13="" _nghost-ddm-c18=""><et-select _ngcontent-ddm-c18="" class="no-arrow ng-tns-c2-2409" _nghost-ddm-c2=""><div _ngcontent-ddm-c2="" class="ng-tns-c2-2409"><et-select-header _ngcontent-ddm-c18="" automation-id="watchlists-quick-edit-btn-add" class="watchlists-edit" _nghost-ddm-c3=""><div _ngcontent-ddm-c3="" class="header-text"></div><i _ngcontent-ddm-c3="" class="arrow-down"></i></et-select-header><!----></div><!----><!----><!----></et-select></et-watchlist-quick-edit></et-trade-item-card-action><!----></et-trade-item-card-action></div></et-instrument-trading-row><!----></et-instrument-row><et-instrument-row _ngcontent-ddm-c13="" automation-id="discover-market-results-row" _nghost-ddm-c16="" class="ng-star-inserted"><!----><!----><et-instrument-trading-row _ngcontent-ddm-c16="" automation-id="watchlist-grid-instruments-list" _nghost-ddm-c21="" class="ng-star-inserted"><div _ngcontent-ddm-c21="" class="row-wrap desktop-row"><et-card-avatar _ngcontent-ddm-c21="" automation-id="watchlist-item-list-wrapp-instrument" class="instrument-cell" _nghost-ddm-c22=""><a _ngcontent-ddm-c22="" class="card-avatar-wrap" href="/markets/eos"><div _ngcontent-ddm-c22="" class="avatar-img-wrap"><img _ngcontent-ddm-c22="" automation-id="trade-item-avatar" class="avatar-img" src="https://etoro-cdn.etorostatic.com/market-avatars/100022/150x150.png" alt="EOS"><!----></div><div _ngcontent-ddm-c22="" automation-id="trade-item-info" class="avatar-info"><div _ngcontent-ddm-c22="" automation-id="trade-item-name" class="symbol">EOS</div><div _ngcontent-ddm-c22="" automation-id="trade-item-full-name" class="name">EOS</div></div></a></et-card-avatar><!----><div _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-wrapp-rate-change" class="instrument-change instrument-cell negative ng-star-inserted"><!----><!----><div _ngcontent-ddm-c21="" class="change-items"><b _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-rate-change-amount" class="instrument-pro">-0.02</b><div _ngcontent-ddm-c21="" class="instrument-num"><span _ngcontent-ddm-c21="" class="arrow-sign"></span>(-0.77%)</div></div></div><!----><div _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-chart" class="instrument-cell chart-wrap ng-star-inserted"><et-instrument-sparklines _ngcontent-ddm-c21="" _nghost-ddm-c24=""><div _ngcontent-ddm-c24="" class="sparklines"><et-canvas-chart _ngcontent-ddm-c24="" class="fedeOut fadeIn" _nghost-ddm-c29=""><!----><canvas _ngcontent-ddm-c29="" class="ng-star-inserted" width="346" height="70" style="width: 173px; height: 35px;"></canvas><!----></et-canvas-chart></div></et-instrument-sparklines><a _ngcontent-ddm-c21="" class="watchlist-card-external-link icon-external-link"></a></div><et-buy-sell-buttons _ngcontent-ddm-c21="" automation-id="watchlist-item-grid-instrument-buy-sell-container" class="instrument-cell buy-sell-buttons" _nghost-ddm-c25=""><et-buy-sell-button _ngcontent-ddm-c25="" _nghost-ddm-c28=""><div _ngcontent-ddm-c28="" class="prices short-label" automation-id="buy-sell-button-container-sell"><div _ngcontent-ddm-c28="" class="trade-button-title">S</div><div _ngcontent-ddm-c28="" automation-id="buy-sell-button-rate-value" class="price">2.<span class="after-decimal">57</span></div></div></et-buy-sell-button><div _ngcontent-ddm-c25="" class="space-gap"></div><et-buy-sell-button _ngcontent-ddm-c25="" _nghost-ddm-c28=""><div _ngcontent-ddm-c28="" class="prices short-label" automation-id="buy-sell-button-container-buy"><div _ngcontent-ddm-c28="" class="trade-button-title">B</div><div _ngcontent-ddm-c28="" automation-id="buy-sell-button-rate-value" class="price">2.<span class="after-decimal">65</span></div></div></et-buy-sell-button></et-buy-sell-buttons><et-fifty-two-weeks _ngcontent-ddm-c21="" class="instrument-cell" _nghost-ddm-c26=""><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range" class="fiftytwo-weeks-progress-bar"><div _ngcontent-ddm-c26="" class="price-range"><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range-min" class="low">1.35</div><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range-max" class="high">5.41</div></div><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-bar" class="bar-wrap"><span _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-indicator" class="measure-arrow" style="left: 30.899%;"></span></div></div></et-fifty-two-weeks><et-instrument-sentiment _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-sentiment" class="instrument-cell" _nghost-ddm-c27=""><!----><div _ngcontent-ddm-c27="" automation-id="instrument-sentiment-bar" class="bar-full-wrap ng-star-inserted"><div _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-data-title" class="bar-info"><h5 _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-percentage" class="percentage">100%</h5><h6 _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-action" class="status">Buying</h6></div><div _ngcontent-ddm-c27="" class="bar-wrap"><span _ngcontent-ddm-c27="" automation-id="list-instrument-sentiment-bar" class="progress-bar-buy-part" style="width: 100%; visibility: visible;"></span><span _ngcontent-ddm-c27="" automation-id="list-instrument-sentiment-bar" class="progress-bar-sell-part" style="width: 0%; visibility: visible;"></span></div></div><!----><!----></et-instrument-sentiment><et-trade-item-card-action _ngcontent-ddm-c16="" _nghost-ddm-c17=""><!----><et-trade-item-card-action _ngcontent-ddm-c13="" _nghost-ddm-c17="" class="ng-star-inserted"><et-watchlist-quick-edit _ngcontent-ddm-c13="" _nghost-ddm-c18=""><et-select _ngcontent-ddm-c18="" class="no-arrow ng-tns-c2-2410" _nghost-ddm-c2=""><div _ngcontent-ddm-c2="" class="ng-tns-c2-2410"><et-select-header _ngcontent-ddm-c18="" automation-id="watchlists-quick-edit-btn-add" class="watchlists-edit" _nghost-ddm-c3=""><div _ngcontent-ddm-c3="" class="header-text"></div><i _ngcontent-ddm-c3="" class="arrow-down"></i></et-select-header><!----></div><!----><!----><!----></et-select></et-watchlist-quick-edit></et-trade-item-card-action><!----></et-trade-item-card-action></div></et-instrument-trading-row><!----></et-instrument-row><et-instrument-row _ngcontent-ddm-c13="" automation-id="discover-market-results-row" _nghost-ddm-c16="" class="ng-star-inserted"><!----><!----><et-instrument-trading-row _ngcontent-ddm-c16="" automation-id="watchlist-grid-instruments-list" _nghost-ddm-c21="" class="ng-star-inserted"><div _ngcontent-ddm-c21="" class="row-wrap desktop-row"><et-card-avatar _ngcontent-ddm-c21="" automation-id="watchlist-item-list-wrapp-instrument" class="instrument-cell" _nghost-ddm-c22=""><a _ngcontent-ddm-c22="" class="card-avatar-wrap" href="/markets/neo"><div _ngcontent-ddm-c22="" class="avatar-img-wrap"><img _ngcontent-ddm-c22="" automation-id="trade-item-avatar" class="avatar-img" src="https://etoro-cdn.etorostatic.com/market-avatars/100023/150x150.png" alt="NEO"><!----></div><div _ngcontent-ddm-c22="" automation-id="trade-item-info" class="avatar-info"><div _ngcontent-ddm-c22="" automation-id="trade-item-name" class="symbol">NEO</div><div _ngcontent-ddm-c22="" automation-id="trade-item-full-name" class="name">NEO</div></div></a></et-card-avatar><!----><div _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-wrapp-rate-change" class="instrument-change instrument-cell negative ng-star-inserted"><!----><!----><div _ngcontent-ddm-c21="" class="change-items"><b _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-rate-change-amount" class="instrument-pro">-0.15</b><div _ngcontent-ddm-c21="" class="instrument-num"><span _ngcontent-ddm-c21="" class="arrow-sign"></span>(-1.40%)</div></div></div><!----><div _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-chart" class="instrument-cell chart-wrap ng-star-inserted"><et-instrument-sparklines _ngcontent-ddm-c21="" _nghost-ddm-c24=""><div _ngcontent-ddm-c24="" class="sparklines"><et-canvas-chart _ngcontent-ddm-c24="" class="fedeOut fadeIn" _nghost-ddm-c29=""><!----><canvas _ngcontent-ddm-c29="" class="ng-star-inserted" width="346" height="70" style="width: 173px; height: 35px;"></canvas><!----></et-canvas-chart></div></et-instrument-sparklines><a _ngcontent-ddm-c21="" class="watchlist-card-external-link icon-external-link"></a></div><et-buy-sell-buttons _ngcontent-ddm-c21="" automation-id="watchlist-item-grid-instrument-buy-sell-container" class="instrument-cell buy-sell-buttons" _nghost-ddm-c25=""><et-buy-sell-button _ngcontent-ddm-c25="" _nghost-ddm-c28=""><div _ngcontent-ddm-c28="" class="prices short-label positive-change" automation-id="buy-sell-button-container-sell"><div _ngcontent-ddm-c28="" class="trade-button-title">S</div><div _ngcontent-ddm-c28="" automation-id="buy-sell-button-rate-value" class="price">10.<span class="after-decimal">57</span></div></div></et-buy-sell-button><div _ngcontent-ddm-c25="" class="space-gap"></div><et-buy-sell-button _ngcontent-ddm-c25="" _nghost-ddm-c28=""><div _ngcontent-ddm-c28="" class="prices short-label positive-change" automation-id="buy-sell-button-container-buy"><div _ngcontent-ddm-c28="" class="trade-button-title">B</div><div _ngcontent-ddm-c28="" automation-id="buy-sell-button-rate-value" class="price">10.<span class="after-decimal">77</span></div></div></et-buy-sell-button></et-buy-sell-buttons><et-fifty-two-weeks _ngcontent-ddm-c21="" class="instrument-cell" _nghost-ddm-c26=""><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range" class="fiftytwo-weeks-progress-bar"><div _ngcontent-ddm-c26="" class="price-range"><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range-min" class="low">3.81</div><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range-max" class="high">16.60</div></div><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-bar" class="bar-wrap"><span _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-indicator" class="measure-arrow" style="left: 53.0746%;"></span></div></div></et-fifty-two-weeks><et-instrument-sentiment _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-sentiment" class="instrument-cell" _nghost-ddm-c27=""><!----><div _ngcontent-ddm-c27="" automation-id="instrument-sentiment-bar" class="bar-full-wrap ng-star-inserted"><div _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-data-title" class="bar-info"><h5 _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-percentage" class="percentage">100%</h5><h6 _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-action" class="status">Buying</h6></div><div _ngcontent-ddm-c27="" class="bar-wrap"><span _ngcontent-ddm-c27="" automation-id="list-instrument-sentiment-bar" class="progress-bar-buy-part" style="width: 100%; visibility: visible;"></span><span _ngcontent-ddm-c27="" automation-id="list-instrument-sentiment-bar" class="progress-bar-sell-part" style="width: 0%; visibility: visible;"></span></div></div><!----><!----></et-instrument-sentiment><et-trade-item-card-action _ngcontent-ddm-c16="" _nghost-ddm-c17=""><!----><et-trade-item-card-action _ngcontent-ddm-c13="" _nghost-ddm-c17="" class="ng-star-inserted"><et-watchlist-quick-edit _ngcontent-ddm-c13="" _nghost-ddm-c18=""><et-select _ngcontent-ddm-c18="" class="no-arrow ng-tns-c2-2411" _nghost-ddm-c2=""><div _ngcontent-ddm-c2="" class="ng-tns-c2-2411"><et-select-header _ngcontent-ddm-c18="" automation-id="watchlists-quick-edit-btn-add" class="watchlists-edit" _nghost-ddm-c3=""><div _ngcontent-ddm-c3="" class="header-text"></div><i _ngcontent-ddm-c3="" class="arrow-down"></i></et-select-header><!----></div><!----><!----><!----></et-select></et-watchlist-quick-edit></et-trade-item-card-action><!----></et-trade-item-card-action></div></et-instrument-trading-row><!----></et-instrument-row><et-instrument-row _ngcontent-ddm-c13="" automation-id="discover-market-results-row" _nghost-ddm-c16="" class="ng-star-inserted"><!----><!----><et-instrument-trading-row _ngcontent-ddm-c16="" automation-id="watchlist-grid-instruments-list" _nghost-ddm-c21="" class="ng-star-inserted"><div _ngcontent-ddm-c21="" class="row-wrap desktop-row"><et-card-avatar _ngcontent-ddm-c21="" automation-id="watchlist-item-list-wrapp-instrument" class="instrument-cell" _nghost-ddm-c22=""><a _ngcontent-ddm-c22="" class="card-avatar-wrap" href="/markets/trx"><div _ngcontent-ddm-c22="" class="avatar-img-wrap"><img _ngcontent-ddm-c22="" automation-id="trade-item-avatar" class="avatar-img" src="https://etoro-cdn.etorostatic.com/market-avatars/100026/150x150.png" alt="TRON"><!----></div><div _ngcontent-ddm-c22="" automation-id="trade-item-info" class="avatar-info"><div _ngcontent-ddm-c22="" automation-id="trade-item-name" class="symbol">TRX</div><div _ngcontent-ddm-c22="" automation-id="trade-item-full-name" class="name">TRON</div></div></a></et-card-avatar><!----><div _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-wrapp-rate-change" class="instrument-change instrument-cell negative ng-star-inserted"><!----><!----><div _ngcontent-ddm-c21="" class="change-items"><b _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-rate-change-amount" class="instrument-pro">-0.0003</b><div _ngcontent-ddm-c21="" class="instrument-num"><span _ngcontent-ddm-c21="" class="arrow-sign"></span>(-1.66%)</div></div></div><!----><div _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-chart" class="instrument-cell chart-wrap ng-star-inserted"><et-instrument-sparklines _ngcontent-ddm-c21="" _nghost-ddm-c24=""><div _ngcontent-ddm-c24="" class="sparklines"><et-canvas-chart _ngcontent-ddm-c24="" class="fedeOut fadeIn" _nghost-ddm-c29=""><!----><canvas _ngcontent-ddm-c29="" class="ng-star-inserted" width="346" height="70" style="width: 173px; height: 35px;"></canvas><!----></et-canvas-chart></div></et-instrument-sparklines><a _ngcontent-ddm-c21="" class="watchlist-card-external-link icon-external-link"></a></div><et-buy-sell-buttons _ngcontent-ddm-c21="" automation-id="watchlist-item-grid-instrument-buy-sell-container" class="instrument-cell buy-sell-buttons" _nghost-ddm-c25=""><et-buy-sell-button _ngcontent-ddm-c25="" _nghost-ddm-c28=""><div _ngcontent-ddm-c28="" class="prices short-label" automation-id="buy-sell-button-container-sell"><div _ngcontent-ddm-c28="" class="trade-button-title">S</div><div _ngcontent-ddm-c28="" automation-id="buy-sell-button-rate-value" class="price">0.<span class="after-decimal">0178</span></div></div></et-buy-sell-button><div _ngcontent-ddm-c25="" class="space-gap"></div><et-buy-sell-button _ngcontent-ddm-c25="" _nghost-ddm-c28=""><div _ngcontent-ddm-c28="" class="prices short-label" automation-id="buy-sell-button-container-buy"><div _ngcontent-ddm-c28="" class="trade-button-title">B</div><div _ngcontent-ddm-c28="" automation-id="buy-sell-button-rate-value" class="price">0.<span class="after-decimal">0184</span></div></div></et-buy-sell-button></et-buy-sell-buttons><et-fifty-two-weeks _ngcontent-ddm-c21="" class="instrument-cell" _nghost-ddm-c26=""><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range" class="fiftytwo-weeks-progress-bar"><div _ngcontent-ddm-c26="" class="price-range"><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range-min" class="low">0.01</div><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range-max" class="high">0.03</div></div><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-bar" class="bar-wrap"><span _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-indicator" class="measure-arrow" style="left: 48.6176%;"></span></div></div></et-fifty-two-weeks><et-instrument-sentiment _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-sentiment" class="instrument-cell" _nghost-ddm-c27=""><!----><div _ngcontent-ddm-c27="" automation-id="instrument-sentiment-bar" class="bar-full-wrap ng-star-inserted"><div _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-data-title" class="bar-info"><h5 _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-percentage" class="percentage">99%</h5><h6 _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-action" class="status">Buying</h6></div><div _ngcontent-ddm-c27="" class="bar-wrap"><span _ngcontent-ddm-c27="" automation-id="list-instrument-sentiment-bar" class="progress-bar-buy-part" style="width: 99%; visibility: visible;"></span><span _ngcontent-ddm-c27="" automation-id="list-instrument-sentiment-bar" class="progress-bar-sell-part" style="width: 1%; visibility: visible;"></span></div></div><!----><!----></et-instrument-sentiment><et-trade-item-card-action _ngcontent-ddm-c16="" _nghost-ddm-c17=""><!----><et-trade-item-card-action _ngcontent-ddm-c13="" _nghost-ddm-c17="" class="ng-star-inserted"><et-watchlist-quick-edit _ngcontent-ddm-c13="" _nghost-ddm-c18=""><et-select _ngcontent-ddm-c18="" class="no-arrow ng-tns-c2-2412" _nghost-ddm-c2=""><div _ngcontent-ddm-c2="" class="ng-tns-c2-2412"><et-select-header _ngcontent-ddm-c18="" automation-id="watchlists-quick-edit-btn-add" class="watchlists-edit" _nghost-ddm-c3=""><div _ngcontent-ddm-c3="" class="header-text"></div><i _ngcontent-ddm-c3="" class="arrow-down"></i></et-select-header><!----></div><!----><!----><!----></et-select></et-watchlist-quick-edit></et-trade-item-card-action><!----></et-trade-item-card-action></div></et-instrument-trading-row><!----></et-instrument-row><et-instrument-row _ngcontent-ddm-c13="" automation-id="discover-market-results-row" _nghost-ddm-c16="" class="ng-star-inserted"><!----><!----><et-instrument-trading-row _ngcontent-ddm-c16="" automation-id="watchlist-grid-instruments-list" _nghost-ddm-c21="" class="ng-star-inserted"><div _ngcontent-ddm-c21="" class="row-wrap desktop-row"><et-card-avatar _ngcontent-ddm-c21="" automation-id="watchlist-item-list-wrapp-instrument" class="instrument-cell" _nghost-ddm-c22=""><a _ngcontent-ddm-c22="" class="card-avatar-wrap" href="/markets/zec"><div _ngcontent-ddm-c22="" class="avatar-img-wrap"><img _ngcontent-ddm-c22="" automation-id="trade-item-avatar" class="avatar-img" src="https://etoro-cdn.etorostatic.com/market-avatars/100028/150x150.png" alt="ZCASH"><!----></div><div _ngcontent-ddm-c22="" automation-id="trade-item-info" class="avatar-info"><div _ngcontent-ddm-c22="" automation-id="trade-item-name" class="symbol">ZEC</div><div _ngcontent-ddm-c22="" automation-id="trade-item-full-name" class="name">ZCASH</div></div></a></et-card-avatar><!----><div _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-wrapp-rate-change" class="instrument-change instrument-cell negative ng-star-inserted"><!----><!----><div _ngcontent-ddm-c21="" class="change-items"><b _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-rate-change-amount" class="instrument-pro">-0.84</b><div _ngcontent-ddm-c21="" class="instrument-num"><span _ngcontent-ddm-c21="" class="arrow-sign"></span>(-1.51%)</div></div></div><!----><div _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-chart" class="instrument-cell chart-wrap ng-star-inserted"><et-instrument-sparklines _ngcontent-ddm-c21="" _nghost-ddm-c24=""><div _ngcontent-ddm-c24="" class="sparklines"><et-canvas-chart _ngcontent-ddm-c24="" class="fedeOut fadeIn" _nghost-ddm-c29=""><!----><canvas _ngcontent-ddm-c29="" class="ng-star-inserted" width="346" height="70" style="width: 173px; height: 35px;"></canvas><!----></et-canvas-chart></div></et-instrument-sparklines><a _ngcontent-ddm-c21="" class="watchlist-card-external-link icon-external-link"></a></div><et-buy-sell-buttons _ngcontent-ddm-c21="" automation-id="watchlist-item-grid-instrument-buy-sell-container" class="instrument-cell buy-sell-buttons" _nghost-ddm-c25=""><et-buy-sell-button _ngcontent-ddm-c25="" _nghost-ddm-c28=""><div _ngcontent-ddm-c28="" class="prices short-label positive-change" automation-id="buy-sell-button-container-sell"><div _ngcontent-ddm-c28="" class="trade-button-title">S</div><div _ngcontent-ddm-c28="" automation-id="buy-sell-button-rate-value" class="price">54.<span class="after-decimal">94</span></div></div></et-buy-sell-button><div _ngcontent-ddm-c25="" class="space-gap"></div><et-buy-sell-button _ngcontent-ddm-c25="" _nghost-ddm-c28=""><div _ngcontent-ddm-c28="" class="prices short-label positive-change" automation-id="buy-sell-button-container-buy"><div _ngcontent-ddm-c28="" class="trade-button-title">B</div><div _ngcontent-ddm-c28="" automation-id="buy-sell-button-rate-value" class="price">56.<span class="after-decimal">87</span></div></div></et-buy-sell-button></et-buy-sell-buttons><et-fifty-two-weeks _ngcontent-ddm-c21="" class="instrument-cell" _nghost-ddm-c26=""><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range" class="fiftytwo-weeks-progress-bar"><div _ngcontent-ddm-c26="" class="price-range"><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range-min" class="low">17.82</div><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range-max" class="high">92.15</div></div><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-bar" class="bar-wrap"><span _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-indicator" class="measure-arrow" style="left: 50.5852%;"></span></div></div></et-fifty-two-weeks><et-instrument-sentiment _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-sentiment" class="instrument-cell" _nghost-ddm-c27=""><!----><div _ngcontent-ddm-c27="" automation-id="instrument-sentiment-bar" class="bar-full-wrap ng-star-inserted"><div _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-data-title" class="bar-info"><h5 _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-percentage" class="percentage">99%</h5><h6 _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-action" class="status">Buying</h6></div><div _ngcontent-ddm-c27="" class="bar-wrap"><span _ngcontent-ddm-c27="" automation-id="list-instrument-sentiment-bar" class="progress-bar-buy-part" style="width: 99%; visibility: visible;"></span><span _ngcontent-ddm-c27="" automation-id="list-instrument-sentiment-bar" class="progress-bar-sell-part" style="width: 1%; visibility: visible;"></span></div></div><!----><!----></et-instrument-sentiment><et-trade-item-card-action _ngcontent-ddm-c16="" _nghost-ddm-c17=""><!----><et-trade-item-card-action _ngcontent-ddm-c13="" _nghost-ddm-c17="" class="ng-star-inserted"><et-watchlist-quick-edit _ngcontent-ddm-c13="" _nghost-ddm-c18=""><et-select _ngcontent-ddm-c18="" class="no-arrow ng-tns-c2-2413" _nghost-ddm-c2=""><div _ngcontent-ddm-c2="" class="ng-tns-c2-2413"><et-select-header _ngcontent-ddm-c18="" automation-id="watchlists-quick-edit-btn-add" class="watchlists-edit" _nghost-ddm-c3=""><div _ngcontent-ddm-c3="" class="header-text"></div><i _ngcontent-ddm-c3="" class="arrow-down"></i></et-select-header><!----></div><!----><!----><!----></et-select></et-watchlist-quick-edit></et-trade-item-card-action><!----></et-trade-item-card-action></div></et-instrument-trading-row><!----></et-instrument-row><et-instrument-row _ngcontent-ddm-c13="" automation-id="discover-market-results-row" _nghost-ddm-c16="" class="ng-star-inserted"><!----><!----><et-instrument-trading-row _ngcontent-ddm-c16="" automation-id="watchlist-grid-instruments-list" _nghost-ddm-c21="" class="ng-star-inserted"><div _ngcontent-ddm-c21="" class="row-wrap desktop-row"><et-card-avatar _ngcontent-ddm-c21="" automation-id="watchlist-item-list-wrapp-instrument" class="instrument-cell" _nghost-ddm-c22=""><a _ngcontent-ddm-c22="" class="card-avatar-wrap" href="/markets/bnb"><div _ngcontent-ddm-c22="" class="avatar-img-wrap"><img _ngcontent-ddm-c22="" automation-id="trade-item-avatar" class="avatar-img" src="https://etoro-cdn.etorostatic.com/market-avatars/100030/150x150.png" alt="Binance Coin"><!----></div><div _ngcontent-ddm-c22="" automation-id="trade-item-info" class="avatar-info"><div _ngcontent-ddm-c22="" automation-id="trade-item-name" class="symbol">BNB</div><div _ngcontent-ddm-c22="" automation-id="trade-item-full-name" class="name">Binance Coin</div></div></a></et-card-avatar><!----><div _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-wrapp-rate-change" class="instrument-change instrument-cell positive ng-star-inserted"><!----><!----><div _ngcontent-ddm-c21="" class="change-items"><b _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-rate-change-amount" class="instrument-pro">0.28</b><div _ngcontent-ddm-c21="" class="instrument-num"><span _ngcontent-ddm-c21="" class="arrow-sign"></span>(1.68%)</div></div></div><!----><div _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-chart" class="instrument-cell chart-wrap ng-star-inserted"><et-instrument-sparklines _ngcontent-ddm-c21="" _nghost-ddm-c24=""><div _ngcontent-ddm-c24="" class="sparklines"><et-canvas-chart _ngcontent-ddm-c24="" class="fedeOut fadeIn" _nghost-ddm-c29=""><!----><canvas _ngcontent-ddm-c29="" class="ng-star-inserted" width="346" height="70" style="width: 173px; height: 35px;"></canvas><!----></et-canvas-chart></div></et-instrument-sparklines><a _ngcontent-ddm-c21="" class="watchlist-card-external-link icon-external-link"></a></div><et-buy-sell-buttons _ngcontent-ddm-c21="" automation-id="watchlist-item-grid-instrument-buy-sell-container" class="instrument-cell buy-sell-buttons" _nghost-ddm-c25=""><et-buy-sell-button _ngcontent-ddm-c25="" _nghost-ddm-c28=""><div _ngcontent-ddm-c28="" class="prices short-label positive-change" automation-id="buy-sell-button-container-sell"><div _ngcontent-ddm-c28="" class="trade-button-title">S</div><div _ngcontent-ddm-c28="" automation-id="buy-sell-button-rate-value" class="price">16.<span class="after-decimal">91</span></div></div></et-buy-sell-button><div _ngcontent-ddm-c25="" class="space-gap"></div><et-buy-sell-button _ngcontent-ddm-c25="" _nghost-ddm-c28=""><div _ngcontent-ddm-c28="" class="prices short-label positive-change" automation-id="buy-sell-button-container-buy"><div _ngcontent-ddm-c28="" class="trade-button-title">B</div><div _ngcontent-ddm-c28="" automation-id="buy-sell-button-rate-value" class="price">17.<span class="after-decimal">33</span></div></div></et-buy-sell-button></et-buy-sell-buttons><et-fifty-two-weeks _ngcontent-ddm-c21="" class="instrument-cell" _nghost-ddm-c26=""><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range" class="fiftytwo-weeks-progress-bar"><div _ngcontent-ddm-c26="" class="price-range"><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range-min" class="low">6.31</div><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range-max" class="high">32.09</div></div><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-bar" class="bar-wrap"><span _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-indicator" class="measure-arrow" style="left: 41.5865%;"></span></div></div></et-fifty-two-weeks><et-instrument-sentiment _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-sentiment" class="instrument-cell" _nghost-ddm-c27=""><!----><div _ngcontent-ddm-c27="" automation-id="instrument-sentiment-bar" class="bar-full-wrap ng-star-inserted"><div _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-data-title" class="bar-info"><h5 _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-percentage" class="percentage">99%</h5><h6 _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-action" class="status">Buying</h6></div><div _ngcontent-ddm-c27="" class="bar-wrap"><span _ngcontent-ddm-c27="" automation-id="list-instrument-sentiment-bar" class="progress-bar-buy-part" style="width: 99%; visibility: visible;"></span><span _ngcontent-ddm-c27="" automation-id="list-instrument-sentiment-bar" class="progress-bar-sell-part" style="width: 1%; visibility: visible;"></span></div></div><!----><!----></et-instrument-sentiment><et-trade-item-card-action _ngcontent-ddm-c16="" _nghost-ddm-c17=""><!----><et-trade-item-card-action _ngcontent-ddm-c13="" _nghost-ddm-c17="" class="ng-star-inserted"><et-watchlist-quick-edit _ngcontent-ddm-c13="" _nghost-ddm-c18=""><et-select _ngcontent-ddm-c18="" class="no-arrow ng-tns-c2-2414" _nghost-ddm-c2=""><div _ngcontent-ddm-c2="" class="ng-tns-c2-2414"><et-select-header _ngcontent-ddm-c18="" automation-id="watchlists-quick-edit-btn-add" class="watchlists-edit" _nghost-ddm-c3=""><div _ngcontent-ddm-c3="" class="header-text"></div><i _ngcontent-ddm-c3="" class="arrow-down"></i></et-select-header><!----></div><!----><!----><!----></et-select></et-watchlist-quick-edit></et-trade-item-card-action><!----></et-trade-item-card-action></div></et-instrument-trading-row><!----></et-instrument-row><et-instrument-row _ngcontent-ddm-c13="" automation-id="discover-market-results-row" _nghost-ddm-c16="" class="ng-star-inserted"><!----><!----><et-instrument-trading-row _ngcontent-ddm-c16="" automation-id="watchlist-grid-instruments-list" _nghost-ddm-c21="" class="ng-star-inserted"><div _ngcontent-ddm-c21="" class="row-wrap desktop-row"><et-card-avatar _ngcontent-ddm-c21="" automation-id="watchlist-item-list-wrapp-instrument" class="instrument-cell" _nghost-ddm-c22=""><a _ngcontent-ddm-c22="" class="card-avatar-wrap" href="/markets/xtz"><div _ngcontent-ddm-c22="" class="avatar-img-wrap"><img _ngcontent-ddm-c22="" automation-id="trade-item-avatar" class="avatar-img" src="https://etoro-cdn.etorostatic.com/market-avatars/100032/150x150.png" alt="Tezos"><!----></div><div _ngcontent-ddm-c22="" automation-id="trade-item-info" class="avatar-info"><div _ngcontent-ddm-c22="" automation-id="trade-item-name" class="symbol">XTZ</div><div _ngcontent-ddm-c22="" automation-id="trade-item-full-name" class="name">Tezos</div></div></a></et-card-avatar><!----><div _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-wrapp-rate-change" class="instrument-change instrument-cell ng-star-inserted positive"><!----><!----><div _ngcontent-ddm-c21="" class="change-items"><b _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-rate-change-amount" class="instrument-pro">0.0122</b><div _ngcontent-ddm-c21="" class="instrument-num"><span _ngcontent-ddm-c21="" class="arrow-sign"></span>(0.49%)</div></div></div><!----><div _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-chart" class="instrument-cell chart-wrap ng-star-inserted"><et-instrument-sparklines _ngcontent-ddm-c21="" _nghost-ddm-c24=""><div _ngcontent-ddm-c24="" class="sparklines"><et-canvas-chart _ngcontent-ddm-c24="" class="fedeOut fadeIn" _nghost-ddm-c29=""><!----><canvas _ngcontent-ddm-c29="" class="ng-star-inserted" width="346" height="70" style="width: 173px; height: 35px;"></canvas><!----></et-canvas-chart></div></et-instrument-sparklines><a _ngcontent-ddm-c21="" class="watchlist-card-external-link icon-external-link"></a></div><et-buy-sell-buttons _ngcontent-ddm-c21="" automation-id="watchlist-item-grid-instrument-buy-sell-container" class="instrument-cell buy-sell-buttons" _nghost-ddm-c25=""><et-buy-sell-button _ngcontent-ddm-c25="" _nghost-ddm-c28=""><div _ngcontent-ddm-c28="" class="prices short-label negative-change" automation-id="buy-sell-button-container-sell"><div _ngcontent-ddm-c28="" class="trade-button-title">S</div><div _ngcontent-ddm-c28="" automation-id="buy-sell-button-rate-value" class="price">2.<span class="after-decimal">5156</span></div></div></et-buy-sell-button><div _ngcontent-ddm-c25="" class="space-gap"></div><et-buy-sell-button _ngcontent-ddm-c25="" _nghost-ddm-c28=""><div _ngcontent-ddm-c28="" class="prices short-label positive-change" automation-id="buy-sell-button-container-buy"><div _ngcontent-ddm-c28="" class="trade-button-title">B</div><div _ngcontent-ddm-c28="" automation-id="buy-sell-button-rate-value" class="price">2.<span class="after-decimal">5484</span></div></div></et-buy-sell-button></et-buy-sell-buttons><et-fifty-two-weeks _ngcontent-ddm-c21="" class="instrument-cell" _nghost-ddm-c26=""><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range" class="fiftytwo-weeks-progress-bar"><div _ngcontent-ddm-c26="" class="price-range"><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range-min" class="low">0.73</div><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-range-max" class="high">3.90</div></div><div _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-bar" class="bar-wrap"><span _ngcontent-ddm-c26="" automation-id="fifty-two-weeks-indicator" class="measure-arrow" style="left: 55.4035%;"></span></div></div></et-fifty-two-weeks><et-instrument-sentiment _ngcontent-ddm-c21="" automation-id="watchlist-item-list-instrument-sentiment" class="instrument-cell" _nghost-ddm-c27=""><!----><div _ngcontent-ddm-c27="" automation-id="instrument-sentiment-bar" class="bar-full-wrap ng-star-inserted"><div _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-data-title" class="bar-info"><h5 _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-percentage" class="percentage">99%</h5><h6 _ngcontent-ddm-c27="" automation-id="watchlist-item-list-instrument-sentiment-action" class="status">Buying</h6></div><div _ngcontent-ddm-c27="" class="bar-wrap"><span _ngcontent-ddm-c27="" automation-id="list-instrument-sentiment-bar" class="progress-bar-buy-part" style="width: 99%; visibility: visible;"></span><span _ngcontent-ddm-c27="" automation-id="list-instrument-sentiment-bar" class="progress-bar-sell-part" style="width: 1%; visibility: visible;"></span></div></div><!----><!----></et-instrument-sentiment><et-trade-item-card-action _ngcontent-ddm-c16="" _nghost-ddm-c17=""><!----><et-trade-item-card-action _ngcontent-ddm-c13="" _nghost-ddm-c17="" class="ng-star-inserted"><et-watchlist-quick-edit _ngcontent-ddm-c13="" _nghost-ddm-c18=""><et-select _ngcontent-ddm-c18="" class="no-arrow ng-tns-c2-2415" _nghost-ddm-c2=""><div _ngcontent-ddm-c2="" class="ng-tns-c2-2415"><et-select-header _ngcontent-ddm-c18="" automation-id="watchlists-quick-edit-btn-add" class="watchlists-edit" _nghost-ddm-c3=""><div _ngcontent-ddm-c3="" class="header-text"></div><i _ngcontent-ddm-c3="" class="arrow-down"></i></et-select-header><!----></div><!----><!----><!----></et-select></et-watchlist-quick-edit></et-trade-item-card-action><!----></et-trade-item-card-action></div></et-instrument-trading-row><!----></et-instrument-row><!----><!----></div>'''

# %%
txt = entry
finds = []
k = 'market-avatars/'
k = '"symbol">'
x = txt.find(k)

# %%
x = txt.find(k)
while x > 0:
    start = txt[x+len(k):]
    n = start[:start.find('<')]
    finds.append(n)
    txt = txt[x+len(n):]
    x = txt.find(k)
print(len(finds))
print(finds)
# Out:
# 16
# ['BTC', 'ETHEREUM', 'BCH', 'XRP', 'DASH', 'LTC', 'ETC', 'ADA', 'MIOTA', 'XLM', 'EOS', 'NEO', 'TRX', 'ZEC', 'BNB', 'XTZ']

# %%
class Stock(tdict):
    def __init__(self, name):
        self.name = name
        self.ticker = yf.Ticker(name)
        self.hist = {}
        self.info = None
    
    def get_history(self, months=12):
        if months not in self.hist:
            self.hist[months] = self.ticker.history(start=get_startdate(months/12))
        return self.hist[months]
    
    def get_closes(self, months=12, p=True):
        data = self.get_history(months).to_numpy()[:,3]
        if p:
            data /= data[0]
            data -= 1
            data *= 100
        return data
    
#     def get_recommendations(self):
#         return self.ticker.recommendations
    
    def get_info(self):
        if self.info is None:
            self.info = self.ticker.info
        return self.info

# %%
frankfurt = ['1COV.DE', 'ADJ.DE', 'ADS.DE', 'AFX.DE', 'AIXA.DE', 'ALV.DE', 'AOX.DE', 'ARL.DE', 'AT1.DE', 'B4B.DE', 'BAS.DE', 'BAYN.DE', 'BC8.DE', 'BEI.DE', 'BMW.DE', 'BNR.DE', 'BOSS.DE', 'CBK.DE', 'CEC.DE', 'CON.DE', 'COP.DE', 'DAI.DE', 'DB1.DE', 'DEQ.DE', 'DHER.DE', 'DLG.DE', 'DPW.DE', 'DRI.DE', 'DTE.DE', 'DUE.DE', 'DWNI.DE', 'DWS.DE', 'EOAN.DE', 'EVD.DE', 'EVK.DE', 'EVT.DE', 'FIE.DE', 'FME.DE', 'FNTN.DE', 'FRA.DE', 'FRE.DE', 'G1A.DE', 'G24.DE', 'GBF.DE', 'GLJ.DE', 'GXI.DE', 'GYC.DE', 'HDD.DE', 'HEI.DE', 'HEN3.DE', 'HLAG.DE', 'HLE.DE', 'HNR1.DE', 'HOT.DE', 'IFX.DE', 'JEN.DE', 'JUN3.DE', 'KBX.DE', 'KGX.DE', 'KRN.DE', 'LEG.DE', 'LEO.DE', 'LHA.DE', 'LXS.DE', 'MOR.DE', 'MTX.DE', 'MUV2.DE', 'NDA.DE', 'NDX1.DE', 'NEM.DE', 'O2D.DE', 'OSR.DE', 'PAH3.DE', 'PAT.DE', 'PSM.DE', 'PUM.DE', 'QGEN.DE', 'RAA.DE', 'RHM.DE', 'RKET.DE', 'RRTL.DE', 'RWE.DE', 'S92.DE', 'SAP.DE', 'SAX.DE', 'SDF.DE', 'SGL.DE', 'SHA.DE', 'SHL.DE', 'SIE.DE', 'SIX2.DE', 'SOW.DE', 'SRT.DE', 'SY1.DE', 'SZG.DE', 'SZU.DE', 'TEG.DE', 'TKA.DE', 'TLG.DE', 'TLX.DE', 'TMV.DE', 'UN01.DE', 'UTDI.DE', 'VNA.DE', 'VOE.DE', 'VOW3.DE', 'WAF.DE', 'WCH.DE', 'WDI.DE', 'ZAL.DE', 'ZIL2.DE']

technology = ['00241.HK', '00268.HK', '00981.HK', '0992.HK', '3888.HK', '888.L', 'ADBE', 'ADI', 'ADP', 'ADSK', 'AIXA.DE', 'AKAM', 'AMAT', 'AMD', 'AMS.MC', 'AMS.ZU', 'AMX', 'ANSS', 'APH', 'ASMI.NV', 'ASML', 'ASML.NV', 'ATHM.CH', 'ATO.PA', 'ATVI', 'AVGO', 'AVID', 'AVST.L', 'AYX', 'AZPN', 'BB', 'BBY.L', 'BC8.DE', 'BESI.NV', 'BIDU', 'BITA', 'BOX', 'BR', 'BT.L', 'CAP.PA', 'CAPC.L', 'CDNS', 'CDW', 'CERN', 'CEVA', 'CHKP', 'CHL', 'CKN.L', 'CLDR', 'COMM', 'COP.DE', 'COUP', 'CREE', 'CRM', 'CRUS', 'CRWD', 'CSCO', 'CSOD', 'CTL', 'CTSH', 'CTXS', 'CUB', 'CYBR', 'DBX', 'DDD', 'DELL', 'DIA.MI', 'DLG.DE', 'DMGT.L', 'DOCU', 'DOYU', 'DSY.PA', 'DTE.DE', 'DUE.DE', 'DXC', 'EA', 'ERIC-A.ST', 'EVBG', 'FB', 'FEYE', 'FIS', 'FSJ.L', 'FSLR', 'FTCH', 'FTNT', 'GDDY', 'GIB', 'GLW', 'GOOG', 'GRMN', 'GSAT', 'GWRE', 'HEXA-B.ST', 'HPE', 'HPQ', 'HUBS', 'IBM', 'IDR.MC', 'IFX.DE', 'INFY', 'ING.PA', 'INTC', 'INTU', 'INTU.L', 'IPGP', 'IPHI', 'JBL', 'JD.CH', 'JEN.DE', 'JKHY', 'JNPR', 'KBX.DE', 'KLAC', 'KPN.NV', 'KRN.DE', 'LDOS', 'LITE', 'LOGN.ZU', 'LPSN', 'LRCX', 'MCHP', 'MDB', 'MOMO', 'MRVL', 'MSCI', 'MSFT', 'MSI', 'MTRO.L', 'MTX.DE', 'MU', 'MX', 'MXIM', 'MXL', 'NATI', 'NCR', 'NEM.DE', 'NET', 'NEWR', 'NLOK', 'NLSN', 'NOK', 'NOW', 'NTAP', 'NTES.CH', 'NTNX', 'NUAN', 'NVDA', 'NXPI', 'ON', 'ORCL', 'PANW', 'PARRO.PA', 'PAYC', 'PAYX', 'PI', 'PINS', 'PIRC.MI', 'POWI', 'PS', 'PTC', 'PYPL', 'QCOM', 'QRVO', 'QTT', 'RENN', 'SAIL', 'SANM', 'SAP.DE', 'SBAC', 'SCMN.ZU', 'SCT.L', 'SE', 'SHOP', 'SIM.CO', 'SLAB', 'SMAR', 'SMSN.L', 'SMTC', 'SNAP', 'SNPS', 'SOP.PA', 'SOW.DE', 'SPLK', 'SPOT', 'SSNC', 'ST', 'STM.MI', 'STM.PA', 'STX', 'SWKS', 'SYNA', 'T', 'TEAM', 'TEF', 'TEMN.ZU', 'TEO', 'TEP.PA', 'TME', 'TMV.DE', 'TOM2.NV', 'TRIP', 'TRMB', 'TTWO', 'TWLO', 'TWTR', 'TXN', 'UBI.PA', 'UI', 'VEEV', 'VIAV', 'VMW', 'VOD', 'VOPA.NV', 'VRSN', 'VZ', 'WAF.DE', 'WB', 'WDAY', 'WDC', 'WIX', 'WLN.PA', 'WUBA', 'XLNX', 'XRX', 'YELP', 'YNDX', 'ZBRA', 'ZEN', 'ZM', 'ZNGA']
conglomerates = ['BYD', 'CC', 'CCU', 'FAST', 'IEP', 'MMM', 'POST', 'SBH', 'SPB', 'WEN']
basic_materials = ['00857.HK', '0386.HK', '03993.HK', '0883.HK', '0968.HK', '1088.HK', '1171.HK', '1898.HK', '1COV.DE', '2883.HK', '2899.HK', '3800.HK', 'AA', 'AAL.L', 'ACX.MC', 'AKE.PA', 'AKSO.OL', 'AKZA.NV', 'AMG.NV', 'ANTO.L', 'APA', 'APD', 'ASH', 'AXTA', 'BAS.DE', 'BHGE', 'BHP', 'BHP.L', 'BNR.DE', 'BOL.ST', 'BP.L', 'BWY.L', 'CE', 'CF', 'CLMT', 'CLN.ZU', 'CLR', 'CMC', 'COG', 'COP', 'CRDA.L', 'CVI.N', 'CVX', 'CXO', 'DAE.ZU', 'DD', 'DK', 'DLN.L', 'DNO.OL', 'DNOW', 'DRX.L', 'DSM.NV', 'DVN', 'EMN', 'EMSN.ZU', 'ENB', 'ENC.MC', 'ENI.MI', 'EOG', 'EPD', 'ET', 'EVK.DE', 'FANG', 'FCX', 'FMC', 'FP.PA', 'FRES.L', 'FTI', 'GGB', 'GIVN.ZU', 'GLEN.L', 'GOLD.BARRICK', 'GXI.DE', 'HAL', 'HES', 'HFC', 'HUN', 'HVPE.L', 'IFF', 'IGG.L', 'IMCD.NV', 'INT', 'IP', 'JMAT.L', 'JSNTST', 'KMI', 'KRO', 'LHN.ZU', 'LIN', 'LKODL.RU', 'LMP.L', 'LNG', 'LUPE.ST', 'LXS.DE', 'LYB', 'MNODL.RU', 'MOS', 'MRO', 'MTS.MC', 'MUR', 'NBL', 'NDA.DE', 'NDX1.DE', 'NEM', 'NESTE.HE', 'NOV', 'NUE', 'OCDO.L', 'OCI.NV', 'OERL.ZU', 'OLN', 'OUT1V.HE', 'OVV', 'OXY', 'PAGP', 'PBF', 'PBR', 'PBR.A', 'PE', 'PFC.L', 'PGS.OL', 'PPG', 'PRS.OL', 'PXD', 'RAA.DE', 'RCP.L', 'RDS.A', 'RDS.B', 'RHIM.L', 'RIG', 'RIO', 'RIO.L', 'ROSNL.RU', 'RPM', 'RS', 'RTN.L', 'RWI.L', 'SAGA.L', 'SAND.ST', 'SAOC', 'SCCO', 'SDF.DE', 'SGL.DE', 'SHW', 'SLB', 'SOLB.PA', 'SON', 'SRP.L', 'SSABAH.HE', 'STLD', 'SU', 'SUBC.OL', 'SUZ', 'SVS.L', 'SVSTL.RU', 'SWN', 'SXT', 'SY1.DE', 'SZG.DE', 'TALK.L', 'TEN.MI', 'TGS.OL', 'TKA.DE', 'TLW.L', 'TRGP', 'TX', 'UHR.ZU', 'UMI.BR', 'UPM.HE', 'VALE', 'VOE.DE', 'VOLV-A.ST', 'VWS.CO', 'WLK', 'WLL', 'X', 'XEC', 'XOM']
consumer_goods = ['00027.HK', '00175.HK', '00322.HK', '00880.HK', '01055.HK', '01093.HK', '01114.HK', '01128.HK', '01177.HK', '01211.HK', '01928.HK', '02020.HK', '02196.HK', '02269.HK', '02313.HK', '02319.HK', '0489.HK', '06862.HK', '0753.HK', '0941.HK', '1585.HK', '1833.HK', '1958.HK', '2238.HK', '2331.HK', '2333.HK', '2338.HK', '288.HK', '6055.HK', 'AAK.ST', 'AAN', 'AAPL', 'ABC', 'ABEV', 'ABF.L', 'ABI.BR', 'ABMD', 'ACAD', 'AD.NV', 'ADM', 'ADS.DE', 'ADYEN.NV', 'AEO', 'AF.PA', 'AGL.MI', 'AGRO', 'ALC.ZU', 'ALGN', 'ALM.MC', 'ALXN', 'AMBUB.CO', 'AMED', 'AML.L', 'ANDE', 'APPS.MC', 'APRN', 'APTV', 'ARCH', 'ARGX.BR', 'ARWR', 'ATGE', 'ATNX', 'ATST.L', 'AVV.L', 'AVY', 'AXGN', 'AZN', 'AZUL', 'B4B.DE', 'BAKK.L', 'BARN.ZU', 'BATS.L', 'BB.PA', 'BBOX.L', 'BC', 'BCO', 'BEAT', 'BEI.DE', 'BERY', 'BFAM', 'BG', 'BGEO.L', 'BHVN', 'BILI', 'BIM.PA', 'BIO', 'BJ', 'BLL', 'BLUE', 'BMRN', 'BMW.DE', 'BN.PA', 'BOSS.DE', 'BOY.L', 'BPMC', 'BRFS', 'BRKR', 'BTI', 'BUD', 'BVI.PA', 'BVIC.L', 'BWA', 'BYG.L', 'CA.PA', 'CAG', 'CAH', 'CBRL', 'CCEP', 'CCH.L', 'CCK', 'CCL', 'CCL.L', 'CDI.PA', 'CEC.DE', 'CGC', 'CHD', 'CHE', 'CHGG', 'CHRS', 'CHWY', 'CL', 'CLX', 'CMCSA', 'CNE.L', 'CNK', 'CNMD', 'CNX', 'CO.PA', 'CODX', 'COLR.BR', 'CON.DE', 'COST', 'COTY', 'CPB', 'CPE', 'CPR.MI', 'CPRI', 'CPRT', 'CRI', 'CRL', 'CROX', 'CSGP', 'CTEC.L', 'CTLT', 'CVNA', 'CWK.L', 'DAI.DE', 'DAN', 'DBV.PA', 'DECK', 'DENN', 'DGE.L', 'DIA.MC', 'DIM.PA', 'DLPH', 'DLTR', 'DNKN', 'DOM.ST', 'DPH.L', 'DPLM.L', 'DTY.L', 'DUFN.ZU', 'DXCM', 'ECL', 'EDEN.PA', 'EDU', 'EEFT', 'EFX', 'EHC', 'EKTAB.ST', 'EL', 'ELAN', 'ELIOR.PA', 'ELIS.PA', 'ENR', 'EO.PA', 'EPC', 'EQN.L', 'ERF.PA', 'ERI', 'ERM.L', 'ESNT.L', 'ESSITYB.ST', 'EVD.DE', 'EW', 'EXAS', 'EXEL', 'F', 'FBHS', 'FCA.MI', 'FDJ.PA', 'FEVR.L', 'FIE.DE', 'FIT', 'FIVE', 'FL', 'FLO', 'FNAC.PA', 'FOSL', 'FR.PA', 'FRPT', 'FXPO.L', 'GALE.ZU', 'GAW.L', 'GEF', 'GEST.MC', 'GETIB.ST', 'GFRD.L', 'GFTU.L', 'GH', 'GIS', 'GKOS', 'GLPG.NV', 'GM', 'GN.CO', 'GNFT.PA', 'GOG.L', 'GOL', 'GOSS', 'GPK', 'GPN', 'GPRO', 'GRG.L', 'GSS.L', 'GT', 'GVNV.NV', 'HAE', 'HAS', 'HBI', 'HEIA.NV', 'HEIO.NV', 'HEN3.DE', 'HFD.L', 'HGV', 'HIK.L', 'HILS.L', 'HLE.DE', 'HLF', 'HM-B.ST', 'HMC', 'HMI', 'HOG', 'HOLX', 'HQY', 'HRC', 'HRL', 'HSX.L', 'HSY', 'HTHT', 'IBP', 'ICA.ST', 'ICP.L', 'IDXX', 'IMB.L', 'IMMU', 'INDV.L', 'INGN', 'INGR', 'INPP.L', 'INSP', 'IPN.PA', 'IPO.L', 'IRBT', 'IRTC', 'ISRG', 'IT', 'ITX.MC', 'JACK', 'JCI', 'JD.L', 'JMT.LSB', 'JOUT', 'JUP.L', 'JUVE.MI', 'K', 'KBH', 'KDP', 'KER.PA', 'KESKOB.HE', 'KHC', 'KINDSDB.ST', 'KMB', 'KO', 'KR', 'LAD', 'LEA', 'LEG', 'LEVI', 'LHX', 'LKQ', 'LONN.ZU', 'LOOMB.ST', 'LOW', 'LRE.L', 'LULU', 'LW', 'M', 'MANU', 'MASI', 'MAT', 'MC.PA', 'MCK', 'MCS.L', 'MD', 'MDC', 'MDC.L', 'MDLZ', 'MEL.MC', 'MGNTL.RU', 'MHK', 'MKC', 'MKTX', 'ML.PA', 'MNDI.L', 'MO', 'MONC.MI', 'MOWI.OL', 'MRNA', 'MRTX', 'MS.MI', 'MSLH.L', 'MTDR', 'MTH', 'MTN', 'MTO.L', 'MTOR', 'MYL', 'NBIX', 'NCLH', 'NESN.ZU', 'NEX.L', 'NIO', 'NIU', 'NKE', 'NSP', 'NTRA', 'NUVA', 'NVAX', 'NVCR', 'NVRO', 'NVS', 'NVTA', 'NWL', 'OAS', 'OI', 'OLLI', 'OR.PA', 'ORK.OL', 'ORNBV.HE', 'ORP.PA', 'OSB.L', 'OSK', 'OTB.L', 'PAG', 'PAG.L', 'PAH3.DE', 'PAY.L', 'PCAR', 'PDCE', 'PDD', 'PEN', 'PENN', 'PEP', 'PFGC', 'PG', 'PHIA.NV', 'PHM.MC', 'PII', 'PKG', 'PLAY', 'PLI.L', 'PLNT', 'PM', 'PNDORA.CO', 'PODD', 'POM.PA', 'POOL', 'PPC', 'PRAH', 'PSG.MC', 'PTEC.L', 'PUM.DE', 'PVH', 'PZC.L', 'PZZA', 'QEP', 'QRTEA', 'RACE', 'RAND.NV', 'RAT.L', 'RB.L', 'RBREW.CO', 'RCL', 'RCO.PA', 'RDSB.L', 'RDW.L', 'REDD.L', 'RETA', 'RFP', 'RGEN', 'RH', 'RHM.DE', 'RI.PA', 'RKET.DE', 'RL', 'RMD', 'RNK.L', 'RNO.PA', 'ROR.L', 'RST', 'RXL.PA', 'SAFM', 'SAGE', 'SALM.OL', 'SAM', 'SDRY.L', 'SEAS', 'SEE', 'SFER.MI', 'SFM', 'SHA.DE', 'SHAK', 'SHB.L', 'SJM', 'SK.PA', 'SLGN', 'SM', 'SNE', 'SOBI.ST', 'SOON.ZU', 'SPI.L', 'SPWR', 'SRPT', 'SSPG.L', 'STE', 'STMN.ZU', 'STNE', 'STZ', 'SW.PA', 'SWMA.ST', 'SXS.L', 'SYNT.L', 'SZU.DE', 'TACO', 'TAL', 'TAP', 'TATE.L', 'TBCG.L', 'TDOC', 'TECH', 'TECN.ZU', 'TEM.L', 'TEP.L', 'TEVA', 'TFX', 'TGT', 'THO', 'THS', 'TIFS.L', 'TKWY.NV', 'TM', 'TMHC', 'TNDM', 'TOD.MI', 'TPR', 'TPX', 'TRI.PA', 'TRU', 'TRXC', 'TSCO', 'TSLA', 'TSN', 'TTM', 'TXRH', 'TYRES.HE', 'UA', 'UCB.BR', 'UEIC', 'UG.PA', 'ULE.L', 'ULTA', 'ULVR.L', 'USFD', 'UTG.L', 'VAC', 'VC', 'VCYT', 'VFC', 'VIAC', 'VIFN.ZU', 'VIS.MC', 'VIV.PA', 'VOW3.DE', 'VSTO', 'WBA', 'WG.L', 'WGO', 'WHR', 'WIZZ.L', 'WMGI', 'WST', 'WTW', 'XI', 'XXII', 'YUMC', 'ZAL.DE', 'ZBH', 'ZIL2.DE']
financial = ['00011.HK', '00016.HK', '00017.HK', '00388.HK', '00966.HK', '01113.HK', '01336.HK', '02388.HK', '03333.HK', '03908.HK', '06060.HK', '0656.HK', '06837.HK', '0688.HK', '06881.HK', '06886.HK', '0939.HK', '0998.HK', '1109.HK', '1288.HK', '1299.HK', '1339.HK', '1359.HK', '1398.HK', '1628.HK', '1966.HK', '1988.HK', '2007.HK', '2318.HK', '2328.HK', '2601.HK', '2628.HK', '3328.HK', '3968.HK', '3988.HK', '3IN.L', '6030.HK', 'ABCB', 'ABN.NV', 'ACA.PA', 'ADJ.DE', 'ADM.L', 'ADS', 'AFG', 'AFL', 'AGN.NV', 'AGNC', 'AGR.L', 'AGS.BR', 'AIG', 'AIZ', 'AJG', 'ALL', 'ALLY', 'ALV.DE', 'AMG', 'AMP', 'AMT', 'AMTD', 'AMUN.PA', 'AOX.DE', 'ARE', 'ARGO', 'ARL.DE', 'ASCL.L', 'ASHM.L', 'ASRNL.NV', 'AT1.DE', 'ATH', 'AV.L', 'AVB', 'AXP', 'AZM.MI', 'BAC', 'BAER.ZU', 'BAG.L', 'BALDB.ST', 'BALN.ZU', 'BAMI.MI', 'BARC.L', 'BBD', 'BBVA.MC', 'BCP', 'BEN', 'BEZ.L', 'BGN.MI', 'BHF', 'BK', 'BKG.L', 'BKIA.MC', 'BKT.MC', 'BLK', 'BLND.L', 'BME.L', 'BME.MC', 'BNP.PA', 'BPE.MI', 'BPY', 'BRK.B', 'BRO', 'BSAC', 'BWNG.L', 'BX', 'BXP', 'BXS', 'C', 'CABK.MC', 'CACC', 'CADE', 'CARD.L', 'CAST.ST', 'CB', 'CBG.L', 'CBK.DE', 'CBRE', 'CCI', 'CEY.L', 'CFG', 'CFR.ZU', 'CINE.L', 'CINF', 'CIT', 'CMA', 'CMBN.ZU', 'CMCX', 'CME', 'CNO', 'CNP.PA', 'COA.L', 'COF', 'COL.MC', 'COLD', 'COV.PA', 'CS.PA', 'CSGN.ZU', 'CTY.L', 'CUBE', 'DB', 'DB1.DE', 'DEQ.DE', 'DFS', 'DGN.L', 'DLR', 'DNB.OL', 'DNLM.L', 'DOM.L', 'DRE', 'DWNI.DE', 'DWS.DE', 'ECM.L', 'EHTH', 'EMG.L', 'ENX.PA', 'EQIX', 'EQR', 'ESNT', 'ESS', 'ETFC', 'EV', 'EVR.L', 'EXO.MI', 'EXR', 'FABG.ST', 'FAF', 'FBK.MI', 'FBP', 'FCIT.L', 'FCPT', 'FDM.L', 'FITB', 'FLOW.NV', 'FNF', 'FRC', 'FRT', 'GASI.MI', 'GBLB.BR', 'GCAP', 'GFC.PA', 'GL', 'GLE.PA', 'GLJ.DE', 'GLPI', 'GNC.L', 'GNS.L', 'GNW', 'GPOR.L', 'GS', 'GYC.DE', 'HAS.L', 'HBAN', 'HELN.ZU', 'HICL.L', 'HIG', 'HL.L', 'HMSO.L', 'HOC.L', 'HSBA.L', 'HSBC', 'HST', 'HSV.L', 'HTA', 'HTG.L', 'IBKR', 'IBST.L', 'ICAD.PA', 'III', 'IIPR', 'INCH.L', 'INDU-A.ST', 'INFO', 'INGA.NV', 'INTER.NV', 'INTL', 'INVE-A.ST', 'INVEB.ST', 'INVP.L', 'IRM', 'ISBC', 'ISP.MI', 'ITUB', 'IWG.L', 'JDW.L', 'JEF', 'JEO.L', 'JFU', 'JLG.L', 'JLL', 'JPM', 'JUST.L', 'JYSK.CO', 'KBC.BR', 'KEY', 'KIE.L', 'KKR', 'KN.PA', 'L', 'LAMR', 'LAND.L', 'LAZ', 'LEG.DE', 'LGEN.L', 'LI.PA', 'LLOY.L', 'LM', 'LMND', 'LNC', 'LSE.L', 'LSI', 'LTC.US', 'LUND-B.ST', 'MA', 'MAA', 'MAB.L', 'MAIN', 'MAP.MC', 'MARS.L', 'MDBI.MI', 'MET', 'MF.PA', 'MGAM.L', 'MKL', 'MMC', 'MMI', 'MNKS.L', 'MONY.L', 'MPW', 'MRL.MC', 'MS', 'MTB', 'MUV2.DE', 'NAVI', 'NDA_SE.ST', 'NLY', 'NN.NV', 'NOG.L', 'NRR.L', 'NTRS', 'NXI.PA', 'O', 'OHI', 'ORI', 'ORSTED.CO', 'PAGE.L', 'PAGS', 'PARG.ZU', 'PAT.DE', 'PEB', 'PFG', 'PFG.L', 'PGHN.ZU', 'PGR', 'PHP.L', 'PIN.L', 'PLD', 'PLUS', 'PNC', 'PNN.L', 'PRU', 'PRU.L', 'PSA',  'PSH.L', 'PSPN.ZU', 'QD', 'QFIN', 'QIWI', 'QLT.L', 'QQ.L', 'RBS.L', 'RDI.L', 'RDN', 'RE', 'REG', 'REXR', 'RF', 'RF.PA', 'RGA', 'RJF', 'RLGY', 'RMAX', 'RNR', 'RSA.L', 'RSW.L', 'SAB.MC', 'SAFE.L', 'SAMPO.HE', 'SAN', 'SBERL.RU', 'SBNY', 'SBRA', 'SCHW', 'SCR.PA', 'SDP.L', 'SDR.L', 'SEB-A.ST', 'SEIC', 'SEQI.L', 'SGC.L', 'SGRO.L', 'SHB-A.ST', 'SHI.L', 'SIG.L', 'SIVB', 'SKT', 'SLA.L', 'SLHN.ZU', 'SMDS.L', 'SMT.L', 'SMWH.L', 'SNN.L', 'SOF.BR', 'SPG', 'SPSN.ZU', 'SREN.ZU', 'STAG', 'STAN.L', 'STJ.L', 'STOB.L', 'STOR', 'STT', 'SUI', 'SWED-A.ST', 'SYF', 'TEG.DE', 'TFC', 'THG', 'TLG.DE', 'TMPL.L', 'TREE', 'TRIG.L', 'TROW', 'TRV', 'TRYG.CO', 'UBI.MI', 'UBSG.ZU', 'UCG.MI', 'UDG.L', 'UDR', 'UNI.MC', 'UNM', 'US.MI', 'USB', 'V', 'VCT.L', 'VEC.L', 'VNA.DE', 'VNO', 'VOF.L', 'VSVS.L', 'VTR', 'VTY.L', 'WDI.DE', 'WDP.BR', 'WELL', 'WFC', 'WHA.NV', 'WKP.L', 'WPC', 'WU', 'Y', 'Z', 'ZION', 'ZURN.ZU']
healthcare = ['A', 'ABBV', 'ABT', 'ACB', 'AFX.DE', 'AI.PA', 'AMGN', 'AMP.MI', 'ANTM', 'APHA', 'AZN.L', 'BAX', 'BAYN.DE', 'BDX', 'BHC', 'BIIB', 'BMY', 'CARA', 'CBPO', 'CHR.CO', 'CI', 'CNC', 'COLO-B.CO', 'COO', 'CRBP', 'CRON', 'CVS', 'CYH', 'DEMANT.CO', 'DGX', 'DVA', 'EL.PA', 'EVT.DE', 'FME.DE', 'FRE.DE', 'GEBN.ZU', 'GILD', 'GMAB.CO', 'GRA', 'GRF.MC', 'GSK.L', 'GWPH', 'HCA', 'HUM', 'ICPT', 'ILMN', 'INCY', 'IONS', 'IQV', 'JAZZ', ]
industrial_goods = ['00066.HK', '00285.HK', '00788.HK', '02018.HK', '02382.HK', '0390.HK', '0914.HK', '1186.HK', '1618.HK', '1800.HK', '3323.HK', 'AA.L', 'AALB.NV', 'AAXN', 'ABBN.ZU', 'ACKB.BR', 'ACS.MC', 'ADP.PA', 'ADT', 'AENA.MC', 'AGCO', 'AIN', 'AKA.PA', 'AKERBP.OL', 'ALFA.ST', 'ALO.PA', 'ALRM', 'AM.PA', 'AMBA', 'AME', 'ARCAD.NV', 'ASSA-B.ST', 'ATCO-A.ST', 'ATE.PA', 'ATI', 'ATL.MI', 'AUTO.L', 'AVAV', 'AYI', 'BA', 'BLDP', 'BLDR', 'BOKA.NV', 'BRE.MI', 'BUCN.ZU', 'BZU.MI', 'CAT', 'CFX', 'CGCBV.HE', 'CLLS', 'CLNX.MC', 'CMI', 'CNHI.MI', 'CRST.L', 'CSIQ', 'CSP.L', 'CX', 'DAR', 'DCI', 'DE', 'DG.PA', 'DHI', 'DHR', 'DOV', 'DSV.CO', 'EDIT', 'ELM.L', 'EME', 'EMR', 'EN.PA', 'ENPH', 'EPIA.ST', 'EQNR.OL', 'ETN', 'FCC.MC', 'FER.MC', 'FERG.L', 'FGR.PA', 'FHZN.ZU', 'FLEX', 'FLIR', 'FLR', 'FLS', 'FLS.CO', 'FTV', 'G1A.DE', 'GBF.DE', 'GD', 'GE', 'GET.PA', 'GNRC', 'GNTX', 'GRI.L', 'HDD.DE', 'HEI', 'HEI.DE', 'HII', 'HLAG.DE', 'HLMA.L', 'HO.PA', 'HON', 'HOT.DE', 'HPOLB.ST', 'HSTG.L', 'HUBb', 'HUH1V.HE', 'HUSQB.ST', 'HWDN.L', 'IEX', 'IIVI', 'IMI.L', 'IP.MI', 'ISS.CO', 'ITW', 'JBT', 'JUN3.DE', 'KCR.HE', 'KEYS', 'KMT', 'KNEBV.HE', 'KNIN.ZU', 'KSU', 'KTOS', 'LAND.ZU', 'LDO.MI', 'LEN', 'LIGHT.NV', 'LII', 'LMT', 'LOG.MC', 'LPX', 'LR.PA', 'MAERBc.CO', 'MAS', 'MDU', 'METSB.HE', 'METSO.HE', 'MGGT.L', 'MLM', 'MRCY', 'MRO.L', 'MTD', 'MTW', 'MTZ', 'MWA', 'NAV', 'NEL.OL', 'NHY.OL', 'NIBEB.ST', 'NK.PA', 'NOC', 'NSC', 'NTDOY', 'NTLA', 'NVR', 'OC', 'ODFL', 'OHL.MC', 'OLED', 'OSR.DE', 'OTE1V.HE', 'PETS.L', 'PH', 'PHM', 'PHNX.L', 'PKI', 'PLP.L', 'PNL.NV', 'PNR', 'POLY.L', 'PRY.MI', 'PSN.L', 'PWR', 'ROCKB.CO', 'ROK', 'ROP', 'RR.L', 'RSG', 'RTX', 'RUN', 'S92.DE', 'SAABB.ST', 'SAF.PA', 'SCHP.ZU', 'SCYR.MC', 'SECU-B.ST', 'SEDG', 'SGO.PA', 'SGRE.MC', 'SGSN.ZU', 'SIE.DE', 'SIKA.ZU', 'SKA-B.ST', 'SKF-A.ST', 'SMIN.L', 'SNR.L', 'SPIE.PA', 'SPR', 'SRAIL.ZU', 'SRCL', 'SU.PA', 'SUM', 'SWBI', 'SWK', 'TCAP.L', 'TDG', 'TEL.US', 'TKTT.PA', 'TOL', 'TOM.OL', 'TPC', 'TPH', 'TPK.L', 'TRE.MC', 'TREL-B.ST', 'TREX', 'TT', 'TW.L', 'TWEKA.NV', 'TXT', 'UNP', 'UPS', 'VACN.ZU', 'VALMT.HE', 'VK.PA', 'VMC', 'VSLR', 'WAB', 'WCH.DE', 'WEIR.L', 'WM', 'WRK', 'WRT1V.HE', 'WY', 'XPO', 'XYL', 'YAR.OL', 'ZTO']
services = ['00001.HK', '00019.HK', '00763.HK', '03690.HK', '0700.HK', '0728.HK', '0762.HK', '9988.HK', 'AAL', 'AAP', 'ABG', 'ABM', 'AC.PA', 'ACIA', 'ACM', 'ACN', 'ADEN.ZU', 'AES', 'AGK.L', 'AHT.L', 'AIR.PA', 'ALK', 'ALLE', 'AMZN', 'AN', 'ANET', 'ANF', 'AON', 'ARMK', 'ARW', 'ASC.L', 'ASNA', 'ATUS', 'AVT', 'AZO', 'BAB.L', 'BABA', 'BAH', 'BBBY', 'BBY', 'BDEV.L', 'BIG', 'BKNG', 'BLMN', 'BNZL.L', 'BOL.PA', 'BRBY.L', 'BURL', 'BYND', 'BZUN', 'CAMP', 'CAR', 'CASY', 'CHDN', 'CHRW', 'CHTR', 'CIEN', 'CMG', 'CORE', 'CPG.L', 'CPI.L', 'CSX', 'CTAS', 'CZR', 'DAL', 'DCC.L', 'DDS', 'DEC.PA', 'DHER.DE', 'DIS', 'DISCA', 'DISH', 'DKS', 'DKSH.ZU', 'DLG.L', 'DPW.DE', 'DPZ', 'DRI', 'EAT', 'EBAY', 'EGHT', 'ETL.PA', 'ETSY', 'EXPD', 'EXPE', 'EXPN.L', 'EZJ.L', 'FDS', 'FDX', 'FFIV', 'FISV', 'FLT', 'FLTR.L', 'FLWS', 'FNTN.DE', 'FRA.DE', 'FRAS', 'FSLY', 'FTI.PA', 'FVRR', 'FWONA', 'G24.DE', 'GFS.L', 'GHC', 'GJF.OL', 'GLP', 'GME', 'GOGL.OL', 'GPC', 'GPI', 'GPS', 'GRUB', 'GWW', 'H', 'HAIN', 'HD', 'HDS', 'HLT', 'HNR1.DE', 'HRI', 'HSIC', 'HTZ', 'IAC', 'IAG.L', 'IDCC', 'INF.L', 'IPG', 'ITRK.L', 'ITV.L', 'J', 'JBHT', 'JBLU', 'JMIA', 'JOBS.CH', 'JWN', 'KBR', 'KGF.L', 'KGX.DE', 'KMX', 'KNX', 'KSS', 'LB', 'LBTYA', 'LBTYK', 'LHA.DE', 'LILA', 'LOGM', 'LSXMA', 'LUV', 'LVS', 'LYFT', 'LYV', 'MAN', 'MAR', 'MAS.MC', 'MCD', 'MCO', 'MCRO.L', 'MELI', 'MGM', 'MIK', 'MKS.L', 'MMB.PA', 'MMT.PA', 'MMYT', 'MNST', 'MRW.L', 'MTCH', 'MUSA', 'NAS.OL', 'NFLX', 'NOKIA.HE', 'NPTN', 'NWSA', 'NXT.L', 'O2D.DE', 'ODP', 'OKTA', 'OMC', 'OMI', 'ORA.PA', 'ORBC', 'ORLY', 'OSTK', 'OUT', 'PDCO', 'PFPT', 'PROX.BR', 'PSM.DE', 'PSON.L', 'PST.MI', 'PTON', 'PUB.PA', 'QSR', 'QTWO', 'R', 'RAD', 'REC.MI', 'REL.L', 'RHI', 'RMG.L', 'RMS', 'RNG', 'ROKU', 'ROST', 'RRD', 'RRTL.DE', 'RTO.L', 'RYAAY', 'Ryanair', 'SAH', 'SAVE', 'SAX.DE', 'SBRY.L', 'SBUX', 'SCHA.OL', 'SCI', 'SERV', 'SESG.PA', 'SFIX', 'SIG', 'SIRI', 'SIX', 'SIX2.DE', 'SKG.L', 'SKM', 'SNX', 'SPGI', 'SPTN', 'SQ', 'SRCG.ZU', 'STB.OL', 'STMP', 'SYY', 'TA', 'TCOM.CH', 'TEL2B.ST', 'TELIA.ST', 'TIF', 'TJX', 'TL5.MC', 'TLX.DE', 'TMUS', 'TNET.BR', 'TSCO.L', 'TTD', 'TUI.L', 'TV', 'UAL', 'UBER', 'UBXN.ZU', 'UNFI', 'UNI.MI', 'UNIT', 'URBN', 'URI', 'UTDI.DE', 'VIPS', 'VMUK.L', 'VRSK', 'W', 'WBT', 'WCC', 'WLTW', 'WMH.L', 'WMT', 'WORK', 'WPP.L', 'WSM', 'WSO', 'WTB.L', 'WYND', 'WYNN', 'YUM', 'ZS']
utilities = ['00002.HK', '00006.HK', '00135.HK', '00257.HK', '00384.HK', '02386.HK', '02688.HK', '0902.HK', '0916.HK', '1816.HK', 'A2A.MI', 'AEE', 'AEP', 'ALB', 'ANA.MC', 'ATADL.RU', 'ATC.NV', 'ATO', 'AWK', 'BCPT.L', 'BRW.L', 'BWLPG.OL', 'CCC.L', 'CIG', 'CMS', 'CNA.L', 'CNP', 'CVA', 'D', 'DANSKE.CO', 'DC.L', 'DRI.DE', 'DTE', 'DUK', 'ED', 'EDF.PA', 'EDP.LSB', 'EIX', 'ELE.MC', 'ELISA.HE', 'ENEL.MI', 'ENG.MC', 'ENGI.PA', 'ENS', 'EOAN.DE', 'ES', 'ETR', 'EVA', 'EVRG', 'EXC', 'FE', 'FGP.L', 'FORTUM.HE', 'GLO.L', 'GVC.L', 'HER.MI', 'IBE.MC', 'IDA', 'IG.MI', 'ILD.PA', 'IRE.MI', 'LEO.DE', 'LNT', 'MPC', 'MRC.L', 'NEE', 'NEP', 'NG.L', 'NI', 'NMC.L', 'NRG', 'NTGY.MC', 'NVTKL.RU', 'OGZDL.RU', 'OKE', 'ORA.US', 'PAM', 'PCG', 'PDL.L', 'PEG', 'PPL', 'PSX', 'REE.MC', 'REP.MC', 'RMV.L', 'RUI.PA', 'RWE.DE', 'SBMO.NV', 'SBS', 'SEV.PA', 'SGGDL.RU', 'SMP.L', 'SO', 'SPX.L', 'SRE', 'SRG.MI', 'SSE.L', 'SVT.L', 'TCH.PA', 'TED.L', 'TEL.OL', 'TFI.PA', 'TLIT.MI', 'TRN.L', 'TRN.MI', 'UGI', 'UKCM.L', 'UN01.DE', 'UU.L', 'VIE.PA', 'VLO', 'VST', 'WEC', 'WKL.NV', 'WMB', 'XEL']

currencies = ['EURUSD', 'GBPUSD', 'NZDUSD', 'USDCAD', 'USDJPY', 'USDCHF', 'AUDUSD', 'EURGBP', 'EURCHF', 'EURJPY', 'GBPJPY', 'EURAUD', 'EURCAD', 'AUDJPY', 'CADJPY', 'CHFJPY', 'USDHKD', 'USDZAR', 'USDRUB', 'USDCNH', 'AUDCHF', 'AUDCAD', 'AUDNZD', 'EURNZD', 'GBPAUD', 'GBPCHF', 'GBPNZD', 'NZDCAD', 'NZDCHF', 'NZDJPY', 'CADCHF', 'USDNOK', 'USDSEK', 'NOKSEK', 'EURNOK', 'EURSEK', 'USDTRY', 'USDMXN', 'USDSGD', 'GBPCAD', 'ZARJPY', 'EURPLN', 'USDHUF', 'EURHUF', 'GBPHUF', 'CHFHUF', 'USDPLN']

etfs = ['AAXJ', 'ACWI', 'AGG', 'AMLP', 'AOA', 'AOK', 'AOR', 'ASHR', 'BIL', 'BKLN', 'BND', 'BNDX', 'BOND', 'BSV', 'CORN', 'DBA', 'DGRO', 'DIA', 'EEM', 'EFA', 'EMB', 'EWG', 'EWH', 'EWJ', 'EWT', 'EWW', 'EWY', 'EWZ', 'EZU', 'FAZ', 'FEZ', 'FXI', 'GDX', 'GDXJ', 'GLD', 'HDV', 'HMMJ', 'HYG', 'IAEX.L', 'IAGG', 'IAPD.L', 'IAU', 'IBB', 'IBZL.L', 'IDEM.L', 'IDEV', 'IEF', 'IEFA', 'IEMG', 'IEML.L', 'IEUR', 'IFFF.L', 'IJH', 'IJJ', 'IJPE.L', 'IJR', 'ILTB', 'IMEU.L', 'IMTB', 'INDA', 'IPAC', 'ISF.L', 'ISTB', 'ITOT', 'ITWN.L', 'IUKP.L', 'IUSA.L', 'IUSB', 'IUSG', 'IUSV', 'IVV', 'IVW', 'IWB', 'IWD', 'IWF', 'IWM', 'IWN', 'IWO', 'IWR', 'IWS', 'IXUS', 'IYR', 'JNK', 'JPST', 'KBE', 'KRE', 'KWEB', 'LQD', 'LQDE.L', 'MCHI', 'MDY', 'MINT', 'MTUM', 'MUB', 'PFF', 'QQQ', 'QUAL', 'RSX', 'RWR', 'SCO', 'SHV', 'SHY', 'SKYY', 'SLV', 'SOXX', 'SPLV', 'SPY', 'SQQQ', 'SSO', 'SWDA.L', 'TIP', 'TLT', 'TQQQ', 'TZA', 'UGA', 'UNG', 'USMV', 'USO', 'USRT', 'VCIT', 'VCSH', 'VEA', 'VEU', 'VGK', 'VGT', 'VNQ', 'VOE', 'VOO', 'VTI', 'VTIP', 'VTV', 'VUG', 'VWO', 'VXX', 'WEAT', 'XBI', 'XCX5.L', 'XDJP.L', 'XLB', 'XLC', 'XLE', 'XLF', 'XLI', 'XLK', 'XLP', 'XLRE', 'XLU', 'XLV', 'XLY', 'XOP', 'XS6R.L']

# %%
extra_etfs = {
    'Canada': 'EWC',
    'US': 'SPY',
    'Mexico': 'EWW',
    'Peru': 'EPU',
    'Brazil': 'EWZ',
    'Argentina': 'ARGT',
    'UK': 'EWU',
    'Spain': 'EWP',
    'Germany': 'EWG',
    'Italy': 'EWI',
    'Russia': 'ERUS',
    'Egypt': 'EGPT',
    'Africa': 'AFK',
    'S. Africa': 'EZA',
    'India': 'INDA',
    'Korea': 'EWY',
    'China': 'MCHI',
    'Singapore': 'EWS',
    'Australia': 'EWA',
    'Japan': 'EWJ',
}
etfs_reversed = {v:k for k,v in extra_etfs.items()}

# %%
nbl = Key_Table(_type=Stock, _get_key=lambda s: s.name)
for name in tqdm(etfs_reversed):
    nbl.new(name)
len(nbl)
# Out:
# C:\Users\anwan\anaconda3\lib\site-packages\ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# ...
# 20

# %%
tbl = Key_Table(_type=Stock, _get_key=lambda s: s.name)

# %%
for name in tqdm(etfs):
    if name != 'HMMJ':
        tbl.new(name)
len(tbl)

# %%
tt = Key_Table(_type=Stock, _get_key=lambda s: s.name)

# %%
for name in tqdm(technology):
    tt.new(name)
len(tt)
# Out:
# C:\Users\anwan\anaconda3\lib\site-packages\ipykernel_launcher.py:1: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """Entry point for launching an IPython kernel.
# ...
# 230

# %%
tk = tbl.get('EWJ')
tk.name
# Out:
# 'EWJ'

# %%
def _load(tk):
    return tk.name, tk.get_closes(months=60)
# data = dict(tbl.map(_load, pbar=tqdm))

ndata = dict(nbl.map(_load, pbar=tqdm))
len(data)
# Out:
# ...
# 150

# %%
nations = ['US', 'China', 'Russia', 'Japan', 'Germany', 'UK', 'Africa']
nations = list(extra_etfs)[10:]

# %%
plt.figure()
for n in nations:
    t = extra_etfs[n]
    plt.plot(ndata[t][::5], label=n)
plt.legend()
pass
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# J = nbl.get('EWJ')
J = Stock('EWY')
J.get_info()#['shortName']
# Out:
# {'previousClose': 58.82,
#  'regularMarketOpen': 58.26,
#  'twoHundredDayAverage': 55.016495,
#  'trailingAnnualDividendYield': 0.020435227,
#  'payoutRatio': None,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 58.48,
#  'navPrice': 58.85,
#  'averageDailyVolume10Day': 4831871,
#  'totalAssets': 4300780544,
#  'regularMarketPreviousClose': 58.82,
#  'fiftyDayAverage': 56.903824,
#  'trailingAnnualDividendRate': 1.202,
#  'open': 58.26,
#  'toCurrency': None,
#  'averageVolume10days': 4831871,
#  'expireDate': None,
#  'yield': 0.0229,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': None,
#  'beta': None,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 57.995,
#  'priceHint': 2,
#  'currency': 'USD',
#  'regularMarketVolume': 2654226,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': None,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 4408496,
# ...

# %%
import requests


def get_symbol(symbol):
    url = "http://d.yimg.com/autoc.finance.yahoo.com/autoc?query={}&region=1&lang=en".format(symbol)

    result = requests.get(url).json()

    for x in result['ResultSet']['Result']:
        if x['symbol'] == symbol:
            return x['name']

# %%
def _find_name(tk):
    tk.company = get_symbol(tk.name)
tt.map(_find_name, pbar=tqdm, safe=True)
pass

# %%
list(tt.select('company'))
# Out:
# [None,
#  None,
#  None,
#  'Lenovo Group Limited',
#  'Kingsoft Corporation Limited',
#  '888 Holdings plc',
#  'Adobe Inc.',
#  'Analog Devices, Inc.',
#  'Automatic Data Processing, Inc.',
#  'Autodesk, Inc.',
#  'AIXTRON SE',
#  'Akamai Technologies, Inc.',
#  'Applied Materials, Inc.',
#  'Advanced Micro Devices, Inc.',
#  'Amadeus IT Group, S.A.',
#  None,
#  'America Movil, S.A.B. de C.V.',
#  'ANSYS, Inc.',
#  'Amphenol Corporation',
#  None,
#  'ASML Holding N.V.',
#  None,
#  None,
#  'Atos SE',
#  'Activision Blizzard, Inc.',
#  'Broadcom Inc.',
#  'Avid Technology, Inc.',
#  'Avast Plc',
#  'Alteryx, Inc.',
#  'Aspen Technology, Inc.',
#  'BlackBerry Limited',
#  'Balfour Beatty plc',
#  'Bechtle AG',
#  None,
#  'Baidu, Inc.',
#  'Bitauto Holdings Limited',
#  'Box, Inc.',
#  'Broadridge Financial Solutions, Inc.',
#  None,
#  'Capgemini SE',
#  'Capital & Counties Properties PLC',
#  'Cadence Design Systems, Inc.',
#  'CDW Corporation',
#  'Cerner Corporation',
# ...

# %%
t = YahooFinancials('XRX')

# %%
company = get_symbol("MSFT")

print(company)
# Out:
# Microsoft Corporation

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-86-b9e9ce79ddc2> in <module>
# ----> 1 companies = [get_symbol(name) for name in technology]
#
# <ipython-input-86-b9e9ce79ddc2> in <listcomp>(.0)
# ----> 1 companies = [get_symbol(name) for name in technology]
#
# <ipython-input-84-d5affc3de955> in get_symbol(symbol)
#       5     url = "http://d.yimg.com/autoc.finance.yahoo.com/autoc?query={}&region=1&lang=en".format(symbol)
#       6
# ----> 7     result = requests.get(url).json()
#       8
#       9     for x in result['ResultSet']['Result']:
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
# ...

# %%
# sel = ['EWJ', 'EWG', 'EWY', 'EWT', 'EWH', 'EZU']
nations = {
    'us': 'SPY',
    'china': 'FXI',
    'brazil': 'EWZ',
    'russia': 'RSX',
    'india': 'INDA',
    'taiwan': 'EWT',
    'germany': 'EWG',
    'japan': 'EWJ',
    'korea': 'EWY',
    'uk': 'isf.l',
    
#     'ex-US': 'efa',
#     'emerging': 'eem',
}

indices = {
#     'dow': 'dj30',
    'dow': 'us30',
}

sel = nations
