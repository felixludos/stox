# %%
import sys, os
from pathlib import Path
import PyPDF2 
from PyPDF2 import PdfFileWriter,PdfFileReader,PdfFileMerger

# %%
root = Path('raw/pdfs')

fname = 'msft_highlights.pdf'
# fname = 'sap_highlights.pdf'

path = root / fname

# %%
imdir = (root/'imgs')
imdir.mkdir(exist_ok=True)

# %%
from pdfstructure.hierarchy.parser import HierarchyParser
from pdfstructure.source import FileSource

parser = HierarchyParser() 

# specify source (that implements source.read())
source = FileSource(path.open('rb')) 

# analyse document and parse as nested data structure
document = parser.parse_pdf(source)

# %%
from pdfstructure.printer import PrettyStringPrinter

stringExporter = PrettyStringPrinter()
prettyString = stringExporter.print(document)
print(prettyString)
# Out:
# [Company Research Highlights ®]
# 	Report created on August 25, 2021
#
# 	[MICROSOFT ORD SHS  NASDAQ:MSFT]
#
# 		[One Microsoft Way
# 		Redmond, WA 98052-6399
# 		USA
# 		Telephone: 425 882 -8080
# 		www.microsoft.com]
#
# 			[Price on 8/24/2021:]
#
# 				[Market Capitalization:]
# 					$302.62
# 					$2275.4 B
# 					Information Technology Sector
# 					Software Industry
# 					Business Description  Data provided by S&P Compustat
# 					Microsoft Corporation develops, licenses, and supports software, services, devices, and
# 					solutions worldwide.
# 					3-Year Price Performance  Data provided by DataScope from Refinitiv
# 			Key Statistics
# 			Employee Count
# 			Institutional Ownership
# 			Total Revenue (TTM)
#
# 			[Revenue Growth]
# 				(TTM vs. Prior TTM)
# 			Enterprise Value
# 			Ex. Dividend Date
# 			Dividend
# 			P/E (TTM)
# 			Earning Yield (TTM)
# 			EPS (Adjusted TTM)
# 			Dividend Yield (Annualized)
#
# 			[Consensus EPS Estimate]
# 				(Q1 2022)
#
# 			[EPS Growth]
# 				(TTM vs. Prior TTM)
# 				181,000
# 				71.7%
# 				$46,152.00
# 				6/30/2021
# 				+17.53%
# 				$2227.3 B
# 				8/24/2021
# 				8/18/2021
# 				$0.560000
# 				0.74%
# 				8/24/2021
# 				37.6
# 				8/24/2021
# 				+2.66%
# 				8/24/2021
# 				$2.17
# 				7/27/2021
# 				$2.07
# 				+40.0%
# 				200-Day Moving Average
# 				150%
# 				100%
# 				50%
# 				0%
# 				-50%
# 				1,000
# 				0
# 				Q2
# 				Q3
# 				Q4
# 				Q2
# 				Q3
# 				Q4
# 				Q2
# 				Q3
# 				Q1
# 				2020
# 				Q1
# 				2021
# 				$305.84
# 			Price Performance (% Change)
#
# 			[Volume]
# 				$196.25
# 			4 Week
# 			13 Week
#
# 			[52 Week]
# 				3.9
# 				7.7
# 				22.8
# 				1 Year Annualized as of 8/24/2021
# 			Total Return
# 			Standard Deviation
#
# 			[Beta]
# 				5.6
# 				20.2
# 				41.6
# 				0.23
# 				1.15
# 				+42.91%
# 			Average 10-Day
#
# 			[Average 90-Day]
# 				21,951,840.8
# 				23,878,322.4
#
# 			[Shares Outstanding]
# 				7,514,891,000
# 			Environmental, Social & Governance Summary (ESG)
#
# 			[Environmental, Social & Governance Summary (ESG)]
# 				PROVIDED BY MSCI
# 				RATING
# 				MSFT
# 				INDUSTRY
# 				Risk:
# 				Leader = Top 25%
# 				Average = Middle 50%
# 				Laggard = Bottom 25%
# 				LEADER
# 				LEADER
# 				LEADER
# 				LEADER
# 				LEADER
# 				LEADER
# 				LEADER
# 				LEADER
# 				AVERAGE
# 				AVERAGE
# 				AVERAGE
# 				AVERAGE
# 				AVERAGE
# 				AVERAGE
# 				AVERAGE
# 				AVERAGE
# 				50-Day Moving Average
# 				Average Monthly Volume (Millions)
# 				Q4
# 				2018
# 				Q1
# 				2019
# 			Trading Characteristics
#
# 			[52 Week High]
# 				8/20/2021
#
# 			[52 Week Low]
# 				9/18/2020
# 			% Price Above/Below
# 			20-Day Average
# 			50-Day Average
#
# 			[200-Day Average]
# 				Overall
# 				Environment
# 				Social
# 				Governance
# 				TRBC Industry: Software
# 				Important Information Regarding Third-Party Content
# 				This is not an investment recommendation from Fidelity Investments. Fidelity provides this information as a service to investors from independent, third-party sources.
# 				Performance of analyst recommendations are provided by StarMine from Refinitiv. Current analyst recommendations are collected and standardized by Investars.
# 				See each section in this report for third-party content attribution, as well as the final page of the report for additional important information regarding third-party content.
# 				Page 1
#
# 	[Company Research Highlights®]
#
# 		[Price on 8/24/2021:]
#
# 			[Market Capitalization:]
# 				$302.62
# 				$2275.4 B
# 				Information Technology Sector
# 				Software Industry
# 				This is not an investment recommendation from Fidelity Investments. The information
# 				contained in this report is sourced from independent, third party providers.
#
# 	[MSFT]
#
# 		[MICROSOFT ORD SHS]
# 			NASDAQ
# 			Starmine
# 			Relative Accuracy2 Standardized Opinion3
#
# 			[MSFT Equity Summary Score]
# 				8 Firms†
# 				Equity Summary Score  (8 Firms†) Provided by StarMine from Refinitiv as of 8/25/2021
# 				Firm1
# 				Ford Equity Research (i)
# 				Refinitiv/Verus (i)
# 				Zacks Investment Research, Inc (i)
# 				ISS-EVA (i)
# 				Jefferson Research (i)
# 				Trading Central (i)
# 				McLean Capital Management (i)
# 				Argus Research A6/Quantitative  (i)
# 				• Opinion used in Equity Summary Score
# 				70
# 				87
# 				82
# 				94
# 				31
# 				16
# 				60
# 				32
# 				Neutral
# 				Neutral
# 				Outperform
# 				Buy
# 				Neutral
# 				Buy
# 				Neutral
# 				Buy
# 				Firm Opinions  Provided by Investars as of 8/25/2021
# 			Firm1 / Aggregate Opinion
# 			Opinion
# 			1 Year History
#
# 			[Investars
# 			Smartindex]
# 				STANDARDIZED OPINION
# 				CURRENT FIRM OPINION
# 				Equity Summary Score is a weighted,
# 				aggregated view of opinions from the
# 				independent research firms on Fidelity.com.
# 				It uses the past accuracy of these firms in
# 				determining the emphasis placed on any
# 				individual opinion.
# 				First Call Consensus Recommendation
# 				is provided by I/B/E/S from Refinitiv, an
# 				independent third-party research provider,
# 				using information gathered from
# 				contributors. The number of contributors for
# 				each security where there is a consensus
# 				recommendation is provided. Each
# 				contributor determines how their individual
# 				recommendation scale maps to the I/B/E/S
# 				from Refinitiv 5-point scale.
# 				Visit Fidelity.com for firm descriptions,
# 				detailed methodologies, and more
# 				information on the Equity Summary Score,
# 				First Call Consensus, opinion history and
# 				performance, and most current available
# 				research reports for MSFT.
# 				1. (i) after the Firm Name indicates an
# 				independent firm that derives no
# 				financial benefit from the nature of their
# 				recommendations.
# 				2. StarMine from Refinitiv Relative Accuracy
# 				is based on a statistical aggregation of
# 				how well a firm performed on all of its
# 				individual stock recommendations in a
# 				given sector. StarMine from Refinitiv first
# 				calculates the individual scores for each
# 				set of recommendations for a single
# 				stock over a 24 month period. Then
# 				StarMine from Refinitiv rolls up these
# 				individual performance scores into a
# 				firm's sector score.
# 				3. Each firm has its own recommendation
# 				categories, making it difficult to compare
# 				one firm’s recommendation to another’s.
# 				Investars, a third-party research
# 				company, collects and standardizes
# 				these recommendations using a
# 				five-point scale.
# 				† The Equity Summary Score provided by
# 				StarMine from Refinitiv is current as of
# 				the date specified. There may be
# 				differences between the Equity Summary
# 				Score analyst count and the number of
# 				underlying analysts listed. Due to the
# 				timing in receiving ratings changes into
# 				the Equity Summary Score model, the
# 				Equity Summary Score analyst count
# 				may lag the ratings count displayed by
# 				one or more days. There may also be
# 				analyst count variations for symbols with
# 				multiple share classes and ADRs. More
# 				details on Equity Summary Score
# 				calculation are included in the
# 				Understanding and Using the Equity
# 				Summary Score Methodology (PDF).
# 				Oppenheimer & Company
# 				RBC Capital Markets
# 				Raymond James
# 				KeyBanc Capital Markets
# 				Bernstein
# 				Stifel Nicolaus
# 				Jefferies
# 				CSFB
# 				Merrill Lynch
# 				UBS
# 				Morgan Stanley
# 				William Blair & Company
# 				Wedbush Morgan
# 				Citigroup Investment Research
# 				Deutsche Bank
# 				Piper Jaffray
# 				Argus Analyst
# 				Ford Equity Research (i)
# 				Refinitiv/Verus (i)
# 				Zacks Investment Research, Inc (i)
# 				ISS-EVA (i)
# 				Jefferson Research (i)
# 				Trading Central (i)
# 				McLean Capital Management (i)
# 				Argus Research A6/Quantitative  (i)
# 				I/B/E/S Estimates from Refinitiv
#
# 			[Equity Summary Score (8 Firms†)]
# 				• Opinion used in Equity Summary Score
# 				Outperform
# 				Outperform
# 				Outperform
# 				Outperform
# 				Outperform
# 				Outperform
# 				Buy
# 				Buy
# 				Buy
# 				Buy
# 				Buy
# 				Buy
# 				Buy
# 				Buy
# 				Buy
# 				Outperform
# 				Outperform
# 				Buy
# 				Neutral
# 				Neutral
# 				Buy
# 				Neutral
# 				Buy
# 				Neutral
# 				Buy
# 				--
# 				--
#
# 			[Bullish]
# 				9.0
# 				VERY BULLISH
# 				BULLISH
# 				NEUTRAL
# 				BEARISH
# 				VERY BEARISH
# 				10
# 				9
# 				7
# 				3
# 				1
# 				0
# 				89.90%
# 				97.57%
# 				64.89%
# 				92.58%
# 				88.10%
# 				103.53%
# 				74.99%
# 				97.33%
# 				88.34%
# 				94.87%
# 				93.56%
# 				73.50%
# 				87.12%
# 				86.16%
# 				83.07%
# 				89.26%
# 				83.55%
# 				92.58%
# 				168.14%
# 				148.46%
# 				102.55%
# 				94.38%
# 				60.18%
# 				66.26%
# 				68.56%
# 				--
# 				--
# 			Date
#
# 			[Opinion]
# 				07/15/21
# 				Outperform
# 				08/20/21
# 				Outperform
# 				04/28/21
# 				Strong Buy
# 				07/26/21
# 				Buy
# 				07/28/21
# 				Outperform
# 				07/28/21
# 				07/28/21
# 				07/28/21
# 				08/20/21
# 				Buy
# 				Buy
# 				Buy
# 				Buy
# 				07/28/21
# 				Outperform
# 				07/28/21
# 				Overweight (o)
# 				05/25/21
# 				Outperform
# 				08/20/21
# 				Outperform
# 				07/28/21
# 				10/29/20
# 				Buy
# 				Buy
# 				07/28/21
# 				Overweight
# 				07/30/21
# 				Buy
# 				08/20/21
# 				3
# 				08/23/21
# 				Hold
# 				08/21/21
# 				Outperform
# 				08/01/21
# 				08/20/21
# 				08/22/21
# 				Buy
# 				Hold
# 				Buy
# 				08/23/21
# 				Neutral
# 				08/19/21
# 				08/23/21
# 				Buy
# 				Buy
# 				08/25/21
#
# 			[Bullish]
# 				Report created on August 25, 2021
# 				The content on this page is provided by third parties and not Fidelity. Fidelity did not prepare and does not endorse such content. All are third-party companies that are not affiliated with Fidelity.
# 				See each section in this report for third-party content attribution and see page 4 for full disclosures.
# 				Page 2
#
# 	[Company Research Highlights®]
#
# 		[Price on 8/24/2021:]
#
# 			[Market Capitalization:]
# 				$302.62
# 				$2275.4 B
# 				Information Technology Sector
# 				Software Industry
# 				This is not an investment recommendation from Fidelity Investments. The information
# 				contained in this report is sourced from independent, third party providers.
#
# 	[MSFT]
#
# 		[MICROSOFT ORD SHS]
# 			NASDAQ
#
# 			[Recent Recap]
# 				Actuals vs. Estimates by Fiscal Quarter  Data provided by I/B/E/S from Refinitiv
# 				ACTUALS
# 				ESTIMATES
# 				STARMINE ESTIMATES
# 				MSFT PRICE
#
# 			[Earnings in US Dollars]
# 				Today
#
# 			[Last Report: Q4 Earnings on 07/27/21
# 			Reported Earnings: $2.17 per share
# 			Next Expected Report Date: 10/25/21]
# 				MSFT exceeded the First Call Consensus
# 				of $1.916 and exceeded the StarMine
# 				SmartEstimate from Refinitiv of $1.949 for
# 				Q4 2021.
# 				About Starmine SmartEstimate
# 				The StarMine SmartEstimate from Refinitiv
# 				seeks to be more accurate than the
# 				consensus EPS by calculating an analyst's
# 				accuracy and timeliness of an analyst's
# 				estimates into its estimate of earnings.
# 				$400
# 				$200
# 				$0
# 				1.37
# 				Q4
# 				1.38
# 				Q1
# 				2020
# 				2020
# 				2020
# 				2020
# 				1.51
# 				Q2
# 				1.40
# 				Q3
# 				1.46
# 				Q4
# 				2.03
# 				Q2
# 				2.03
# 				Q3
# 				2.17
# 				Q4
# 				1.82
# 				Q1
# 				2021
# 				2021
# 				2021
# 				2021
# 				2.07
# 				Q1
# 				2022
# 				2022
# 				2022
# 				2022
# 			Actuals vs. Estimates for Fiscal Year
# 			Actual ($)
# 			Consensus ($)
#
# 			[Low / High Range ($)]
# 				Previous Year (Ends 06/30/21)
# 				Next Year (Ends 06/30/22)
# 				8.05
# 				--
# 				7.77
# 				8.77
# 				31
# 				34
# 				7.24 / 7.96
# 				8.09 / 9.34
#
# 			[First Call Estimates
# 			Analysts in Consensus]
# 				Industry Comparisons**  Data provided by S&P Compustat
#
# 			[MSFT Percentile Rank in Industry]
# 				Valuation Ratios (trailing 12 months)
# 				Price / Earnings
# 				PEG Ratio
# 				Enterprise Value
# 				Price / Sales
# 				Price / Book
# 				Price / Cash Flow
# 				Company Quality Ratios
# 				Gross Profit Margin (Trailing 12 Months)
# 				Operating Margin (Trailing 12 Months)
# 				Return on Assets (Trailing 12 Months)
# 				Return on Equity (Trailing 12 Months)
# 				MSFT
# 				37.6
# 				2.5
# 				$0.00
# 				13.6
# 				17.2
# 				31.3
# 				MSFT
# 				75.9%
# 				41.6%
# 				19.6%
# 				46.2%
# 				Growth Rates (%)
# 				Revenue Growth (Trailing 12 Months vs. Prior Trailing 12 Months)
# 				EPS Growth (Trailing 12 Months vs. Prior Trailing 12 Months)
# 				Revenue % Change (Trailing 12 Months)
# 				MSFT
# 				+17.5%
# 				+40.0%
# 				+21.35%
# 				Industry
# 				61.0
# 				4.2
# 				$0.00
# 				17.8
# 				28.6
# 				76.6
# 				Industry
# 				78.0
# 				18.3
# 				9.9
# 				31.6
# 				Industry
# 				+67.4
# 				+50.8
# 				+67.01
# 				58
# 				17
# 				100
# 				70
# 				74
# 				49
# 				58
# 				99
# 				96
# 				89
# 				53
# 				73
# 				50
# 				0: Worst
# 				Best: 100
#
# 			[MSFT Percentile Rank in Industry]
# 				0: Worst
# 				Best: 100
#
# 			[MSFT Percentile Rank in Industry]
# 				0: Worst
# 				Best: 100
# 				** The Industry Average and Percentile Rank methodology is based on the daily list of U.S. equity securities in each industry to which a company belongs, as
# 				determined by Standard & Poor's. S&P uses the Global Industry Classification Standard (GICS)SM, an industry classification system developed by S&P in
# 				collaboration with Morgan Stanley Capital International (MSCI).
# 				A company is assigned to a single GICS sub-industry according to the definition of its principal business activity as determined by Standard & Poor's and MSCI.
# 				Revenues are a significant factor in defining principal business activity; however, earnings analysis and market perception are also important criteria for
# 				classification.
# 				Securities are first grouped into their respective S&P GIC Industry, null values are removed and then the percentile is computed. The percentile is the value of a
# 				variable below which a certain percent of observations fall. So the 20th percentile is the value (or score) below which 20 percent of the observations may be
# 				found. Sometimes, being in the 100th percentile is not the best for items such as Debt to Capital Ratio where a lower number means less debt. Therefore, being
# 				in the 1st percentile indicates lower debt than its peers in the industry.
# 				The Industry Average is a market cap-weighted average of the non-null values in the industry.
# 				Report created on August 25, 2021
# 				The content on this page is provided by third parties and not Fidelity. Fidelity did not prepare and does not endorse such content. All are third-party companies that are not affiliated with Fidelity.
# 				See each section in this report for third-party content attribution.
# 				Page 3
#
# 	[Company Research Highlights®]
#
# 		[Price on 8/24/2021:]
#
# 			[Market Capitalization:]
# 				$302.62
# 				$2275.4 B
# 				Information Technology Sector
# 				Software Industry
#
# 		[Important Information Regarding Third-Party Content]
# 			This is not an investment recommendation from Fidelity Investments. The information
# 			contained in this report is sourced from independent, third party providers.
#
# 	[MSFT]
#
# 		[MICROSOFT ORD SHS]
# 			NASDAQ
# 			The content compiled in this report is provided by third parties and not Fidelity. Fidelity did not prepare and does not endorse such content. Historical prices provided by Datascope from
# 			Refinitiv. Fundamental data provided by  Standard & Poor’s Compustat®.  Earnings estimates provided by Refinitiv. Analyst recommendations performance measurement provided by
# 			StarMine from Refinitiv. Analyst recommendations data and analysis provided by Investars. All are third-party companies that are not affiliated with Fidelity.
# 			This report provides quotes and data concerning the financial markets, securities and other subjects. Content is supplied by companies that are not affiliated with Fidelity ("Third-Party
# 			Content"). Most Third-Party Content and its source are clearly and prominently identified. Fidelity does not prepare, edit, or endorse Third-Party Content. News and research are subject
# 			to change without notice and Fidelity does not guarantee their accuracy, timeliness, completeness or usefulness, and is not responsible or liable for any content, advertising, products, or
# 			other materials on or available from third parties nor is Fidelity liable for losses resulting from their use. You use Third-Party Content only at your own risk. With respect to research
# 			reports, in order to comply with applicable laws and regulations, Fidelity may at times suppress the delivery of certain reports which are the subject of public offerings made available to
# 			Fidelity’s brokerage customers, or otherwise.
# 			Content is provided for informational and/or educational purposes and is not intended to provide tax, legal or investment advice and should not be construed as an offer to sell, a
# 			solicitation of an offer to buy, or a recommendation for any security by Fidelity or any Third-Party Provider. Requests for reports are unsolicited. Individuals are responsible for determining
# 			whether any investment, security or strategy is appropriate or suitable and that neither Fidelity nor any Third-Party Provider has made any determination that any recommendation,
# 			investment, or strategy in any content is suitable or appropriate based on investment objectives and financial situations.
# 			Report created on August 25, 2021
# 			The content on this page is provided by third parties and not Fidelity. Fidelity did not prepare and does not endorse such content. All are third-party companies that are not affiliated with Fidelity.
# 			See each section in this report for third-party content attribution.
# 			Page 4
# 			© 2021 FMR LLC. All rights reserved. 447628.8.0

# %%
D = document

# %%
D.title

# %%
cs = D.elements[0].children#[0]
[c.heading_text for c in cs]
# Out:
# ['Report created on August 25, 2021',
#  'MICROSOFT ORD SHS  NASDAQ:MSFT',
#  'Company Research Highlights®',
#  'MSFT',
#  'Company Research Highlights®',
#  'MSFT',
#  'Company Research Highlights®',
#  'MSFT']

# %%
addr = D.elements[0].children[1].children[0]
addr.heading_text.split('\n')
# Out:
# ['One Microsoft Way',
#  'Redmond, WA 98052-6399',
#  'USA',
#  'Telephone: 425 882 -8080',
#  'www.microsoft.com']

# %%
sector, industry = addr.children[0].children[0].children[-4].heading_text.split('\n')
sector = ' '.join(sector.split(' ')[:-1])
industry = ' '.join(industry.split(' ')[:-1])
desc = addr.children[0].children[0].children[-2].heading_text.replace('\n', ' ')
sector, industry, desc
# Out:
# ('Information Technology',
#  'Software',
#  'Microsoft Corporation develops, licenses, and supports software, services, devices, and solutions worldwide.')

# %%
ccs = addr.children[14].children
end = [c.heading_text for c in ccs].index('200-Day Moving Average')
ccs = ccs[1:end]
vals = [c.heading_text for c in ccs]

ccs = addr.children[2:15]
keys = [c.heading_text for c in ccs]

# %%
tbl = []

i = 0
for v in vals:
    k = None
    if '/' in v:
        if keys[i].startswith('Ex. Div'):
            i += 1
        if tbl[-1][0].startswith('Ex. Div'):
            tbl[-1][0] = f'{keys[i-2]} Date'
        i -= 1
        if not keys[i].endswith('Date'):
            k = f'{keys[i]} Date'    
    if k is None:
        k = keys[i]
    tbl.append([k, v])
    i += 1
tbl
key_stats = tbl

# %%
ccs = addr.children[27].children
esg_cats = [c.heading_text for c in addr.children[34].children[:4]]
ccs = addr.children[27].children[-8:-4]
esg_scores = [c.heading_text.split('\n')[0] for c in ccs]
esg = list(zip(esg_cats, esg_scores))
esg
# Out:
# [('Overall', 'LEADER'),
#  ('Environment', 'LEADER'),
#  ('Social', 'AVERAGE'),
#  ('Governance', 'AVERAGE')]

# %%
ccs = D.elements[0].children[3].children[0].children[3].children
enames = ccs[2].heading_text.split('\n')[1:]
eacc = ccs[4].heading_text.split('\n')
escore = ccs[5].heading_text.split('\n')
equity_summary = list(zip(enames, eacc, escore))
equity_summary
# Out:
# [('Ford Equity Research (i)', '70', 'Neutral'),
#  ('Refinitiv/Verus (i)', '87', 'Neutral'),
#  ('Zacks Investment Research, Inc (i)', '82', 'Outperform'),
#  ('ISS-EVA (i)', '94', 'Buy'),
#  ('Jefferson Research (i)', '31', 'Neutral'),
#  ('Trading Central (i)', '16', 'Buy'),
#  ('McLean Capital Management (i)', '60', 'Neutral'),
#  ('Argus Research A6/Quantitative  (i)', '32', 'Buy')]

# %%
ccs = D.elements[0].children[3].children[0].children[7].children

i = [i for i, c in enumerate(ccs) if c.heading_text.endswith('Summary Score Methodology (PDF).')][0] + 1

ns = [n.heading_text.split('\n') for n in ccs[i:]]
names = []
for n in ns:
    names.extend(n)
names
# Out:
# ['Oppenheimer & Company',
#  'RBC Capital Markets',
#  'Raymond James',
#  'KeyBanc Capital Markets',
#  'Bernstein',
#  'Stifel Nicolaus',
#  'Jefferies',
#  'CSFB',
#  'Merrill Lynch',
#  'UBS',
#  'Morgan Stanley',
#  'William Blair & Company',
#  'Wedbush Morgan',
#  'Citigroup Investment Research',
#  'Deutsche Bank',
#  'Piper Jaffray',
#  'Argus Analyst',
#  'Ford Equity Research (i)',
#  'Refinitiv/Verus (i)',
#  'Zacks Investment Research, Inc (i)',
#  'ISS-EVA (i)',
#  'Jefferson Research (i)',
#  'Trading Central (i)',
#  'McLean Capital Management (i)',
#  'Argus Research A6/Quantitative  (i)',
#  'I/B/E/S Estimates from Refinitiv']

# %%
ccs = D.elements[0].children[3].children[0].children[8].children
[c.heading_text for c in ccs]
# Out:
# ['• Opinion used in Equity Summary Score',
#  'Outperform',
#  'Outperform',
#  'Outperform',
#  'Outperform',
#  'Outperform',
#  'Outperform',
#  'Buy',
#  'Buy',
#  'Buy',
#  'Buy',
#  'Buy',
#  'Buy',
#  'Buy',
#  'Buy',
#  'Buy',
#  'Outperform',
#  'Outperform',
#  'Buy',
#  'Neutral',
#  'Neutral',
#  'Buy',
#  'Neutral',
#  'Buy',
#  'Neutral',
#  'Buy',
#  '--',
#  '--']

# %%
ccs = D.elements[0].children[1].children
[c.heading_text for c in ccs]

# %%
# from pdf2image import convert_from_path
# pages = convert_from_path(path, 500)

# %%
# for i, page in enumerate(pages):
#     page.save(imdir/f'out{i}.jpg', 'JPEG')

# %%
page_no = 0

# %%
import pdfplumber

pdf_obj = pdfplumber.open(path)
page = pdf_obj.pages[page_no]
images_in_page = page.images
page_height = page.height
image_bbox = (image['x0'], page_height - image['y1'], image['x1'], page_height - image['y0'])
cropped_page = page.crop(image_bbox)
image_obj = cropped_page.to_image(resolution=400)
image_obj.save(path_to_save_image)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-ba5ba153f0d7> in <module>
#       5 images_in_page = page.images
#       6 page_height = page.height
# ----> 7 image_bbox = (image['x0'], page_height - image['y1'], image['x1'], page_height - image['y0'])
#       8 cropped_page = page.crop(image_bbox)
#       9 image_obj = cropped_page.to_image(resolution=400)
#
# TypeError: 'JpegImageFile' object is not subscriptable

# %%
from pdfminer.layout import LAParams, LTTextBox
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfinterp import PDFResourceManager
from pdfminer.pdfinterp import PDFPageInterpreter
from pdfminer.converter import PDFPageAggregator

rsrcmgr = PDFResourceManager()
laparams = LAParams()
device = PDFPageAggregator(rsrcmgr, laparams=laparams)
interpreter = PDFPageInterpreter(rsrcmgr, device)

# %%
for page in PDFPage.get_pages(path.open('rb')):
#     print('Processing next page...')
    interpreter.process_page(page)
    layout = device.get_result()
    for lobj in layout:
        if isinstance(lobj, LTTextBox):
            x, y, text = lobj.bbox[0], lobj.bbox[3], lobj.get_text()
#             print(text)
            if '3-Year Price Performance' in text:
                print(text, x, y)
#             print('At %r is text: %s' % ((x, y), text))
# Out:
# 3-Year Price Performance  Data provided by DataScope from Refinitiv
#  174.96013996800002 596.7844774272

# %%
# import fitz # PyMuPDF
# import io
# from PIL import Image

# %%
# pdf_file = fitz.open(str(path))

# %%
# for page_index in range(len(pdf_file)):
#     # get the page itself
#     page = pdf_file[page_index]
#     image_list = page.getImageList()
#     # printing number of images found in this page
#     if image_list:
#         print(f"[+] Found a total of {len(image_list)} images in page {page_index}")
#     else:
#         print("[!] No images found on page", page_index)
#     for image_index, img in enumerate(page.getImageList(), start=1):
#         # get the XREF of the image
#         xref = img[0]
#         # extract the image bytes
#         base_image = pdf_file.extractImage(xref)
#         image_bytes = base_image["image"]
#         # get the image extension
#         image_ext = base_image["ext"]
#         # load it to PIL
#         image = Image.open(io.BytesIO(image_bytes))
#         # save it to local disk
#         image.save(open(f"image{page_index+1}_{image_index}.{image_ext}", "wb"))

# %%
from pdfstructure.hierarchy.parser import HierarchyParser
from pdfstructure.source import FileSource

parser = HierarchyParser() 

# specify source (that implements source.read())
source = FileSource(path.open('rb')) 

# analyse document and parse as nested data structure
document = parser.parse_pdf(source)

# %%
from pdfstructure.printer import PrettyStringPrinter

stringExporter = PrettyStringPrinter()
prettyString = stringExporter.print(document)
print(prettyString)
# Out:
# [Company Research Highlights ®]
# 	Report created on August 25, 2021
#
# 	[NVIDIA ORD SHS  NASDAQ:NVDA]
#
# 		[2788 San Tomas Expressway
# 		Santa Clara, CA 95051
# 		USA
# 		Telephone: 408 486 -2000
# 		www.nvidia.com]
#
# 			[Price on 8/24/2021:]
#
# 				[Market Capitalization:]
# 					$217.93
# 					$544.0 B
# 					Information Technology Sector
# 					Semiconductors & Semiconductor Equipment Industry
# 					Business Description  Data provided by S&P Compustat
# 					NVIDIA Corporation operates as a visual computing company worldwide. It operates in two
# 					segments, Graphics and Compute & Networking.
# 					3-Year Price Performance  Data provided by DataScope from Refinitiv
# 			Key Statistics
# 			Employee Count
# 			Institutional Ownership
# 			Total Revenue (TTM)
#
# 			[Revenue Growth]
# 				(TTM vs. Prior TTM)
# 			Enterprise Value
# 			Ex. Dividend Date
# 			Dividend
# 			P/E (TTM)
# 			Earning Yield (TTM)
# 			EPS (Adjusted TTM)
# 			Dividend Yield (Annualized)
#
# 			[Consensus EPS Estimate]
# 				(Q3 2021)
#
# 			[EPS Growth]
# 				(TTM vs. Prior TTM)
# 				18,975
# 				66.5%
# 				$6,507.00
# 				7/31/2021
# 				+67.60%
# 				$537.1 B
# 				8/24/2021
# 				8/31/2021
# 				$0.040000
# 				0.07%
# 				8/24/2021
# 				77.7
# 				8/24/2021
# 				+1.28%
# 				8/24/2021
# 				$1.04
# 				8/18/2021
# 				$1.10
# 				+106.3%
#
# 			[% Price Above/Below]
# 				50-Day Moving Average
# 				Average Monthly Volume (Millions)
# 				Q4
# 				2018
# 				Q1
# 				2019
# 			Trading Characteristics
#
# 			[52 Week High]
# 				8/23/2021
#
# 			[52 Week Low]
# 				3/8/2021
# 			20-Day Average
# 			50-Day Average
#
# 			[200-Day Average]
# 				Overall
# 				Environment
# 				Social
# 				Governance
# 				TRBC Industry: Semiconductors
# 				200-Day Moving Average
# 				200%
# 				100%
# 				0%
# 				-100%
# 				1,000
# 				0
# 				Q2
# 				Q3
# 				Q4
# 				Q2
# 				Q3
# 				Q4
# 				Q2
# 				Q3
# 				Q1
# 				2020
# 				Q1
# 				2021
# 				$219.97
# 			Price Performance (% Change)
#
# 			[Volume]
# 				$115.67
# 			4 Week
# 			13 Week
#
# 			[52 Week]
# 				8.3
# 				10.8
# 				41.0
# 				1 Year Annualized as of 8/24/2021
# 			Total Return
# 			Standard Deviation
#
# 			[Beta]
# 				13.5
# 				39.3
# 				71.3
# 				0.39
# 				1.61
# 				+71.53%
# 			Average 10-Day
#
# 			[Average 90-Day]
# 				33,792,179.5
# 				36,152,471.2
#
# 			[Shares Outstanding]
# 				2,500,000,000
# 			Environmental, Social & Governance Summary (ESG)
#
# 			[Environmental, Social & Governance Summary (ESG)]
# 				PROVIDED BY MSCI
# 				RATING
# 				NVDA
# 				INDUSTRY
# 				Risk:
# 				Leader = Top 25%
# 				Average = Middle 50%
# 				Laggard = Bottom 25%
# 				LEADER
# 				LEADER
# 				LEADER
# 				LEADER
# 				AVERAGE
# 				AVERAGE
# 				AVERAGE
# 				AVERAGE
# 				LEADER
# 				LEADER
# 				LEADER
# 				LEADER
# 				AVERAGE
# 				AVERAGE
# 				AVERAGE
# 				AVERAGE
# 				Important Information Regarding Third-Party Content
# 				This is not an investment recommendation from Fidelity Investments. Fidelity provides this information as a service to investors from independent, third-party sources.
# 				Performance of analyst recommendations are provided by StarMine from Refinitiv. Current analyst recommendations are collected and standardized by Investars.
# 				See each section in this report for third-party content attribution, as well as the final page of the report for additional important information regarding third-party content.
# 				Page 1
#
# 	[Company Research Highlights®]
# 		This is not an investment recommendation from Fidelity Investments. The information
# 		contained in this report is sourced from independent, third party providers.
#
# 		[Price on 8/24/2021:]
#
# 			[Market Capitalization:]
# 				$217.93
# 				$544.0 B
# 				Information Technology Sector
# 				Semiconductors & Semiconductor Equipment Industry
# 				NASDAQ
#
# 	[NVDA]
#
# 		[NVIDIA ORD SHS]
# 			Starmine
# 			Relative Accuracy2 Standardized Opinion3
#
# 			[NVDA Equity Summary Score]
# 				8 Firms†
# 				Equity Summary Score  (8 Firms†) Provided by StarMine from Refinitiv as of 8/25/2021
# 				Firm1
# 				Ford Equity Research (i)
# 				Refinitiv/Verus (i)
# 				Zacks Investment Research, Inc (i)
# 				ISS-EVA (i)
# 				Jefferson Research (i)
# 				Trading Central (i)
# 				McLean Capital Management (i)
# 				Argus Research A6/Quantitative  (i)
# 				• Opinion used in Equity Summary Score
# 				70
# 				87
# 				82
# 				94
# 				31
# 				16
# 				60
# 				32
# 				Neutral
# 				Neutral
# 				Neutral
# 				Underperform
# 				Neutral
# 				Neutral
# 				Buy
# 				Buy
# 				Firm Opinions  Provided by Investars as of 8/25/2021
# 			Firm1 / Aggregate Opinion
# 			Opinion
#
# 			[1 Year History]
# 				STANDARDIZED OPINION
#
# 			[Investars
# 			Smartindex]
# 				Equity Summary Score is a weighted,
# 				aggregated view of opinions from the
# 				independent research firms on Fidelity.com.
# 				It uses the past accuracy of these firms in
# 				determining the emphasis placed on any
# 				individual opinion.
# 				First Call Consensus Recommendation
# 				is provided by I/B/E/S from Refinitiv, an
# 				independent third-party research provider,
# 				using information gathered from
# 				contributors. The number of contributors for
# 				each security where there is a consensus
# 				recommendation is provided. Each
# 				contributor determines how their individual
# 				recommendation scale maps to the I/B/E/S
# 				from Refinitiv 5-point scale.
# 				Visit Fidelity.com for firm descriptions,
# 				detailed methodologies, and more
# 				information on the Equity Summary Score,
# 				First Call Consensus, opinion history and
# 				performance, and most current available
# 				research reports for NVDA.
# 				1. (i) after the Firm Name indicates an
# 				independent firm that derives no
# 				financial benefit from the nature of their
# 				recommendations.
# 				2. StarMine from Refinitiv Relative Accuracy
# 				is based on a statistical aggregation of
# 				how well a firm performed on all of its
# 				individual stock recommendations in a
# 				given sector. StarMine from Refinitiv first
# 				calculates the individual scores for each
# 				set of recommendations for a single
# 				stock over a 24 month period. Then
# 				StarMine from Refinitiv rolls up these
# 				individual performance scores into a
# 				firm's sector score.
# 				3. Each firm has its own recommendation
# 				categories, making it difficult to compare
# 				one firm’s recommendation to another’s.
# 				Investars, a third-party research
# 				company, collects and standardizes
# 				these recommendations using a
# 				five-point scale.
# 				† The Equity Summary Score provided by
# 				StarMine from Refinitiv is current as of
# 				the date specified. There may be
# 				differences between the Equity Summary
# 				Score analyst count and the number of
# 				underlying analysts listed. Due to the
# 				timing in receiving ratings changes into
# 				the Equity Summary Score model, the
# 				Equity Summary Score analyst count
# 				may lag the ratings count displayed by
# 				one or more days. There may also be
# 				analyst count variations for symbols with
# 				multiple share classes and ADRs. More
# 				details on Equity Summary Score
# 				calculation are included in the
# 				Understanding and Using the Equity
# 				Summary Score Methodology (PDF).
# 				Oppenheimer & Company
# 				RBC Capital Markets
# 				Raymond James
# 				KeyBanc Capital Markets
# 				Needham
# 				Bernstein
# 				Jefferies
# 				CSFB
# 				Merrill Lynch
# 				Wells Fargo Securities
# 				UBS
# 				Wedbush Morgan
# 				Citigroup Investment Research
# 				Baird
# 				Deutsche Bank
# 				Piper Jaffray
# 				SunTrust Robinson Humphrey
# 				Argus Analyst
# 				Ford Equity Research (i)
# 				Refinitiv/Verus (i)
# 				Zacks Investment Research, Inc (i)
# 				ISS-EVA (i)
# 				Jefferson Research (i)
# 				Trading Central (i)
# 				McLean Capital Management (i)
# 				Argus Research A6/Quantitative  (i)
# 				I/B/E/S Estimates from Refinitiv
#
# 			[Equity Summary Score (8 Firms†)]
# 				• Opinion used in Equity Summary Score
# 				Outperform
# 				Outperform
# 				Outperform
# 				Outperform
# 				Outperform
# 				Buy
# 				Buy
# 				Buy
# 				Buy
# 				Buy
# 				Buy
# 				Buy
# 				Buy
# 				Outperform
# 				Neutral
# 				Outperform
# 				Buy
# 				Buy
# 				Neutral
# 				Neutral
# 				Neutral
# 				Neutral
# 				Neutral
# 				Buy
# 				Buy
# 				--
# 				--
# 				Underperform
# 				VERY BULLISH
# 				BULLISH
# 				NEUTRAL
# 				BEARISH
# 				VERY BEARISH
# 				10
# 				9
# 				7
# 				3
# 				1
# 				0
#
# 			[Neutral]
# 				6.1
# 				89.90%
# 				97.57%
# 				64.89%
# 				92.58%
# 				107.72%
# 				88.10%
# 				74.99%
# 				97.33%
# 				88.34%
# 				71.56%
# 				94.87%
# 				87.12%
# 				86.16%
# 				93.47%
# 				83.07%
# 				89.26%
# 				68.33%
# 				83.55%
# 				92.58%
# 				168.14%
# 				148.46%
# 				102.55%
# 				94.38%
# 				60.18%
# 				66.26%
# 				68.56%
# 				--
# 				--
# 				CURRENT FIRM OPINION
# 			Date
#
# 			[Opinion]
# 				07/21/21
# 				Outperform
# 				04/09/21
# 				Outperform
# 				06/22/21
# 				Strong Buy
# 				08/19/21
# 				08/19/21
# 				Buy
# 				Buy
# 				05/27/21
# 				Outperform
# 				08/19/21
# 				Buy
# 				08/19/21
# 				Outperform
# 				08/19/21
# 				Buy
# 				08/12/21
# 				Outperform
# 				08/19/21
# 				Buy
# 				08/16/21
# 				Outperform
# 				07/22/21
# 				Buy
# 				08/19/21
# 				Outperform
# 				08/19/21
# 				Hold
# 				08/19/21
# 				Overweight
# 				08/19/21
# 				07/23/21
# 				Buy
# 				Buy
# 				08/20/21
# 				3
# 				08/23/21
# 				Hold
# 				08/21/21
# 				Neutral
# 				08/01/21
# 				Underweight
# 				08/20/21
# 				Hold
# 				08/22/21
# 				Neutral
# 				08/23/21
# 				08/19/21
# 				08/19/21
# 				Buy
# 				Buy
# 				Buy
# 				08/25/21
#
# 			[Neutral]
# 				Report created on August 25, 2021
# 				The content on this page is provided by third parties and not Fidelity. Fidelity did not prepare and does not endorse such content. All are third-party companies that are not affiliated with Fidelity.
# 				See each section in this report for third-party content attribution and see page 4 for full disclosures.
# 				Page 2
#
# 	[Company Research Highlights®]
# 		This is not an investment recommendation from Fidelity Investments. The information
# 		contained in this report is sourced from independent, third party providers.
#
# 		[Price on 8/24/2021:]
#
# 			[Market Capitalization:]
# 				$217.93
# 				$544.0 B
# 				Information Technology Sector
# 				Semiconductors & Semiconductor Equipment Industry
#
# 		[Recent Recap]
# 			Actuals vs. Estimates by Fiscal Quarter  Data provided by I/B/E/S from Refinitiv
# 			ACTUALS
# 			ESTIMATES
# 			STARMINE ESTIMATES
# 			NVDA PRICE
# 			NASDAQ
#
# 	[NVDA]
#
# 		[NVIDIA ORD SHS]
#
# 			[Earnings in US Dollars]
# 				Today
# 				$250
#
# 			[Last Report: Q2 Earnings on 08/18/21
# 			Reported Earnings: $1.04 per share
# 			Next Expected Report Date: 11/16/21]
# 				NVDA exceeded the First Call Consensus
# 				of $1.015 and exceeded the StarMine
# 				SmartEstimate from Refinitiv of $1.015 for
# 				Q2 2021.
# 				About Starmine SmartEstimate
# 				The StarMine SmartEstimate from Refinitiv
# 				seeks to be more accurate than the
# 				consensus EPS by calculating an analyst's
# 				accuracy and timeliness of an analyst's
# 				estimates into its estimate of earnings.
# 				0.31
# 				Q2
# 				0.45
# 				Q3
# 				0.47
# 				Q4
# 				0.55
# 				Q2
# 				0.73
# 				Q3
# 				0.78
# 				Q4
# 				1.04
# 				Q2
# 				1.10
# 				Q3
# 				$0
# 				0.92
# 				Q1
# 				2021
# 				2021
# 				2021
# 				2021
# 				0.45
# 				Q1
# 				2020
# 				2020
# 				2020
# 				2020
# 			Actuals vs. Estimates for Fiscal Year
# 			Actual ($)
#
# 			[Consensus ($)]
# 				Previous Year (Ends 01/31/21)
# 				Next Year (Ends 01/31/22)
# 				2.50
# 				--
# 				9.72
# 				4.13
# 				Industry Comparisons**  Data provided by S&P Compustat
# 				Valuation Ratios (trailing 12 months)
# 				Price / Earnings
# 				PEG Ratio
# 				Enterprise Value
# 				Price / Sales
# 				Price / Book
# 				Price / Cash Flow
# 				Company Quality Ratios
# 				Gross Profit Margin (Trailing 12 Months)
# 				Operating Margin (Trailing 12 Months)
# 				Return on Assets (Trailing 12 Months)
# 				Return on Equity (Trailing 12 Months)
# 				NVDA
# 				77.7
# 				2.4
# 				$0.00
# 				24.7
# 				30.0
# 				65.8
# 				NVDA
# 				69.1%
# 				33.6%
# 				22.6%
# 				39.2%
# 				Growth Rates (%)
# 				Revenue Growth (Trailing 12 Months vs. Prior Trailing 12 Months)
# 				EPS Growth (Trailing 12 Months vs. Prior Trailing 12 Months)
# 				Revenue % Change (Trailing 12 Months)
# 				NVDA
# 				+67.6%
# 				+106.3%
# 				+68.31%
#
# 			[First Call Estimates
# 			Analysts in Consensus]
# 				35
# 				34
#
# 			[Low / High Range ($)]
# 				9.65 / 10.31
# 				3.99 / 4.20
#
# 			[NVDA Percentile Rank in Industry]
# 				Industry
# 				31.5
# 				1.9
# 				$0.00
# 				11.7
# 				14.5
# 				43.3
# 				Industry
# 				61.2
# 				27.3
# 				17.9
# 				37.1
# 				Industry
# 				+34.3
# 				+84.9
# 				+40.15
# 				80
# 				69
# 				100
# 				99
# 				100
# 				86
# 				90
# 				94
# 				92
# 				88
# 				96
# 				82
# 				84
# 				0: Worst
# 				Best: 100
#
# 			[NVDA Percentile Rank in Industry]
# 				0: Worst
# 				Best: 100
#
# 			[NVDA Percentile Rank in Industry]
# 				0: Worst
# 				Best: 100
# 				** The Industry Average and Percentile Rank methodology is based on the daily list of U.S. equity securities in each industry to which a company belongs, as
# 				determined by Standard & Poor's. S&P uses the Global Industry Classification Standard (GICS)SM, an industry classification system developed by S&P in
# 				collaboration with Morgan Stanley Capital International (MSCI).
# 				A company is assigned to a single GICS sub-industry according to the definition of its principal business activity as determined by Standard & Poor's and MSCI.
# 				Revenues are a significant factor in defining principal business activity; however, earnings analysis and market perception are also important criteria for
# 				classification.
# 				Securities are first grouped into their respective S&P GIC Industry, null values are removed and then the percentile is computed. The percentile is the value of a
# 				variable below which a certain percent of observations fall. So the 20th percentile is the value (or score) below which 20 percent of the observations may be
# 				found. Sometimes, being in the 100th percentile is not the best for items such as Debt to Capital Ratio where a lower number means less debt. Therefore, being
# 				in the 1st percentile indicates lower debt than its peers in the industry.
# 				The Industry Average is a market cap-weighted average of the non-null values in the industry.
# 				Report created on August 25, 2021
# 				The content on this page is provided by third parties and not Fidelity. Fidelity did not prepare and does not endorse such content. All are third-party companies that are not affiliated with Fidelity.
# 				See each section in this report for third-party content attribution.
# 				Page 3
#
# 	[Company Research Highlights®]
# 		This is not an investment recommendation from Fidelity Investments. The information
# 		contained in this report is sourced from independent, third party providers.
#
# 		[Price on 8/24/2021:]
#
# 			[Market Capitalization:]
# 				$217.93
# 				$544.0 B
# 				Information Technology Sector
# 				Semiconductors & Semiconductor Equipment Industry
#
# 		[Important Information Regarding Third-Party Content]
# 			NASDAQ
#
# 	[NVDA]
#
# 		[NVIDIA ORD SHS]
# 			The content compiled in this report is provided by third parties and not Fidelity. Fidelity did not prepare and does not endorse such content. Historical prices provided by Datascope from
# 			Refinitiv. Fundamental data provided by  Standard & Poor’s Compustat®.  Earnings estimates provided by Refinitiv. Analyst recommendations performance measurement provided by
# 			StarMine from Refinitiv. Analyst recommendations data and analysis provided by Investars. All are third-party companies that are not affiliated with Fidelity.
# 			This report provides quotes and data concerning the financial markets, securities and other subjects. Content is supplied by companies that are not affiliated with Fidelity ("Third-Party
# 			Content"). Most Third-Party Content and its source are clearly and prominently identified. Fidelity does not prepare, edit, or endorse Third-Party Content. News and research are subject
# 			to change without notice and Fidelity does not guarantee their accuracy, timeliness, completeness or usefulness, and is not responsible or liable for any content, advertising, products, or
# 			other materials on or available from third parties nor is Fidelity liable for losses resulting from their use. You use Third-Party Content only at your own risk. With respect to research
# 			reports, in order to comply with applicable laws and regulations, Fidelity may at times suppress the delivery of certain reports which are the subject of public offerings made available to
# 			Fidelity’s brokerage customers, or otherwise.
# 			Content is provided for informational and/or educational purposes and is not intended to provide tax, legal or investment advice and should not be construed as an offer to sell, a
# 			solicitation of an offer to buy, or a recommendation for any security by Fidelity or any Third-Party Provider. Requests for reports are unsolicited. Individuals are responsible for determining
# 			whether any investment, security or strategy is appropriate or suitable and that neither Fidelity nor any Third-Party Provider has made any determination that any recommendation,
# 			investment, or strategy in any content is suitable or appropriate based on investment objectives and financial situations.
# 			Report created on August 25, 2021
# 			The content on this page is provided by third parties and not Fidelity. Fidelity did not prepare and does not endorse such content. All are third-party companies that are not affiliated with Fidelity.
# 			See each section in this report for third-party content attribution.
# 			Page 4
# 			© 2021 FMR LLC. All rights reserved. 447628.8.0

# %%
document.text
# Out:
# 'Company Research Highlights ®\nReport created on August 25, 2021\nNVIDIA ORD SHS  NASDAQ:NVDA\n2788 San Tomas Expressway\nSanta Clara, CA 95051\nUSA\nTelephone: 408 486 -2000\nwww.nvidia.com\nPrice on 8/24/2021:\nMarket Capitalization:\n$217.93\n$544.0 B\nInformation Technology Sector\nSemiconductors & Semiconductor Equipment Industry\nBusiness Description  Data provided by S&P Compustat\nNVIDIA Corporation operates as a visual computing company worldwide. It operates in two\nsegments, Graphics and Compute & Networking.\n3-Year Price Performance  Data provided by DataScope from Refinitiv\nKey Statistics\nEmployee Count\nInstitutional Ownership\nTotal Revenue (TTM)\nRevenue Growth\n(TTM vs. Prior TTM)\nEnterprise Value\nEx. Dividend Date\nDividend\nP/E (TTM)\nEarning Yield (TTM)\nEPS (Adjusted TTM)\nDividend Yield (Annualized)\nConsensus EPS Estimate\n(Q3 2021)\nEPS Growth\n(TTM vs. Prior TTM)\n18,975\n66.5%\n$6,507.00\n7/31/2021\n+67.60%\n$537.1 B\n8/24/2021\n8/31/2021\n$0.040000\n0.07%\n8/24/2021\n77.7\n8/24/2021\n+1.28%\n8/24/2021\n$1.04\n8/18/2021\n$1.10\n+106.3%\n% Price Above/Below\n50-Day Moving Average\nAverage Monthly Volume (Millions)\nQ4\n2018\nQ1\n2019\nTrading Characteristics\n52 Week High\n8/23/2021\n52 Week Low\n3/8/2021\n20-Day Average\n50-Day Average\n200-Day Average\nOverall\nEnvironment\nSocial\nGovernance\nTRBC Industry: Semiconductors\n200-Day Moving Average\n200%\n100%\n0%\n-100%\n1,000\n0\nQ2\nQ3\nQ4\nQ2\nQ3\nQ4\nQ2\nQ3\nQ1\n2020\nQ1\n2021\n$219.97\nPrice Performance (% Change)\nVolume\n$115.67\n4 Week\n13 Week\n52 Week\n8.3\n10.8\n41.0\n1 Year Annualized as of 8/24/2021\nTotal Return\nStandard Deviation\nBeta\n13.5\n39.3\n71.3\n0.39\n1.61\n+71.53%\nAverage 10-Day\nAverage 90-Day\n33,792,179.5\n36,152,471.2\nShares Outstanding\n2,500,000,000\nEnvironmental, Social & Governance Summary (ESG)\nEnvironmental, Social & Governance Summary (ESG)\nPROVIDED BY MSCI\nRATING\nNVDA\nINDUSTRY\nRisk:\nLeader = Top 25%\nAverage = Middle 50%\nLaggard = Bottom 25%\nLEADER\nLEADER\nLEADER\nLEADER\nAVERAGE\nAVERAGE\nAVERAGE\nAVERAGE\nLEADER\nLEADER\nLEADER\nLEADER\nAVERAGE\nAVERAGE\nAVERAGE\nAVERAGE\nImportant Information Regarding Third-Party Content\nThis is not an investment recommendation from Fidelity Investments. Fidelity provides this information as a service to investors from independent, third-party sources.\nPerformance of analyst recommendations are provided by StarMine from Refinitiv. Current analyst recommendations are collected and standardized by Investars.\nSee each section in this report for third-party content attribution, as well as the final page of the report for additional important information regarding third-party content.\nPage 1\nCompany Research Highlights®\nThis is not an investment recommendation from Fidelity Investments. The information\ncontained in this report is sourced from independent, third party providers.\nPrice on 8/24/2021:\nMarket Capitalization:\n$217.93\n$544.0 B\nInformation Technology Sector\nSemiconductors & Semiconductor Equipment Industry\nNASDAQ\nNVDA\nNVIDIA ORD SHS\nStarmine\nRelative Accuracy2 Standardized Opinion3\nNVDA Equity Summary Score\n8 Firms†\nEquity Summary Score  (8 Firms†) Provided by StarMine from Refinitiv as of 8/25/2021\nFirm1\nFord Equity Research (i)\nRefinitiv/Verus (i)\nZacks Investment Research, Inc (i)\nISS-EVA (i)\nJefferson Research (i)\nTrading Central (i)\nMcLean Capital Management (i)\nArgus Research A6/Quantitative  (i)\n• Opinion used in Equity Summary Score\n70\n87\n82\n94\n31\n16\n60\n32\nNeutral\nNeutral\nNeutral\nUnderperform\nNeutral\nNeutral\nBuy\nBuy\nFirm Opinions  Provided by Investars as of 8/25/2021\nFirm1 / Aggregate Opinion\nOpinion\n1 Year History\nSTANDARDIZED OPINION\nInvestars\nSmartindex\nEquity Summary Score is a weighted,\naggregated view of opinions from the\nindependent research firms on Fidelity.com.\nIt uses the past accuracy of these firms in\ndetermining the emphasis placed on any\nindividual opinion.\nFirst Call Co ...

# %%
import sys
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfparser import PDFParser
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfdevice import PDFDevice, TagExtractor
from pdfminer.pdfpage import PDFPage
from pdfminer.converter import XMLConverter, HTMLConverter, TextConverter
from pdfminer.cmapdb import CMapDB
from pdfminer.layout import LAParams
from pdfminer.image import ImageWriter
from pdfminer.high_level import extract_text

# %%
import io

# %%
rsrcmgr = PDFResourceManager(caching=True)

# %%
rsrcmgr = PDFResourceManager()
retstr = io.BytesIO()
codec = 'utf-8'
laparams = LAParams()
imagewriter = ImageWriter(str(imdir))

device = TextConverter(rsrcmgr, retstr, laparams=laparams, imagewriter=imagewriter)

# %%
with path.open('rb') as fp:
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0 #is for all
    caching = True
    pagenos=set()
    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password,caching=caching, check_extractable=True):
        interpreter.process_page(page)

device.close()
sv = retstr.getvalue()
retstr.close()

# %%
# creating a pdf reader object 
pdfReader = PyPDF2.PdfFileReader(path.open('rb')) 
    
# printing number of pages in pdf file 
print(pdfReader.numPages) 
    
# creating a page object 
pageObj = pdfReader.getPage(1) 
    
# extracting text from page 
print(pageObj.extractText()) 
    
# closing the pdf file object 
# pdfFileObj.close()
# Out:
# 4
# Company Research Highlights®NVDANASDAQThis is not an investment recommendation from Fidelity Investments. The information
# contained in this report is sourced from independent, third party providers.Price on 8/24/2021:$217.93Information Technology SectorMarket Capitalization:$544.0 BSemiconductors & Semiconductor Equipment Industry
# NVIDIA ORD SHSThe content on this page is provided by third parties and not Fidelity. Fidelity did not prepare and does not endorse such content. All are third-party companies that are not affiliated with Fidelity.
# See each section in this report for third-party content attribution and see page 4 for full disclosures.Page 2Report created on August 25, 2021Equity Summary Score is a weighted,aggregated view of opinions from the
# independent research firms on Fidelity.com.
# It uses the past accuracy of these firms in
# determining the emphasis placed on any
# individual opinion.
# First Call Consensus Recommendation
# is provided by I/B/E/S from Refinitiv, an
# independent third-party research provider,
# using information gathered from
# contributors. The number of contributors for
# each security where there is a consensus
# recommendation is provided. Each
# contributor determines how their individual
# recommendation scale maps to the I/B/E/S
# from Refinitiv 5-point scale.
# Visit Fidelity.com for firm descriptions,
# detailed methodologies, and more
# information on the Equity Summary Score,
# First Call Consensus, opinion history and
# performance, and most current available
# research reports for NVDA.Equity Summary Score  (8 Firms
# ƒ) Provided by StarMine from Refinitiv as of 8/25/2021Firm1StarmineRelative Accuracy2Standardized Opinion3Ford Equity Research (i)70Neutral
# Refinitiv/Verus (i)87Neutral
# Zacks Investment Research, Inc (i)82Neutral
# ISS-EVA (i)94Underperform
# Jefferson Research (i)31Neutral
# Trading Central (i)16Neutral
# McLean Capital Management (i)60Buy
# Argus Research A6/Quantitative (i)32Buy
# Ł Opinion used in Equity Summary ScoreNVDA Equity Summary Score8 Firmsƒ109VERY BULLISH7BULLISH3NEUTRAL1BEARISH0VERY BEARISH6.1NeutralFirm Opinions  Provided by Investars as of 8/25/2021
# STANDARDIZED OPINIONCURRENT FIRM OPINIONFirm1 / Aggregate OpinionOpinion1 Year History
# InvestarsSmartindexDateOpinion
# Oppenheimer & CompanyOutperform 89.90%07/21/21Outperform
# RBC Capital MarketsOutperform 97.57%04/09/21Outperform
# Raymond JamesBuy 64.89%06/22/21Strong Buy
# KeyBanc Capital MarketsBuy 92.58%08/19/21Buy
# NeedhamBuy 107.72%08/19/21Buy
# BernsteinOutperform 88.10%05/27/21Outperform
# JefferiesBuy 74.99%08/19/21Buy
# CSFBOutperform 97.33%08/19/21Outperform
# Merrill LynchBuy 88.34%08/19/21Buy
# Wells Fargo SecuritiesOutperform 71.56%08/12/21Outperform
# UBSBuy 94.87%08/19/21Buy
# Wedbush MorganBuy 87.12%08/16/21Outperform
# Citigroup Investment ResearchBuy 86.16%07/22/21Buy
# BairdOutperform 93.47%08/19/21Outperform
# Deutsche BankNeutral 83.07%08/19/21Hold
# Piper JaffrayOutperform 89.26%08/19/21Overweight
# SunTrust Robinson HumphreyBuy 68.33%08/19/21Buy
# Argus AnalystBuy 83.55%07/23/21Buy
# Ford Equity Research (i)Neutral 92.58%08/20/213
# Refinitiv/Verus (i)Neutral 168.14%08/23/21Hold
# Zacks Investment Research, Inc (i)Neutral 148.46%08/21/21Neutral
# ISS-EVA (i)Underperform 102.55%08/01/21Underweight
# Jefferson Research (i)Neutral 94.38%08/20/21Hold
# Trading Central (i)Neutral 60.18%08/22/21Neutral
# McLean Capital Management (i)Buy 66.26%08/23/21Buy
# Argus Research A6/Quantitative (i)Buy 68.56%08/19/21Buy
# I/B/E/S Estimates from Refinitiv-- --08/19/21Buy
# Equity Summary Score (8 Firmsƒ)-- --08/25/21Neutral
# Ł Opinion used in Equity Summary Score1.(i) after the Firm Name indicates an
# independent firm that derives no
# financial benefit from the nature of their
# recommendations.2.StarMine from Refinitiv Relative Accuracy
# is based on a statistical aggregation of
# how well a firm performed on all of its
# individual stock recommendations in a
# given sector. StarMine from Refinitiv first
# calculates the individual scores for each
# set of recommendations for a single
# stock over a 24 month period. Then
# StarMine from Refinitiv rolls up these
# individual performance scores into a
# firm's sector score.3.Each firm has its own recommendation
# categories, making it difficult to compare
# one firm™s recommendation to another™s.
# Investars, a third-party research
# company, collects and standardizes
# these recommendations using a
# five-point scale.ƒThe Equity Summary Score provided by
# StarMine from Refinitiv is current as of
# the date specified. There may be
# differences between the Equity Summary
# Score analyst count and the number of
# underlying analysts listed. Due to the
# timing in receiving ratings changes into
# the Equity Summary Score model, the
# Equity Summary Score analyst count
# may lag the ratings count displayed by
# one or more days. There may also be
# analyst count variations for symbols with
# multiple share classes and ADRs. More
# details on Equity Summary Score
# calculation are included in theUnderstanding and Using the Equity
# Summary Score Methodology (PDF).

# %%
pageObj.getContents()
# Out:
# {'/Filter': '/FlateDecode'}

# %%
pageObj.artBox
# Out:
# RectangleObject([0, 0, 612, 792])

# %%
from pdfminer.high_level import extract_text

# %%
text = extract_text(path)
print(text)
# Out:
# Company Research Highlights ®
#
# Report created on August 25, 2021
#
# NVIDIA ORD SHS  NASDAQ:NVDA
# 2788 San Tomas Expressway
# Santa Clara, CA 95051
# USA
# Telephone: 408 486 -2000
# www.nvidia.com
#
# Price on 8/24/2021:
# Market Capitalization:
#
# $217.93
# $544.0 B
#
# Information Technology Sector
# Semiconductors & Semiconductor Equipment Industry
#
# Business Description  Data provided by S&P Compustat
#
# NVIDIA Corporation operates as a visual computing company worldwide. It operates in two
# segments, Graphics and Compute & Networking.
#
# 3-Year Price Performance  Data provided by DataScope from Refinitiv
#
# Key Statistics
#
# Employee Count
#
# Institutional Ownership
#
# Total Revenue (TTM)
#
# Revenue Growth
# (TTM vs. Prior TTM)
#
# Enterprise Value
#
# Ex. Dividend Date
#
# Dividend
#
# P/E (TTM)
#
# Earning Yield (TTM)
#
# EPS (Adjusted TTM)
#
# Dividend Yield (Annualized)
#
# Consensus EPS Estimate
# (Q3 2021)
#
# EPS Growth
# (TTM vs. Prior TTM)
#
# 18,975
#
# 66.5%
#
# $6,507.00
# 7/31/2021
#
# +67.60%
#
# $537.1 B
# 8/24/2021
#
# 8/31/2021
#
# $0.040000
#
# 0.07%
# 8/24/2021
#
# 77.7
# 8/24/2021
#
# +1.28%
# 8/24/2021
#
# $1.04
# 8/18/2021
#
# $1.10
#
# +106.3%
#
# % Price Above/Below
#
# 50-Day Moving Average
#
# Average Monthly Volume (Millions)
#
# Q4
# 2018
#
# Q1
# 2019
#
# Trading Characteristics
#
# 52 Week High
# 8/23/2021
#
# 52 Week Low
# 3/8/2021
#
#    20-Day Average
#
#    50-Day Average
#
#    200-Day Average
#
# Overall
#
#    Environment
#
#    Social
#
#    Governance
#
# TRBC Industry: Semiconductors
#
# 200-Day Moving Average
#
# 200%
#
# 100%
#
# 0%
#
# -100%
#
# 1,000
#
# 0
#
# Q2
#
# Q3
#
# Q4
#
# Q2
#
# Q3
#
# Q4
#
# Q2
#
# Q3
#
# Q1
# 2020
#
# Q1
# 2021
#
# $219.97
#
# Price Performance (% Change)
#
# Volume
#
# $115.67
#
#    4 Week
#
#    13 Week
#
#    52 Week
#
# 8.3
#
# 10.8
#
# 41.0
#
# 1 Year Annualized as of 8/24/2021
#    Total Return
#
#    Standard Deviation
#
#    Beta
#
# 13.5
#
# 39.3
#
# 71.3
#
# 0.39
#
# 1.61
#
# +71.53%
#
#    Average 10-Day
#
#    Average 90-Day
#
# 33,792,179.5
#
# 36,152,471.2
#
# Shares Outstanding
#
# 2,500,000,000
#
# Environmental, Social & Governance Summary (ESG)
#
# Environmental, Social & Governance Summary (ESG)
# PROVIDED BY MSCI
# RATING
#
# NVDA
#
# INDUSTRY
#
# LEADER
# LEADER
# LEADER
# LEADER
#
# AVERAGE
# AVERAGE
# AVERAGE
# AVERAGE
#
# LEADER
# LEADER
# LEADER
# LEADER
#
# AVERAGE
# AVERAGE
# AVERAGE
# AVERAGE
#
# Risk:
#
# Leader = Top 25%
#
# Average = Middle 50%
#
# Laggard = Bottom 25%
#
# Important Information Regarding Third-Party Content
# This is not an investment recommendation from Fidelity Investments. Fidelity provides this information as a service to investors from independent, third-party sources.
# Performance of analyst recommendations are provided by StarMine from Refinitiv. Current analyst recommendations are collected and standardized by Investars.
# See each section in this report for third-party content attribution, as well as the final page of the report for additional important information regarding third-party content.
#
# Page 1
#
# Company Research Highlights®
#
# This is not an investment recommendation from Fidelity Investments. The information
# contained in this report is sourced from independent, third party providers.
#
# Price on 8/24/2021:
# Market Capitalization:
#
# $217.93
# $544.0 B
#
# Information Technology Sector
# Semiconductors & Semiconductor Equipment Industry
#
# NASDAQ
#
# NVDA
# NVIDIA ORD SHS
#
# Starmine
#
# Relative Accuracy2 Standardized Opinion3
#
# NVDA Equity Summary Score
# 8 Firms†
#
# Equity Summary Score  (8 Firms†) Provided by StarMine from Refinitiv as of 8/25/2021
#
# Firm1
# Ford Equity Research (i)
# Refinitiv/Verus (i)
# Zacks Investment Research, Inc (i)
# ISS-EVA (i)
# Jefferson Research (i)
# Trading Central (i)
# McLean Capital Management (i)
# Argus Research A6/Quantitative  (i)
# • Opinion used in Equity Summary Score
#
# 70
# 87
# 82
# 94
# 31
# 16
# 60
# 32
#
# Neutral
# Neutral
# Neutral
# Underperform
# Neutral
# Neutral
# Buy
# Buy
#
# Firm Opinions  Provided by Investars as of 8/25/2021
#
# Firm1 / Aggregate Opinion
#
# Opinion
#
# 1 Year History
#
# STANDARDIZED OPINION
#
# Investars
# Smartindex
#
# Equity Summary Score is a weighted,
# aggregated view of opinions from the
# independent research firms on Fidelity.com.
# It uses the past accuracy of these firms in
# determining the emphasis placed on any
# individual opinion.
#
# First Call Consensus Recommendation
# is provided by I/B/E/S from Refinitiv, an
# independent third-party research provider,
# using information gathered from
# contributors. The number of contributors for
# each security where there is a consensus
# recommendation is provided. Each
# contributor determines how their individual
# recommendation scale maps to the I/B/E/S
# from Refinitiv 5-point scale.
#
# Visit Fidelity.com for firm descriptions,
# detailed methodologies, and more
# information on the Equity Summary Score,
# First Call Consensus, opinion history and
# performance, and most current available
# research reports for NVDA.
#
# 1. (i) after the Firm Name indicates an
# independent firm that derives no
# financial benefit from the nature of their
# recommendations.
#
# 2. StarMine from Refinitiv Relative Accuracy
# is based on a statistical aggregation of
# how well a firm performed on all of its
# individual stock recommendations in a
# given sector. StarMine from Refinitiv first
# calculates the individual scores for each
# set of recommendations for a single
# stock over a 24 month period. Then
# StarMine from Refinitiv rolls up these
# individual performance scores into a
# firm's sector score.
#
# 3. Each firm has its own recommendation
#
# categories, making it difficult to compare
# one firm’s recommendation to another’s.
# Investars, a third-party research
# company, collects and standardizes
# these recommendations using a
# five-point scale.
#
# † The Equity Summary Score provided by
# StarMine from Refinitiv is current as of
# the date specified. There may be
# differences between the Equity Summary
# Score analyst count and the number of
# underlying analysts listed. Due to the
# timing in receiving ratings changes into
# the Equity Summary Score model, the
# Equity Summary Score analyst count
# may lag the ratings count displayed by
# one or more days. There may also be
# analyst count variations for symbols with
# multiple share classes and ADRs. More
# details on Equity Summary Score
# calculation are included in the
# Understanding and Using the Equity
# Summary Score Methodology (PDF).
#
# Oppenheimer & Company
#
# RBC Capital Markets
#
# Raymond James
#
# KeyBanc Capital Markets
#
# Needham
#
# Bernstein
#
# Jefferies
#
# CSFB
#
# Merrill Lynch
#
# Wells Fargo Securities
#
# UBS
#
# Wedbush Morgan
#
# Citigroup Investment Research
#
# Baird
#
# Deutsche Bank
#
# Piper Jaffray
#
# SunTrust Robinson Humphrey
#
# Argus Analyst
#
# Ford Equity Research (i)
# Refinitiv/Verus (i)
# Zacks Investment Research, Inc (i)
# ISS-EVA (i)
# Jefferson Research (i)
# Trading Central (i)
# McLean Capital Management (i)
# Argus Research A6/Quantitative  (i)
# I/B/E/S Estimates from Refinitiv
#
# Equity Summary Score (8 Firms†)
# • Opinion used in Equity Summary Score
#
# Outperform
#
# Outperform
#
# Outperform
#
# Outperform
#
# Outperform
#
# Buy
#
# Buy
#
# Buy
#
# Buy
#
# Buy
#
# Buy
#
# Buy
#
# Buy
#
# Outperform
#
# Neutral
#
# Outperform
#
# Buy
#
# Buy
#
# Neutral
#
# Neutral
#
# Neutral
#
# Neutral
#
# Neutral
#
# Buy
#
# Buy
#
# --
#
# --
#
# Underperform
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# VERY BULLISH
#
# BULLISH
#
# NEUTRAL
#
# BEARISH
#
# VERY BEARISH
#
# 10
#
# 9
#
# 7
#
# 3
#
# 1
#
# 0
#
# Neutral
# 6.1
#
# CURRENT FIRM OPINION
#
# Date
#
# Opinion
#
# 07/21/21
#
# Outperform
#
# 04/09/21
#
# Outperform
#
# 06/22/21
#
# Strong Buy
#
# 08/19/21
#
# 08/19/21
#
# Buy
#
# Buy
#
# 05/27/21
#
# Outperform
#
# 08/19/21
#
# Buy
#
# 08/19/21
#
# Outperform
#
# 08/19/21
#
# Buy
#
# 08/12/21
#
# Outperform
#
# 08/19/21
#
# Buy
#
# 08/16/21
#
# Outperform
#
# 07/22/21
#
# Buy
#
# 08/19/21
#
# Outperform
#
# 08/19/21
#
# Hold
#
# 08/19/21
#
# Overweight
#
# 08/19/21
#
# 07/23/21
#
# Buy
#
# Buy
#
# 08/20/21
#
# 3
#
# 08/23/21
#
# Hold
#
# 08/21/21
#
# Neutral
#
# 08/01/21
#
# Underweight
#
# 08/20/21
#
# Hold
#
# 08/22/21
#
# Neutral
#
# 08/23/21
#
# 08/19/21
#
# 08/19/21
#
# Buy
#
# Buy
#
# Buy
#
# 08/25/21
#
# Neutral
#
# 89.90%
#
# 97.57%
#
# 64.89%
#
# 92.58%
#
# 107.72%
#
# 88.10%
#
# 74.99%
#
# 97.33%
#
# 88.34%
#
# 71.56%
#
# 94.87%
#
# 87.12%
#
# 86.16%
#
# 93.47%
#
# 83.07%
#
# 89.26%
#
# 68.33%
#
# 83.55%
#
# 92.58%
#
# 168.14%
#
# 148.46%
#
# 102.55%
#
# 94.38%
#
# 60.18%
#
# 66.26%
#
# 68.56%
#
# --
#
# --
#
# Report created on August 25, 2021
# The content on this page is provided by third parties and not Fidelity. Fidelity did not prepare and does not endorse such content. All are third-party companies that are not affiliated with Fidelity.
# See each section in this report for third-party content attribution and see page 4 for full disclosures.
#
# Page 2
#
# Company Research Highlights®
#
# This is not an investment recommendation from Fidelity Investments. The information
# contained in this report is sourced from independent, third party providers.
#
# Price on 8/24/2021:
# Market Capitalization:
#
# $217.93
# $544.0 B
#
# Information Technology Sector
# Semiconductors & Semiconductor Equipment Industry
#
# Recent Recap
#
# Actuals vs. Estimates by Fiscal Quarter  Data provided by I/B/E/S from Refinitiv
#
# ACTUALS
#
# ESTIMATES
#
# STARMINE ESTIMATES
#
# NVDA PRICE
#
# NASDAQ
#
# NVDA
# NVIDIA ORD SHS
#
# Earnings in US Dollars
#
# Today
#
# $250
#
# Last Report: Q2 Earnings on 08/18/21
# Reported Earnings: $1.04 per share
# Next Expected Report Date: 11/16/21
#
# NVDA exceeded the First Call Consensus
# of $1.015 and exceeded the StarMine
# SmartEstimate from Refinitiv of $1.015 for
# Q2 2021.
#
# About Starmine SmartEstimate
# The StarMine SmartEstimate from Refinitiv
# seeks to be more accurate than the
# consensus EPS by calculating an analyst's
# accuracy and timeliness of an analyst's
# estimates into its estimate of earnings.
#
# 0.31
#
# Q2
#
# 0.45
#
# Q3
#
# 0.47
#
# Q4
#
# 0.55
#
# Q2
#
# 0.73
#
# Q3
#
# 0.78
#
# Q4
#
# 1.04
#
# Q2
#
# 1.10
#
# Q3
#
# $0
#
# 0.92
#
# Q1
# 2021
# 2021
# 2021
# 2021
#
# 0.45
#
# Q1
# 2020
# 2020
# 2020
# 2020
#
# Actuals vs. Estimates for Fiscal Year
#
#
#
# Actual ($)
#
# Consensus ($)
#
# Previous Year (Ends 01/31/21)
# Next Year (Ends 01/31/22)
#
# 2.50
# --
#
# 9.72
# 4.13
#
# Industry Comparisons**  Data provided by S&P Compustat
#
# Valuation Ratios (trailing 12 months)
# Price / Earnings
# PEG Ratio
# Enterprise Value
# Price / Sales
# Price / Book
# Price / Cash Flow
#
# Company Quality Ratios
# Gross Profit Margin (Trailing 12 Months)
# Operating Margin (Trailing 12 Months)
# Return on Assets (Trailing 12 Months)
# Return on Equity (Trailing 12 Months)
#
# NVDA
# 77.7
# 2.4
# $0.00
# 24.7
# 30.0
# 65.8
#
# NVDA
# 69.1%
# 33.6%
# 22.6%
# 39.2%
#
# Growth Rates (%)
# Revenue Growth (Trailing 12 Months vs. Prior Trailing 12 Months)
# EPS Growth (Trailing 12 Months vs. Prior Trailing 12 Months)
# Revenue % Change (Trailing 12 Months)
#
# NVDA
# +67.6%
# +106.3%
# +68.31%
#
# First Call Estimates
# Analysts in Consensus
#
# Low / High Range ($)
#
# 9.65 / 10.31
# 3.99 / 4.20
#
# 35
# 34
#
# NVDA Percentile Rank in Industry
#
# Industry
# 31.5
# 1.9
# $0.00
# 11.7
# 14.5
# 43.3
#
# Industry
# 61.2
# 27.3
# 17.9
# 37.1
#
# Industry
# +34.3
# +84.9
# +40.15
#
# 80
# 69
# 100
# 99
# 100
# 86
#
# 90
# 94
# 92
# 88
#
# 96
# 82
# 84
#
# 0: Worst
#
# Best: 100
#
# NVDA Percentile Rank in Industry
#
# 0: Worst
#
# Best: 100
#
# NVDA Percentile Rank in Industry
#
# 0: Worst
#
# Best: 100
#
# ** The Industry Average and Percentile Rank methodology is based on the daily list of U.S. equity securities in each industry to which a company belongs, as
# determined by Standard & Poor's. S&P uses the Global Industry Classification Standard (GICS)SM, an industry classification system developed by S&P in
# collaboration with Morgan Stanley Capital International (MSCI).
#
# A company is assigned to a single GICS sub-industry according to the definition of its principal business activity as determined by Standard & Poor's and MSCI.
# Revenues are a significant factor in defining principal business activity; however, earnings analysis and market perception are also important criteria for
# classification.
#
# Securities are first grouped into their respective S&P GIC Industry, null values are removed and then the percentile is computed. The percentile is the value of a
# variable below which a certain percent of observations fall. So the 20th percentile is the value (or score) below which 20 percent of the observations may be
# found. Sometimes, being in the 100th percentile is not the best for items such as Debt to Capital Ratio where a lower number means less debt. Therefore, being
# in the 1st percentile indicates lower debt than its peers in the industry.
#
# The Industry Average is a market cap-weighted average of the non-null values in the industry.
#
# Report created on August 25, 2021
# The content on this page is provided by third parties and not Fidelity. Fidelity did not prepare and does not endorse such content. All are third-party companies that are not affiliated with Fidelity.
# See each section in this report for third-party content attribution.
#
# Page 3
#
# Company Research Highlights®
#
# This is not an investment recommendation from Fidelity Investments. The information
# contained in this report is sourced from independent, third party providers.
#
# Price on 8/24/2021:
# Market Capitalization:
#
# $217.93
# $544.0 B
#
# Information Technology Sector
# Semiconductors & Semiconductor Equipment Industry
#
# Important Information Regarding Third-Party Content
#
# NASDAQ
#
# NVDA
# NVIDIA ORD SHS
#
# The content compiled in this report is provided by third parties and not Fidelity. Fidelity did not prepare and does not endorse such content. Historical prices provided by Datascope from
# Refinitiv. Fundamental data provided by  Standard & Poor’s Compustat®.  Earnings estimates provided by Refinitiv. Analyst recommendations performance measurement provided by
# StarMine from Refinitiv. Analyst recommendations data and analysis provided by Investars. All are third-party companies that are not affiliated with Fidelity.
#
# This report provides quotes and data concerning the financial markets, securities and other subjects. Content is supplied by companies that are not affiliated with Fidelity ("Third-Party
# Content"). Most Third-Party Content and its source are clearly and prominently identified. Fidelity does not prepare, edit, or endorse Third-Party Content. News and research are subject
# to change without notice and Fidelity does not guarantee their accuracy, timeliness, completeness or usefulness, and is not responsible or liable for any content, advertising, products, or
# other materials on or available from third parties nor is Fidelity liable for losses resulting from their use. You use Third-Party Content only at your own risk. With respect to research
# reports, in order to comply with applicable laws and regulations, Fidelity may at times suppress the delivery of certain reports which are the subject of public offerings made available to
# Fidelity’s brokerage customers, or otherwise.
#
# Content is provided for informational and/or educational purposes and is not intended to provide tax, legal or investment advice and should not be construed as an offer to sell, a
# solicitation of an offer to buy, or a recommendation for any security by Fidelity or any Third-Party Provider. Requests for reports are unsolicited. Individuals are responsible for determining
# whether any investment, security or strategy is appropriate or suitable and that neither Fidelity nor any Third-Party Provider has made any determination that any recommendation,
# investment, or strategy in any content is suitable or appropriate based on investment objectives and financial situations.
#
# Report created on August 25, 2021
# The content on this page is provided by third parties and not Fidelity. Fidelity did not prepare and does not endorse such content. All are third-party companies that are not affiliated with Fidelity.
# See each section in this report for third-party content attribution.
#
#
# Page 4
#
#  © 2021 FMR LLC. All rights reserved. 447628.8.0

# %%
from pdfminer.high_level import extract_pages
from pdfminer.layout import LTTextContainer

# %%
for page_layout in extract_pages(path):
    break
page_layout
# Out:
# <LTPage(1) 0.000,0.000,612.000,792.000 rotate=0>

# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import HTMLConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from io import BytesIO


def convert_pdf_to_html(path):
    rsrcmgr = PDFResourceManager()
    retstr = BytesIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = HTMLConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    fp = open(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0 #is for all
    caching = True
    pagenos=set()
    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password,caching=caching, check_extractable=True):
        interpreter.process_page(page)
    fp.close()
    device.close()
    str = retstr.getvalue()
    retstr.close()
    return str

test = convert_pdf_to_html(path)

# %%
with open('test.html', 'wb') as f:
    f.write(test)

# %%
for page in doc.iter_pages():
    im = page.images[0].as_pil()  # requires pillow
    display(im)

# %%
document.style_distribution

# %%
document.metadata
# Out:
# defaultdict(str,
#             {'style_distribution': <pdfstructure.analysis.styledistribution.StyleDistribution at 0x296350c74c0>,
#              'filename': 'msft_highlights.pdf'})

# %%
document.

# %%
for page in doc.iter_pages():
    im = page.images[0].as_pil()  # requires pillow
    display(im)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-5f55f7070aae> in <module>
# ----> 1 for page in doc.iter_pages():
#       2     im = page.images[0].as_pil()  # requires pillow
#       3     display(im)
#
# NameError: name 'doc' is not defined

# %%
for shape in page.shapes.iter_in_bbox((0, 0, 100, 200)):
    print(shape.path, shape.fill.color.as_rgb())
im = page.images[0].as_pil()  # requires pillow
im.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-e637f1dff570> in <module>
# ----> 1 for shape in page.shapes.iter_in_bbox((0, 0, 100, 200)):
#       2     print(shape.path, shape.fill.color.as_rgb())
#       3 im = page.images[0].as_pil()  # requires pillow
#       4 im.show()
#
# NameError: name 'page' is not defined

# %%
print(prettyString)
# Out:
# [Company Research Highlights ®]
# 	Report created on August 25, 2021
#
# 	[NVIDIA ORD SHS  NASDAQ:NVDA]
#
# 		[2788 San Tomas Expressway
# 		Santa Clara, CA 95051
# 		USA
# 		Telephone: 408 486 -2000
# 		www.nvidia.com]
#
# 			[Price on 8/24/2021:]
#
# 				[Market Capitalization:]
# 					$217.93
# 					$544.0 B
# 					Information Technology Sector
# 					Semiconductors & Semiconductor Equipment Industry
# 					Business Description  Data provided by S&P Compustat
# 					NVIDIA Corporation operates as a visual computing company worldwide. It operates in two
# 					segments, Graphics and Compute & Networking.
# 					3-Year Price Performance  Data provided by DataScope from Refinitiv
# 			Key Statistics
# 			Employee Count
# 			Institutional Ownership
# 			Total Revenue (TTM)
#
# 			[Revenue Growth]
# 				(TTM vs. Prior TTM)
# 			Enterprise Value
# 			Ex. Dividend Date
# 			Dividend
# 			P/E (TTM)
# 			Earning Yield (TTM)
# 			EPS (Adjusted TTM)
# 			Dividend Yield (Annualized)
#
# 			[Consensus EPS Estimate]
# 				(Q3 2021)
#
# 			[EPS Growth]
# 				(TTM vs. Prior TTM)
# 				18,975
# 				66.5%
# 				$6,507.00
# 				7/31/2021
# 				+67.60%
# 				$537.1 B
# 				8/24/2021
# 				8/31/2021
# 				$0.040000
# 				0.07%
# 				8/24/2021
# 				77.7
# 				8/24/2021
# 				+1.28%
# 				8/24/2021
# 				$1.04
# 				8/18/2021
# 				$1.10
# 				+106.3%
#
# 			[% Price Above/Below]
# 				50-Day Moving Average
# 				Average Monthly Volume (Millions)
# 				Q4
# 				2018
# 				Q1
# 				2019
# 			Trading Characteristics
#
# 			[52 Week High]
# 				8/23/2021
#
# 			[52 Week Low]
# 				3/8/2021
# 			20-Day Average
# 			50-Day Average
#
# 			[200-Day Average]
# 				Overall
# 				Environment
# 				Social
# 				Governance
# 				TRBC Industry: Semiconductors
# 				200-Day Moving Average
# 				200%
# 				100%
# 				0%
# 				-100%
# 				1,000
# 				0
# 				Q2
# 				Q3
# 				Q4
# 				Q2
# 				Q3
# 				Q4
# 				Q2
# 				Q3
# 				Q1
# 				2020
# 				Q1
# 				2021
# 				$219.97
# 			Price Performance (% Change)
#
# 			[Volume]
# 				$115.67
# 			4 Week
# 			13 Week
#
# 			[52 Week]
# 				8.3
# 				10.8
# 				41.0
# 				1 Year Annualized as of 8/24/2021
# 			Total Return
# 			Standard Deviation
#
# 			[Beta]
# 				13.5
# 				39.3
# 				71.3
# 				0.39
# 				1.61
# 				+71.53%
# 			Average 10-Day
#
# 			[Average 90-Day]
# 				33,792,179.5
# 				36,152,471.2
#
# 			[Shares Outstanding]
# 				2,500,000,000
# 			Environmental, Social & Governance Summary (ESG)
#
# 			[Environmental, Social & Governance Summary (ESG)]
# 				PROVIDED BY MSCI
# 				RATING
# 				NVDA
# 				INDUSTRY
# 				Risk:
# 				Leader = Top 25%
# 				Average = Middle 50%
# 				Laggard = Bottom 25%
# 				LEADER
# 				LEADER
# 				LEADER
# 				LEADER
# 				AVERAGE
# 				AVERAGE
# 				AVERAGE
# 				AVERAGE
# 				LEADER
# 				LEADER
# 				LEADER
# 				LEADER
# 				AVERAGE
# 				AVERAGE
# 				AVERAGE
# 				AVERAGE
# 				Important Information Regarding Third-Party Content
# 				This is not an investment recommendation from Fidelity Investments. Fidelity provides this information as a service to investors from independent, third-party sources.
# 				Performance of analyst recommendations are provided by StarMine from Refinitiv. Current analyst recommendations are collected and standardized by Investars.
# 				See each section in this report for third-party content attribution, as well as the final page of the report for additional important information regarding third-party content.
# 				Page 1
#
# 	[Company Research Highlights®]
# 		This is not an investment recommendation from Fidelity Investments. The information
# 		contained in this report is sourced from independent, third party providers.
#
# 		[Price on 8/24/2021:]
#
# 			[Market Capitalization:]
# 				$217.93
# 				$544.0 B
# 				Information Technology Sector
# 				Semiconductors & Semiconductor Equipment Industry
# 				NASDAQ
#
# 	[NVDA]
#
# 		[NVIDIA ORD SHS]
# 			Starmine
# 			Relative Accuracy2 Standardized Opinion3
#
# 			[NVDA Equity Summary Score]
# 				8 Firms†
# 				Equity Summary Score  (8 Firms†) Provided by StarMine from Refinitiv as of 8/25/2021
# 				Firm1
# 				Ford Equity Research (i)
# 				Refinitiv/Verus (i)
# 				Zacks Investment Research, Inc (i)
# 				ISS-EVA (i)
# 				Jefferson Research (i)
# 				Trading Central (i)
# 				McLean Capital Management (i)
# 				Argus Research A6/Quantitative  (i)
# 				• Opinion used in Equity Summary Score
# 				70
# 				87
# 				82
# 				94
# 				31
# 				16
# 				60
# 				32
# 				Neutral
# 				Neutral
# 				Neutral
# 				Underperform
# 				Neutral
# 				Neutral
# 				Buy
# 				Buy
# 				Firm Opinions  Provided by Investars as of 8/25/2021
# 			Firm1 / Aggregate Opinion
# 			Opinion
#
# 			[1 Year History]
# 				STANDARDIZED OPINION
#
# 			[Investars
# 			Smartindex]
# 				Equity Summary Score is a weighted,
# 				aggregated view of opinions from the
# 				independent research firms on Fidelity.com.
# 				It uses the past accuracy of these firms in
# 				determining the emphasis placed on any
# 				individual opinion.
# 				First Call Consensus Recommendation
# 				is provided by I/B/E/S from Refinitiv, an
# 				independent third-party research provider,
# 				using information gathered from
# 				contributors. The number of contributors for
# 				each security where there is a consensus
# 				recommendation is provided. Each
# 				contributor determines how their individual
# 				recommendation scale maps to the I/B/E/S
# 				from Refinitiv 5-point scale.
# 				Visit Fidelity.com for firm descriptions,
# 				detailed methodologies, and more
# 				information on the Equity Summary Score,
# 				First Call Consensus, opinion history and
# 				performance, and most current available
# 				research reports for NVDA.
# 				1. (i) after the Firm Name indicates an
# 				independent firm that derives no
# 				financial benefit from the nature of their
# 				recommendations.
# 				2. StarMine from Refinitiv Relative Accuracy
# 				is based on a statistical aggregation of
# 				how well a firm performed on all of its
# 				individual stock recommendations in a
# 				given sector. StarMine from Refinitiv first
# 				calculates the individual scores for each
# 				set of recommendations for a single
# 				stock over a 24 month period. Then
# 				StarMine from Refinitiv rolls up these
# 				individual performance scores into a
# 				firm's sector score.
# 				3. Each firm has its own recommendation
# 				categories, making it difficult to compare
# 				one firm’s recommendation to another’s.
# 				Investars, a third-party research
# 				company, collects and standardizes
# 				these recommendations using a
# 				five-point scale.
# 				† The Equity Summary Score provided by
# 				StarMine from Refinitiv is current as of
# 				the date specified. There may be
# 				differences between the Equity Summary
# 				Score analyst count and the number of
# 				underlying analysts listed. Due to the
# 				timing in receiving ratings changes into
# 				the Equity Summary Score model, the
# 				Equity Summary Score analyst count
# 				may lag the ratings count displayed by
# 				one or more days. There may also be
# 				analyst count variations for symbols with
# 				multiple share classes and ADRs. More
# 				details on Equity Summary Score
# 				calculation are included in the
# 				Understanding and Using the Equity
# 				Summary Score Methodology (PDF).
# 				Oppenheimer & Company
# 				RBC Capital Markets
# 				Raymond James
# 				KeyBanc Capital Markets
# 				Needham
# 				Bernstein
# 				Jefferies
# 				CSFB
# 				Merrill Lynch
# 				Wells Fargo Securities
# 				UBS
# 				Wedbush Morgan
# 				Citigroup Investment Research
# 				Baird
# 				Deutsche Bank
# 				Piper Jaffray
# 				SunTrust Robinson Humphrey
# 				Argus Analyst
# 				Ford Equity Research (i)
# 				Refinitiv/Verus (i)
# 				Zacks Investment Research, Inc (i)
# 				ISS-EVA (i)
# 				Jefferson Research (i)
# 				Trading Central (i)
# 				McLean Capital Management (i)
# 				Argus Research A6/Quantitative  (i)
# 				I/B/E/S Estimates from Refinitiv
#
# 			[Equity Summary Score (8 Firms†)]
# 				• Opinion used in Equity Summary Score
# 				Outperform
# 				Outperform
# 				Outperform
# 				Outperform
# 				Outperform
# 				Buy
# 				Buy
# 				Buy
# 				Buy
# 				Buy
# 				Buy
# 				Buy
# 				Buy
# 				Outperform
# 				Neutral
# 				Outperform
# 				Buy
# 				Buy
# 				Neutral
# 				Neutral
# 				Neutral
# 				Neutral
# 				Neutral
# 				Buy
# 				Buy
# 				--
# 				--
# 				Underperform
# 				VERY BULLISH
# 				BULLISH
# 				NEUTRAL
# 				BEARISH
# 				VERY BEARISH
# 				10
# 				9
# 				7
# 				3
# 				1
# 				0
#
# 			[Neutral]
# 				6.1
# 				89.90%
# 				97.57%
# 				64.89%
# 				92.58%
# 				107.72%
# 				88.10%
# 				74.99%
# 				97.33%
# 				88.34%
# 				71.56%
# 				94.87%
# 				87.12%
# 				86.16%
# 				93.47%
# 				83.07%
# 				89.26%
# 				68.33%
# 				83.55%
# 				92.58%
# 				168.14%
# 				148.46%
# 				102.55%
# 				94.38%
# 				60.18%
# 				66.26%
# 				68.56%
# 				--
# 				--
# 				CURRENT FIRM OPINION
# 			Date
#
# 			[Opinion]
# 				07/21/21
# 				Outperform
# 				04/09/21
# 				Outperform
# 				06/22/21
# 				Strong Buy
# 				08/19/21
# 				08/19/21
# 				Buy
# 				Buy
# 				05/27/21
# 				Outperform
# 				08/19/21
# 				Buy
# 				08/19/21
# 				Outperform
# 				08/19/21
# 				Buy
# 				08/12/21
# 				Outperform
# 				08/19/21
# 				Buy
# 				08/16/21
# 				Outperform
# 				07/22/21
# 				Buy
# 				08/19/21
# 				Outperform
# 				08/19/21
# 				Hold
# 				08/19/21
# 				Overweight
# 				08/19/21
# 				07/23/21
# 				Buy
# 				Buy
# 				08/20/21
# 				3
# 				08/23/21
# 				Hold
# 				08/21/21
# 				Neutral
# 				08/01/21
# 				Underweight
# 				08/20/21
# 				Hold
# 				08/22/21
# 				Neutral
# 				08/23/21
# 				08/19/21
# 				08/19/21
# 				Buy
# 				Buy
# 				Buy
# 				08/25/21
#
# 			[Neutral]
# 				Report created on August 25, 2021
# 				The content on this page is provided by third parties and not Fidelity. Fidelity did not prepare and does not endorse such content. All are third-party companies that are not affiliated with Fidelity.
# 				See each section in this report for third-party content attribution and see page 4 for full disclosures.
# 				Page 2
#
# 	[Company Research Highlights®]
# 		This is not an investment recommendation from Fidelity Investments. The information
# 		contained in this report is sourced from independent, third party providers.
#
# 		[Price on 8/24/2021:]
#
# 			[Market Capitalization:]
# 				$217.93
# 				$544.0 B
# 				Information Technology Sector
# 				Semiconductors & Semiconductor Equipment Industry
#
# 		[Recent Recap]
# 			Actuals vs. Estimates by Fiscal Quarter  Data provided by I/B/E/S from Refinitiv
# 			ACTUALS
# 			ESTIMATES
# 			STARMINE ESTIMATES
# 			NVDA PRICE
# 			NASDAQ
#
# 	[NVDA]
#
# 		[NVIDIA ORD SHS]
#
# 			[Earnings in US Dollars]
# 				Today
# 				$250
#
# 			[Last Report: Q2 Earnings on 08/18/21
# 			Reported Earnings: $1.04 per share
# 			Next Expected Report Date: 11/16/21]
# 				NVDA exceeded the First Call Consensus
# 				of $1.015 and exceeded the StarMine
# 				SmartEstimate from Refinitiv of $1.015 for
# 				Q2 2021.
# 				About Starmine SmartEstimate
# 				The StarMine SmartEstimate from Refinitiv
# 				seeks to be more accurate than the
# 				consensus EPS by calculating an analyst's
# 				accuracy and timeliness of an analyst's
# 				estimates into its estimate of earnings.
# 				0.31
# 				Q2
# 				0.45
# 				Q3
# 				0.47
# 				Q4
# 				0.55
# 				Q2
# 				0.73
# 				Q3
# 				0.78
# 				Q4
# 				1.04
# 				Q2
# 				1.10
# 				Q3
# 				$0
# 				0.92
# 				Q1
# 				2021
# 				2021
# 				2021
# 				2021
# 				0.45
# 				Q1
# 				2020
# 				2020
# 				2020
# 				2020
# 			Actuals vs. Estimates for Fiscal Year
# 			Actual ($)
#
# 			[Consensus ($)]
# 				Previous Year (Ends 01/31/21)
# 				Next Year (Ends 01/31/22)
# 				2.50
# 				--
# 				9.72
# 				4.13
# 				Industry Comparisons**  Data provided by S&P Compustat
# 				Valuation Ratios (trailing 12 months)
# 				Price / Earnings
# 				PEG Ratio
# 				Enterprise Value
# 				Price / Sales
# 				Price / Book
# 				Price / Cash Flow
# 				Company Quality Ratios
# 				Gross Profit Margin (Trailing 12 Months)
# 				Operating Margin (Trailing 12 Months)
# 				Return on Assets (Trailing 12 Months)
# 				Return on Equity (Trailing 12 Months)
# 				NVDA
# 				77.7
# 				2.4
# 				$0.00
# 				24.7
# 				30.0
# 				65.8
# 				NVDA
# 				69.1%
# 				33.6%
# 				22.6%
# 				39.2%
# 				Growth Rates (%)
# 				Revenue Growth (Trailing 12 Months vs. Prior Trailing 12 Months)
# 				EPS Growth (Trailing 12 Months vs. Prior Trailing 12 Months)
# 				Revenue % Change (Trailing 12 Months)
# 				NVDA
# 				+67.6%
# 				+106.3%
# 				+68.31%
#
# 			[First Call Estimates
# 			Analysts in Consensus]
# 				35
# 				34
#
# 			[Low / High Range ($)]
# 				9.65 / 10.31
# 				3.99 / 4.20
#
# 			[NVDA Percentile Rank in Industry]
# 				Industry
# 				31.5
# 				1.9
# 				$0.00
# 				11.7
# 				14.5
# 				43.3
# 				Industry
# 				61.2
# 				27.3
# 				17.9
# 				37.1
# 				Industry
# 				+34.3
# 				+84.9
# 				+40.15
# 				80
# 				69
# 				100
# 				99
# 				100
# 				86
# 				90
# 				94
# 				92
# 				88
# 				96
# 				82
# 				84
# 				0: Worst
# 				Best: 100
#
# 			[NVDA Percentile Rank in Industry]
# 				0: Worst
# 				Best: 100
#
# 			[NVDA Percentile Rank in Industry]
# 				0: Worst
# 				Best: 100
# 				** The Industry Average and Percentile Rank methodology is based on the daily list of U.S. equity securities in each industry to which a company belongs, as
# 				determined by Standard & Poor's. S&P uses the Global Industry Classification Standard (GICS)SM, an industry classification system developed by S&P in
# 				collaboration with Morgan Stanley Capital International (MSCI).
# 				A company is assigned to a single GICS sub-industry according to the definition of its principal business activity as determined by Standard & Poor's and MSCI.
# 				Revenues are a significant factor in defining principal business activity; however, earnings analysis and market perception are also important criteria for
# 				classification.
# 				Securities are first grouped into their respective S&P GIC Industry, null values are removed and then the percentile is computed. The percentile is the value of a
# 				variable below which a certain percent of observations fall. So the 20th percentile is the value (or score) below which 20 percent of the observations may be
# 				found. Sometimes, being in the 100th percentile is not the best for items such as Debt to Capital Ratio where a lower number means less debt. Therefore, being
# 				in the 1st percentile indicates lower debt than its peers in the industry.
# 				The Industry Average is a market cap-weighted average of the non-null values in the industry.
# 				Report created on August 25, 2021
# 				The content on this page is provided by third parties and not Fidelity. Fidelity did not prepare and does not endorse such content. All are third-party companies that are not affiliated with Fidelity.
# 				See each section in this report for third-party content attribution.
# 				Page 3
#
# 	[Company Research Highlights®]
# 		This is not an investment recommendation from Fidelity Investments. The information
# 		contained in this report is sourced from independent, third party providers.
#
# 		[Price on 8/24/2021:]
#
# 			[Market Capitalization:]
# 				$217.93
# 				$544.0 B
# 				Information Technology Sector
# 				Semiconductors & Semiconductor Equipment Industry
#
# 		[Important Information Regarding Third-Party Content]
# 			NASDAQ
#
# 	[NVDA]
#
# 		[NVIDIA ORD SHS]
# 			The content compiled in this report is provided by third parties and not Fidelity. Fidelity did not prepare and does not endorse such content. Historical prices provided by Datascope from
# 			Refinitiv. Fundamental data provided by  Standard & Poor’s Compustat®.  Earnings estimates provided by Refinitiv. Analyst recommendations performance measurement provided by
# 			StarMine from Refinitiv. Analyst recommendations data and analysis provided by Investars. All are third-party companies that are not affiliated with Fidelity.
# 			This report provides quotes and data concerning the financial markets, securities and other subjects. Content is supplied by companies that are not affiliated with Fidelity ("Third-Party
# 			Content"). Most Third-Party Content and its source are clearly and prominently identified. Fidelity does not prepare, edit, or endorse Third-Party Content. News and research are subject
# 			to change without notice and Fidelity does not guarantee their accuracy, timeliness, completeness or usefulness, and is not responsible or liable for any content, advertising, products, or
# 			other materials on or available from third parties nor is Fidelity liable for losses resulting from their use. You use Third-Party Content only at your own risk. With respect to research
# 			reports, in order to comply with applicable laws and regulations, Fidelity may at times suppress the delivery of certain reports which are the subject of public offerings made available to
# 			Fidelity’s brokerage customers, or otherwise.
# 			Content is provided for informational and/or educational purposes and is not intended to provide tax, legal or investment advice and should not be construed as an offer to sell, a
# 			solicitation of an offer to buy, or a recommendation for any security by Fidelity or any Third-Party Provider. Requests for reports are unsolicited. Individuals are responsible for determining
# 			whether any investment, security or strategy is appropriate or suitable and that neither Fidelity nor any Third-Party Provider has made any determination that any recommendation,
# 			investment, or strategy in any content is suitable or appropriate based on investment objectives and financial situations.
# 			Report created on August 25, 2021
# 			The content on this page is provided by third parties and not Fidelity. Fidelity did not prepare and does not endorse such content. All are third-party companies that are not affiliated with Fidelity.
# 			See each section in this report for third-party content attribution.
# 			Page 4
# 			© 2021 FMR LLC. All rights reserved. 447628.8.0

# %%
document.elements[0].children[0].heading_text
# Out:
# 'Report created on August 25, 2021'
